# %% [markdown]
# # Introdução

# %% [markdown]
# Instruções gerais:
# - Vocês precisarão instalar provavelmente apenas uma biblioteca para essa aula (nba_api). Para os exercícios mais avançados, tem um processo mais complexo de instalação de aplicações e bibliotecas (a saber: google-api-python-client, google-auth-httplib2, google-auth-oauthlib)
# - Precisaremos ter contas em alguns dos serviços que iremos utilizar se der tempo de chegar nos exercícios mais avançados. Tentem criar suas contas antes da aula, pois alguns são bastante complexos. Se não conseguirem não tem problema, aprenderemos bastante já com os serviços mais básicos.
#   - Para os exercícios intermediários, precisaremos de uma conta no Spotify (gratuita é suficiente) e uma conta no Youtube
#   - Para os exercícios avançados serão necessários uma conta no Google API, no Google Cloud Platform - GCP e no Twitter (a proposta é passar pelo processo de criação de conta com vocês)

# %% [markdown]
# # TEORIA

# %% [markdown]
# ## API (Application Programming Interface)

# %% [markdown]
# Antes de falarmos de API, precisamos entender como a internet funciona e porque devemos separar as partes de um software.

# %% [markdown]
# ## Como funciona o protocolo HTTP
#
# A internet trafega através do protocolo **HTTP (*Hypertext Transfer Protocol*)**. O protocolo HTTP foi criado por **Tim Berners-Lee**, o criador da web, enquanto ele trabalhava na CERN em 1989 (sua equipe e ele também foram responsáveis pelo HTML).
#
# O HTTP possui duas entidades básicas: a **Request (pedido)** e a **Response (resposta)**
#
# Sempre que entramos em uma página, enviamos uma request para o servidor do site e esperamos uma response com o HTML da página.

# %% [markdown]
# Sempre que enviamos um ***Request (pedido)*** devemos especificar um método. A tabela abaixo cita os métodos mais comuns e explica brevemente o objetivo de cada um:
#
# | Método |        Objetivo       |
# |:------:|:---------------------:|
# | GET    | Obter informações     |
# | POST   | Salvar informações    |
# | PUT    | Atualizar informações |
# | DELETE | Deletar informações   |
#
# Todos eles são comumente utilizados por APIs.
#
# O método ***GET*** é o que seu navegador usa para baixar o HTML da página.
#
# O metódo ***POST*** também é muito utilizado sempre que você envia algum formulário em um site.
#
# Além do método, as requisições também possuem um **header**:
#
# O **Header (cabeçalho)** tem a função de dizer para o servidor diversos dados sobre quem fez a solicitação. Dessa forma, o servidor consegue até permitir que você veja mais informações dependendo do seu nível de acesso.

# %% [markdown]
# ### PROTOCOLO DE COMUNICAÇÃO HTTP
# <img src="https://www.pubnub.com/wp-content/uploads/2014/11/HTTP-LONG-POLLING.png">
# <br>
# Os clientes, nossos computadores, conseguem acessar páginas e aplicações na internet atravez deste protocolo, que responde as requisições com arquivos de acordo com seu nível de acesso e com o que foi solicitado.
# Se você acessar o site da Digital House por exemplo e pedir para inspecionar (no Chrome `Ctrl+Shift+i`) os dados de rede, vai ver todos as solicitações e respostas do seu navegador ao servidor.
# <br>
# O resultado será algo parecido com isso:
# <img src="https://developer.chrome.com/devtools/images/network-panel.png">

# %% [markdown]
# ## Códigos de status
# A solicitação que acabamos de fazer tinha um código de status de 200. Os códigos de status são retornados com cada solicitação feita para um servidor da web. Códigos de status indicam informações sobre o que aconteceu com uma solicitação. Aqui estão alguns códigos que são relevantes para solicitações GET :
#
# - 200 - tudo correu bem, e o resultado foi devolvido (se houver)
# - 301- o servidor está redirecionando você para um terminal diferente. Isso pode acontecer quando uma empresa troca nomes de domínio ou um nome de terminal é alterado.
# - 401- o servidor acha que você não está autenticado. Isso acontece quando você não envia as credenciais corretas para acessar uma API (falaremos sobre autenticação em uma postagem posterior).
# - 400- o servidor acha que você fez um pedido incorreto. Isso pode acontecer quando você não envia os dados corretos, entre outras coisas.
# - 403 - o recurso que você está tentando acessar é proibido - você não tem as permissões certas para visualizá-lo.
# - 404 - o recurso que você tentou acessar não foi encontrado no servidor.
#
# Se tentarmos acessar um site ou endereço que não existe, receberemos o código acima.

# %%
import requests

response = requests.get("http://www.globo.com/cursos/data_science")
print(response.status_code)
# Out:
# 404

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json")
print(response.status_code)
# Out:
# 400

# %%
# This is the latitude and longitude of New York City.
parameters = {"q": 'data science'}

# Make a get request with the parameters.
response = requests.get("http://google.com/search", params=parameters)
print(response.status_code)

# Equivalente a URL: http://google.com/search?q=data+science
# Out:
# 200

# %% [markdown]
# ___

# %% [markdown]
# ## O que é uma API?

# %% [markdown]
# Podemos dizer que uma API é como se fosse uma página da web só que para computadores. Só eles conseguirem acessar, ler e interagir da maneira adequada com as APIs.
#
# Ao trabalhar com projetos que envolvem dados, é muito comum vocês utilizarão APIs tanto internas (fornecidas pelas próprias empresas em que vocês trabalham) quanto externas.
#
# APIs são uma das principais formas para se obter dados que devem ser analisados.
#
# <center>
# <img src="https://cdn-images-1.medium.com/max/1600/1*CkynRe-J1FVnUAk7JmOTdQ.gif" alt="drawing" width="600px"></center>

# %% [markdown]
# ### Por que acessar uma API ao invez de um banco de dados diretamente?
#
# Porque o mundo está cheio de pessoas mal intencionadas e ao dar acesso direto ao banco de dados você está correndo risco de ter seus dados apagados, alterados ou que as pessoas tenham acesso a dados que deveriam ser confidenciais.
#
# É uma forma de separar, controlar e até multiplicar os acessos a sistemas de forma organizada.
# Imagine se cada cliente de um restaurante fosse fazer os pedidos direto ao Chef na cozinha, é provável que os pedidos saiam errados, fora de ordem ou o Chef fique estressado, por isso existe o garçom que faz o papel de levar os pedidos e trazer a comida organizando uma fila de pedidos.
# A API faz exatamente isso, controlando o que pedir e para quem pedir.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*Elr2TpvMI7xfSack20B6bA.png">

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='s7wmiS2mSXY'

YouTubeVideo(id=id,width=600,height=300)

# %% [markdown]
# Mas por que usar uma API em vez de um conjunto de dados estáticos que você pode baixar? As APIs são úteis nos seguintes casos:
#
# - Os dados estão mudando rapidamente. Um exemplo disso são os dados do preço das ações. Não faz muito sentido gerar um conjunto de dados e baixá-lo a cada minuto - isso demandará muita largura de banda e será bastante lento.
# - Você quer um pequeno pedaço de um conjunto muito maior de dados. Comentários do Reddit são um exemplo. E se você quiser apenas puxar seus próprios comentários no Reddit? Não faz muito sentido baixar todo o banco de dados Reddit, depois filtrar apenas seus próprios comentários.
# - Há computação repetida envolvida. Spotify tem uma API que pode dizer o gênero de uma peça musical. Você poderia, teoricamente, criar seu próprio classificador e usá-lo para categorizar a música, mas nunca terá tantos dados quanto o Spotify.
#
# Em casos como os acima, uma API é a solução certa.
#
# Agora, vamos consultar uma API simples para recuperar dados sobre a Estação Espacial Internacional (ISS). O uso de uma API nos poupará tempo e esforço ao fazermos todos os cálculos.
# Então, faremos uma solicitação GET para http://api.open-notify.org/iss-passum terminal que não existe, de acordo com a documentação da API .

# %%
response = requests.get("http://api.open-notify.org/iss-pass")
print(response.status_code)
# Out:
# 404

# %%
response = requests.get("http://api.open-notify.org/iss-now.json")
print(response.status_code)
# Out:
# 200

# %%
response.text
# Out:
# '{"iss_position": {"latitude": "-51.1124", "longitude": "14.7339"}, "message": "success", "timestamp": 1598549371}'

# %%
# This is the latitude and longitude of New York City.
parameters = {"lat": 40.71, "lon": -74}

# Make a get request with the parameters.
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)
print(response.status_code)
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74'

# %%
response.content
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1598548352, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 254, \n      "risetime": 1598595925\n    }, \n    {\n      "duration": 633, \n      "risetime": 1598601492\n    }, \n    {\n      "duration": 633, \n      "risetime": 1598607301\n    }, \n    {\n      "duration": 566, \n      "risetime": 1598613190\n    }, \n    {\n      "duration": 585, \n      "risetime": 1598619051\n    }\n  ]\n}\n'

# %%
type(response.content)
# Out:
# bytes

# %% [markdown]
# ___

# %% [markdown]
# ## XML × JSON × YAML
#
# Anos atrás a comunicação entre serviços se dava por XML usando o padrão SOAP. Na era da mobilidade, JSON passou a ser largamente usado. Hoje, aos poucos está sendo substituido por YAML, que é similar,  porém mais amigável para leitura por humanos.
#
# <img src="XML×JSON×YAML.png" width="150%"></img>
#
# A estrutura de um json se parece muito com os dicionários em Python
#
# Ele foi feito para que máquinas entendam seus dados e os utilizem como quiser.
#
# Outra característica das APIs REST é a **divisão dos recursos**. Por exemplo:
#
# https://jsonplaceholder.typicode.com/users/1
#
# Ao abrirmos esta URL estamos fazendo um GET (o navegador executa o GET) para obtermos informações do usuário (/users) com código 1 (/1). Podemos trocar o código do usuário para buscar outros usuários.
#
# Também podemos pedir todos os usuários digitando:
#
# https://jsonplaceholder.typicode.com/users

# %% [markdown]
# ## Trabalhando com dados JSON
# Você deve ter notado que o conteúdo da resposta anterior era um string (embora tenha sido mostrado como um objeto, podemos facilmente converter o conteúdo em uma string usando response.content.decode("utf-8")).
#
# As strings são a forma como passamos as informações para as APIs, mas é difícil obter as informações que queremos delas. Como decodificar a string que recebemos e trabalhar com ela em Python?
#
# O JSON é uma maneira de codificar estruturas de dados, como listas e dicionários, para seqüências de caracteres que garantem que elas sejam facilmente legíveis por máquinas. JSON é o formato principal no qual os dados são passados para as APIs e a maioria dos servidores de API envia suas respostas nesse formato.
#
# O Python tem um ótimo suporte a JSON, com a biblioteca 'json'. Ele faz parte da biblioteca padrão, portanto, não precisamos instalar nada para usá-lo. Podemos converter listas e dicionários em JSON e converter strings em listas e dicionários . No caso dos nossos dados do ISS Pass, é um dicionário codificado para uma string no formato JSON.
#
# A biblioteca json possui dois métodos principais:
#
# - dumps - Utiliza um objeto Python e o converte em uma string.
# - loads - Leva uma string JSON e a converte em um objeto Python.

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1598548352,
#   'latitude': 40.71,
#   'longitude': -74.0,
#   'passes': 5},
#  'response': [{'duration': 254, 'risetime': 1598595925},
#   {'duration': 633, 'risetime': 1598601492},
#   {'duration': 633, 'risetime': 1598607301},
#   {'duration': 566, 'risetime': 1598613190},
#   {'duration': 585, 'risetime': 1598619051}]}

# %%
type(response.json())
# Out:
# dict

# %%
meu_dicionario = response.json()
meu_dicionario
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1598548352,
#   'latitude': 40.71,
#   'longitude': -74.0,
#   'passes': 5},
#  'response': [{'duration': 254, 'risetime': 1598595925},
#   {'duration': 633, 'risetime': 1598601492},
#   {'duration': 633, 'risetime': 1598607301},
#   {'duration': 566, 'risetime': 1598613190},
#   {'duration': 585, 'risetime': 1598619051}]}

# %%
meu_request = meu_dicionario['request']
meu_request
# Out:
# {'altitude': 100,
#  'datetime': 1598548352,
#  'latitude': 40.71,
#  'longitude': -74.0,
#  'passes': 5}

# %%
meu_request['datetime']
# Out:
# 1598548352

# %%
response.json()['request']['datetime']
# Out:
# 1598548352

# %%
import json
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "request": {
#         "altitude": 100,
#         "datetime": 1598548352,
#         "latitude": 40.71,
#         "longitude": -74.0,
#         "passes": 5
#     },
#     "response": [
#         {
#             "duration": 254,
#             "risetime": 1598595925
#         },
#         {
#             "duration": 633,
#             "risetime": 1598601492
#         },
#         {
#             "duration": 633,
#             "risetime": 1598607301
#         },
#         {
#             "duration": 566,
#             "risetime": 1598613190
#         },
#         {
#             "duration": 585,
#             "risetime": 1598619051
#         }
#     ]
# }

# %% [markdown]
# ## Parâmetros de consulta
# Você verá que, no último exemplo, recebemos um código de status '400', que indica uma solicitação incorreta. Se você observar a documentação da API do OpenNotify, veremos que o ponto de extremidade do ISS Pass requer dois parâmetros.
#
# O ponto de extremidade do ISS Pass retorna quando o ISS passará em seguida sobre um determinado local na Terra. Para calcular isso, precisamos passar as coordenadas do local para a API. Fazemos isso passando dois parâmetros - latitude e longitude.
#
# Podemos fazer isso adicionando um argumento opcional de palavra-chave params, a nosso pedido. Neste caso, existem dois parâmetros que precisamos passar:
#
# - lat - A latitude do local que queremos.
# - lon - A longitude do local que queremos.
#
# Podemos criar um dicionário com esses parâmetros e depois passá-los para a função 'requests.get'.
#
# Nós também podemos fazer a mesma coisa diretamente, adicionando os parâmetros de consulta para a url, como este: http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74.
#
# É quase sempre preferível configurar os parâmetros como um dicionário, porque requests cuida de algumas coisas que surgem, como formatar corretamente os parâmetros da consulta.
#
# Faremos uma solicitação usando as coordenadas da cidade de São Paulo e veremos a resposta que recebermos.
#
# __São Paulo__<br>
# Latitude: -23.68<br>
# Longitude: -46.87

# %%
# Este comando busca os mesmos dados que o comando que usamos para buscar os dados de São Paulo acima
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=-23.68&lon=-46.87")
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "request": {
#         "altitude": 100,
#         "datetime": 1598548353,
#         "latitude": -23.68,
#         "longitude": -46.87,
#         "passes": 5
#     },
#     "response": [
#         {
#             "duration": 521,
#             "risetime": 1598577790
#         },
#         {
#             "duration": 651,
#             "risetime": 1598583544
#         },
#         {
#             "duration": 593,
#             "risetime": 1598631755
#         },
#         {
#             "duration": 614,
#             "risetime": 1598637542
#         }
#     ]
# }

# %% [markdown]
# ## Uma mesma API pode conter diversas **ROTAS** ou endpoints diferentes
#
# Como o servidor faz para saber o que está sendo pedido na solicitação? Isso é especificado na URL (Uniform Resource Locator), uma espécie de caminho que indica onde um recurso pode ser encontrado.
#
# - protocol: Indica o protocolo que será utilizado para acessar (HTTP, FTP, HTTPS)
# - host: Indica como encontrar na rede (local ou internet) o servidor que tem o recurso
# - port: Indica em qual porta o servidor está escutando. A 'porta' de um IP é o que permite que um computador se comunique simultaneamente com outros. Cada comunicação requer uma porta (são ao todo 65.535)
# - path: Indica o caminho para localizar o recurso dentro do servidor. Como se fossem pastas do navegador de arquivos
# - query: Indica qual é a consulta que está sendo realizada. Inclui quais são os argumentos desejados ou necessários, bem como os valores a ser utilizado para cada argumento
#
# <img src="http://digitalad.com.br/DH/Picture1.png">
# <br>
#
# Por exemplo, podemos usar a funcionalidade dessa API da ISS para descobrir todas as pessoas que estão em orbita.

# %%
# Get the response from the API endpoint.
response = requests.get("http://api.open-notify.org/astros.json")
data = response.json()
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "number": 3,
#     "people": [
#         {
#             "craft": "ISS",
#             "name": "Chris Cassidy"
#         },
#         {
#             "craft": "ISS",
#             "name": "Anatoly Ivanishin"
#         },
#         {
#             "craft": "ISS",
#             "name": "Ivan Vagner"
#         }
#     ]
# }

# %% [markdown]
# Para conseguir capturar um dado específico do JSON, basta fazer as referências como se buscasse em um dicionário, identificando o tipo de cada elemento ou nível do dicionário (exemplo: um dicionário de listas, um dicionário de dicionários, etc).

# %%
print('Total de astronautas:', data["number"])
print('Primeiro da lista:', data["people"][0])
print('Nome do 1o da lista:', data["people"][0]['name'])
# Out:
# Total de astronautas: 3
# Primeiro da lista: {'craft': 'ISS', 'name': 'Chris Cassidy'}
# Nome do 1o da lista: Chris Cassidy

# %%
data['people']
# Out:
# [{'craft': 'ISS', 'name': 'Chris Cassidy'},
#  {'craft': 'ISS', 'name': 'Anatoly Ivanishin'},
#  {'craft': 'ISS', 'name': 'Ivan Vagner'}]

# %% [markdown]
# ___

# %% [markdown]
# # PRÁTICA

# %% [markdown]
# ## Acesso simples

# %% [markdown]
# ### Mercado Livre
# Vamos utilizar a API do MercadoLivre para consultar anúncios<br>
# <strong>O que fazer</strong>: acesso, download, tratamento e cálculo<br>
# <strong>Documentação</strong>: https://developers.mercadolivre.com.br/pt_br/api-docs-pt-br<br>
# <strong>Objetivo</strong>: Qual o preço médio dos anúncios de iphones em Minas Gerais<br>
# <strong>Desafio</strong>: Resolve o exercício através de uma função para permitir realizar a mesma consulta com outros itens ou estados<br>
# <strong>Dica</strong>: Carregue seus dados para um dataframe para facilitar a manipulação dos dados

# %%
import sys
import json
import codecs
import urllib.request
import urllib.parse
import pandas as pd

def usage():
    print('Uso: {0} "PRODUTO"'.format(sys.argv[0]))
    print('Busque um produto por vez')
    sys.exit(1)


def busca(item):
    url = 'https://api.mercadolibre.com/sites/MLB/search?q={0}'.format(item)
    opener = urllib.request.build_opener()
    opener.addheaders = [
        ('User-agent',
         "Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201")]

    with opener.open(url) as fd:
        content = fd.read()
        encoding = fd.info().get_content_charset()
        content = content.decode(encoding)

    dic = json.loads(content)
    #utf-8

# encoding
# 0001 = 'A' (encoding 1)
# 0001 = '$' (encoding 2)

    
    return dic

# %%
temp = requests.get('https://api.mercadolibre.com/sites/MLB/search?q=iphone')

# %%
temp.json()
# Out:
# {'site_id': 'MLB',
#  'query': 'iphone',
#  'paging': {'total': 22693, 'offset': 0, 'limit': 50, 'primary_results': 1013},
#  'results': [{'id': 'MLB1618920771',
#    'site_id': 'MLB',
#    'title': 'iPhone 7 Plus 128 Gb Prata 3 Gb Ram',
#    'seller': {'id': 405964617,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 3807,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-31T19:01:45.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-7-plus-128-gb-prata-3-gb-ram/p/MLB6240136',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/729977-MLA40678415625_022020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 317.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-PR',
#     'state_name': 'Paraná',
#     'city_id': 'TUxCQ0NVUjYyZmY1',
#     'city_name': 'Curitiba'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'xd_drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-PR', 'name': 'Paraná'},
#     'city': {'id': 'TUxCQ0NVUjYyZmY1', 'name': 'Curitiba'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Marca'},
#     {'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_id': '8010379',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'id': 'GPU_MODEL',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8010379',
#        'name': 'PowerVR Series7XT Plus'}],
#      'attribute_group_name': 'Outros'},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'id': 'ITEM_CONDITION',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724},
#     {'attribute_group_id': 'OTHERS',
#      'id': 'LINE',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_name': 'iPhone 7 Plus',
#      'value_struct': None,
#      'values': [{'id': '312157',
#        'name': 'iPhone 7 Plus',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'value_id': '312157',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A10 Fusion',
#      'values': [{'id': '6946002',
#        'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_id': '6946002',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Peso',
#      'value_struct': {'number': 188, 'unit': 'g'},
#      'values': [{'id': '522900',
#        'name': '188 g',
#        'struct': {'number': 188, 'unit': 'g'},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_id': '522900',
#      'value_name': '188 g'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 4230,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6240136',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1585945069',
#    'site_id': 'MLB',
#    'title': 'iPhone SE (2nd Generation) 128 Gb Branco 3 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 281817,
#       'canceled': 11829,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 269988},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0235,
#        'value': 1546,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 60721},
#       'cancellations': {'rate': 0.0103, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 3715.52,
#    'currency_id': 'BRL',
#    'available_quantity': 250,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-02T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-se-2nd-generation-128-gb-branco-3-gb-ram/p/MLB15591335',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/983659-MLA42348493114_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 309.63,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_struct': None,
#      'value_name': 'Apple',
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344'},
#     {'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'value_struct': None,
#      'name': 'Modelo de GPU',
#      'values': [{'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'name': 'Condição do item',
#      'value_name': 'Novo',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_id': '58993',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'name': 'Linha'},
#     {'value_name': 'iPhone SE (2nd Generation)',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '8230322',
#        'name': 'iPhone SE (2nd Generation)',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '8230322',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL'},
#     {'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A13 Bionic',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '6861161',
#      'value_name': '148 g',
#      'attribute_group_name': 'Outros',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_struct': {'number': 148, 'unit': 'g'},
#      'values': [{'id': '6861161',
#        'name': '148 g',
#        'struct': {'number': 148, 'unit': 'g'},
#        'source': 1}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15591335',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1608016128',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s Plus 32 Gb Prata 2 Gb Ram',
#    'seller': {'id': 259218381,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 2360,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-plus-32-gb-prata-2-gb-ram/p/MLB11712143',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/820963-MLA31347985928_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 196.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SC',
#     'state_name': 'Santa Catarina',
#     'city_id': 'TUxCQ1BPUjE3NWM0',
#     'city_name': 'Porto União'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SC', 'name': 'Santa Catarina'},
#     'city': {'id': 'TUxCQ1BPUjE3NWM0', 'name': 'Porto União'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None},
#     {'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799,
#        'id': '2230284'}],
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros'},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_name': 'iPhone 6s Plus',
#      'values': [{'id': '312153',
#        'name': 'iPhone 6s Plus',
#        'struct': None,
#        'source': 1}],
#      'value_id': '312153',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'value_name': 'Apple A9',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '6973026',
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'name': 'Modelo do processador'},
#     {'id': 'WEIGHT',
#      'value_name': '192 g',
#      'value_struct': {'number': 192, 'unit': 'g'},
#      'attribute_group_id': 'OTHERS',
#      'name': 'Peso',
#      'value_id': '522894',
#      'values': [{'id': '522894',
#        'name': '192 g',
#        'struct': {'number': 192, 'unit': 'g'},
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB11712143',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1622965271',
#    'site_id': 'MLB',
#    'title': 'iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram',
#    'seller': {'id': 8710030,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 4100,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-19T14:49:16.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-se-2nd-generation-256-gb-preto-3-gb-ram/p/MLB15591337',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/917693-MLA42348499125_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 341.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-40',
#     'city_name': 'São Caetano do Sul'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-40', 'name': 'São Caetano do Sul'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha'},
#     {'id': 'MODEL',
#      'value_id': '8230322',
#      'value_struct': None,
#      'name': 'Modelo',
#      'value_name': 'iPhone SE (2nd Generation)',
#      'values': [{'id': '8230322',
#        'name': 'iPhone SE (2nd Generation)',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15591337',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1548895261',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 128 Gb Ouro Rosa 2 Gb Ram',
#    'seller': {'id': 78613217,
#     'permalink': 'http://perfil.mercadolivre.com.br/DIAMANTINASHOP',
#     'registration_date': '2005-02-09T06:31:05.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 440,
#       'canceled': 40,
#       'period': 'historic',
#       'ratings': {'negative': 0.01, 'positive': 0.99, 'neutral': 0},
#       'completed': 400},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.039, 'value': 10, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0167,
#        'value': 4,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 230},
#       'cancellations': {'rate': 0, 'value': 1, 'period': '3 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '46900000',
#      'address': 'RUA PIO XII 368',
#      'state': 'BR-BA',
#      'city': 'Seabra'}},
#    'price': 2850,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-05-31T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-128-gb-ouro-rosa-2-gb-ram/p/MLB6127580',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/819171-MLA31347280256_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 270.73,
#     'rate': 13.99,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-BA',
#     'state_name': 'Bahia',
#     'city_id': 'TUxCQ1NFQThhYjM',
#     'city_name': 'Seabra'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-BA', 'name': 'Bahia'},
#     'city': {'id': 'TUxCQ1NFQThhYjM', 'name': 'Seabra'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'id': 'BRAND',
#      'name': 'Marca'},
#     {'name': 'Modelo de GPU',
#      'value_id': '8094621',
#      'value_name': 'PowerVR GT7600',
#      'value_struct': None,
#      'values': [{'id': '8094621',
#        'name': 'PowerVR GT7600',
#        'struct': None,
#        'source': 1}],
#      'id': 'GPU_MODEL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'source': 2860837171021627,
#      'id': 'ITEM_CONDITION',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284'},
#     {'id': 'LINE',
#      'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'source': 1,
#      'name': 'Modelo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}],
#      'id': 'MODEL',
#      'value_id': '312151',
#      'value_name': 'iPhone 6s'},
#     {'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '6973026',
#      'value_name': 'Apple A9',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Peso',
#      'value_id': '522899',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_struct': {'number': 143, 'unit': 'g'},
#      'values': [{'source': 1,
#        'id': '522899',
#        'name': '143 g',
#        'struct': {'number': 143, 'unit': 'g'}}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': '143 g'}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6127580',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1622334438',
#    'site_id': 'MLB',
#    'title': 'iPhone 8 256 Gb Prata 2 Gb Ram',
#    'seller': {'id': 336592499,
#     'permalink': 'http://perfil.mercadolivre.com.br/SICE+DIGITAL',
#     'registration_date': '2018-07-14T07:33:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1235,
#       'canceled': 139,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.96, 'neutral': 0.01},
#       'completed': 1096},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0217, 'value': 26, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0018,
#        'value': 2,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1062},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13097158',
#      'address': 'Rua João de Barro SN',
#      'state': 'BR-SP',
#      'city': 'Campinas'}},
#    'price': 3499.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 1,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-03T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-8-256-gb-prata-2-gb-ram/p/MLB8752434',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/694892-MLA42533131046_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 291.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_id': 'OTHERS',
#      'value_id': '9344',
#      'value_struct': None,
#      'value_name': 'Apple',
#      'values': [{'source': 1, 'id': '9344', 'name': 'Apple', 'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca'},
#     {'id': 'ITEM_CONDITION',
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627,
#        'id': '2230284'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 2860837171021627,
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}]},
#     {'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'value_name': 'iPhone 8',
#      'values': [{'name': 'iPhone 8',
#        'struct': None,
#        'source': 1,
#        'id': '2244670'}],
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_id': '2244670',
#      'value_struct': None},
#     {'value_name': 'Apple A11 Bionic',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '6936434',
#      'value_struct': None},
#     {'name': 'Peso',
#      'value_id': '6861161',
#      'value_name': '148 g',
#      'attribute_group_id': 'OTHERS',
#      'id': 'WEIGHT',
#      'value_struct': {'number': 148, 'unit': 'g'},
#      'values': [{'source': 1,
#        'id': '6861161',
#        'name': '148 g',
#        'struct': {'number': 148, 'unit': 'g'}}],
#      'attribute_group_name': 'Outros',
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752434',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1560352635',
#    'site_id': 'MLB',
#    'title': 'iPhone XS Max 512 Gb Ouro 4 Gb Ram',
#    'seller': {'id': 147172848,
#     'permalink': 'http://perfil.mercadolivre.com.br/FIVENDASONLINE',
#     'registration_date': '2013-10-08T22:59:50.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 11661,
#       'canceled': 714,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.94, 'neutral': 0.03},
#       'completed': 10947},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0206, 'value': 40, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0693,
#        'value': 114,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1734},
#       'cancellations': {'rate': 0.0051, 'value': 10, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '03572340',
#      'address': 'José Da Costa De Andrade 105',
#      'state': 'BR-SP',
#      'city': 'São Paulo'}},
#    'price': 7199,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-06-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-max-512-gb-ouro-4-gb-ram/p/MLB12866634',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/864619-MLA42092921659_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 599.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Apple',
#      'value_struct': None,
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}]},
#     {'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799,
#      'value_id': '2230284',
#      'value_name': 'Novo'},
#     {'value_id': '58993',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '5414168',
#        'name': 'iPhone XS Max'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '5414168',
#      'value_name': 'iPhone XS Max',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'value_id': '6927771',
#      'value_name': 'Apple A12 Bionic',
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866634',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1629045107',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 32 Gb Prata 2 Gb Ram',
#    'seller': {'id': 227936319,
#     'permalink': 'http://perfil.mercadolivre.com.br/OUTLET-IMPORTADOS',
#     'registration_date': '2016-09-09T19:42:39.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 607,
#       'canceled': 51,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.95, 'neutral': 0.03},
#       'completed': 556},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.053, 'value': 29, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0384,
#        'value': 20,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 503},
#       'cancellations': {'rate': 0, 'value': 2, 'period': '3 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '08411470',
#      'address': 'Rua Macabu 241',
#      'state': 'BR-SP',
#      'city': 'São Paulo'}},
#    'price': 5000,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-32-gb-prata-2-gb-ram/p/MLB6282513',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/831527-MLA31347985627_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 416.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_id': '8094621',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8094621',
#        'name': 'PowerVR GT7600'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': 'PowerVR GT7600',
#      'value_struct': None},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 7092,
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 7092}]},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}]},
#     {'value_name': 'iPhone 6s',
#      'value_struct': None,
#      'id': 'MODEL',
#      'value_id': '312151',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}]},
#     {'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_id': '6973026',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A9'},
#     {'name': 'Peso',
#      'value_id': '522899',
#      'value_name': '143 g',
#      'value_struct': {'number': 143, 'unit': 'g'},
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'WEIGHT',
#      'attribute_group_name': 'Outros',
#      'values': [{'source': 1,
#        'id': '522899',
#        'name': '143 g',
#        'struct': {'number': 143, 'unit': 'g'}}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6282513',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1621676696',
#    'site_id': 'MLB',
#    'title': 'iPhone XS Dual Sim 256 Gb Ouro 4 Gb Ram',
#    'seller': {'id': 114128462,
#     'permalink': 'http://perfil.mercadolivre.com.br/MIAMISTORE+OFICIAL',
#     'registration_date': '2012-05-31T11:40:16.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'credits_profile',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 38634,
#       'canceled': 658,
#       'period': 'historic',
#       'ratings': {'negative': 0.04, 'positive': 0.92, 'neutral': 0.04},
#       'completed': 37976},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0228, 'value': 67, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0793,
#        'value': 141,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 2746},
#       'cancellations': {'rate': 0.0102, 'value': 30, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13076040',
#      'address': 'Rua Castro Alves 508',
#      'state': 'BR-SP',
#      'city': 'Campinas'}},
#    'price': 6239.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-02T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-dual-sim-256-gb-ouro-4-gb-ram/p/MLB12866589',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/877935-MLA33003199447_112019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 520,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_struct': None,
#      'values': [{'source': 1, 'id': '9344', 'name': 'Apple', 'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': 'Novo',
#      'source': 1},
#     {'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'attribute_group_name': 'Outros',
#      'value_id': '58993',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'values': [{'id': '5414092',
#        'name': 'iPhone XS Dual SIM',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '5414092',
#      'value_name': 'iPhone XS Dual SIM',
#      'value_struct': None,
#      'source': 1},
#     {'id': 'PROCESSOR_MODEL',
#      'value_struct': None,
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'name': 'Modelo do processador',
#      'value_id': '6927771',
#      'value_name': 'Apple A12 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 1087,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866589',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1563190467',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 16 Gb Ouro 2 Gb Ram',
#    'seller': {'id': 336592499,
#     'permalink': 'http://perfil.mercadolivre.com.br/SICE+DIGITAL',
#     'registration_date': '2018-07-14T07:33:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1235,
#       'canceled': 139,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.96, 'neutral': 0.01},
#       'completed': 1096},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0217, 'value': 26, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0018,
#        'value': 2,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1062},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13097158',
#      'address': 'Rua João de Barro SN',
#      'state': 'BR-SP',
#      'city': 'Campinas'}},
#    'price': 1849.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 2,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-06-13T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-16-gb-ouro-2-gb-ram/p/MLB6127571',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/846101-MLA31347280220_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 154.17,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_name': 'Apple',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '9344'},
#     {'value_id': '8094621',
#      'value_name': 'PowerVR GT7600',
#      'values': [{'id': '8094621',
#        'name': 'PowerVR GT7600',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_struct': None,
#      'source': 1},
#     {'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_name': 'Outros',
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_struct': None,
#      'attribute_group_name': 'Outros'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'value_id': '312151',
#      'value_name': 'iPhone 6s',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_id': '6973026',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '6973026',
#        'name': 'Apple A9'}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6127571',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1625322844',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s Plus 128 Gb Cinza-espacial 2 Gb Ram',
#    'seller': {'id': 110706143,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 3080,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-07T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-plus-128-gb-cinza-espacial-2-gb-ram/p/MLB6143816',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/884567-MLA31347186400_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 256.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'attribute_group_name': 'Outros',
#      'source': 1505,
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1505}],
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item'},
#     {'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
# ...
#        'id': '58993',
#        'name': 'iPhone'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'value_name': 'iPhone',
#      'value_struct': None},
#     {'values': [{'id': '2244673',
#        'name': 'iPhone 8 Plus',
#        'struct': None,
#        'source': 6587939990796619}],
#      'attribute_group_id': 'OTHERS',
#      'value_id': '2244673',
#      'value_name': 'iPhone 8 Plus',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'id': 'MODEL',
#      'name': 'Modelo'},
#     {'value_name': 'Apple A11 Bionic',
#      'value_struct': None,
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 6587939990796619}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '6936434',
#      'source': 6587939990796619},
#     {'id': 'WEIGHT',
#      'values': [{'id': '2263677',
#        'name': '202 g',
#        'struct': {'number': 202, 'unit': 'g'},
#        'source': 6587939990796619}],
#      'attribute_group_name': 'Outros',
#      'attribute_group_id': 'OTHERS',
#      'source': 6587939990796619,
#      'name': 'Peso',
#      'value_id': '2263677',
#      'value_name': '202 g',
#      'value_struct': {'number': 202, 'unit': 'g'}}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752450',
#    'tags': ['brand_verified',
#     'catalog_listing_eligible',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible']},
#   {'id': 'MLB1374360266',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 Pro Verde 5,8  4g 64gb Câm 12mp - Mwc62bz/a',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 281817,
#       'canceled': 11829,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 269988},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0235,
#        'value': 1546,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 60721},
#       'cancellations': {'rate': 0.0103, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 6226.64,
#    'currency_id': 'BRL',
#    'available_quantity': 250,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-11-22T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://produto.mercadolivre.com.br/MLB-1374360266-iphone-11-pro-verde-58-4g-64gb-cm-12mp-mwc62bza-_JM',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/968069-MLB42057606288_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 518.89,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 4060709329251625}],
#      'source': 4060709329251625,
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Modelo de GPU',
#      'value_id': '7741027',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'id': 'GPU_MODEL',
#      'value_name': 'Apple GPU',
#      'value_struct': None,
#      'values': [{'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None,
#        'source': 4709228965570453}]},
#     {'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}]},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 3942444344910321,
#        'id': '58993'}],
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'source': 3942444344910321,
#      'id': 'LINE',
#      'value_id': '58993'},
#     {'value_name': 'iPhone 11 Pro',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 3942444344910321,
#      'id': 'MODEL',
#      'value_id': '7741023',
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo',
#      'values': [{'id': '7741023',
#        'name': 'iPhone 11 Pro',
#        'struct': None,
#        'source': 3942444344910321}]},
#     {'values': [{'struct': None,
#        'source': 4709228965570453,
#        'id': '7740540',
#        'name': 'Apple A13 Bionic'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '7740540',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A13 Bionic',
#      'value_struct': None,
#      'source': 4709228965570453,
#      'id': 'PROCESSOR_MODEL'},
#     {'id': 'WEIGHT',
#      'value_id': '522900',
#      'value_name': '188 g',
#      'attribute_group_name': 'Outros',
#      'source': 3942444344910321,
#      'name': 'Peso',
#      'value_struct': {'number': 188, 'unit': 'g'},
#      'values': [{'struct': {'number': 188, 'unit': 'g'},
#        'source': 3942444344910321,
#        'id': '522900',
#        'name': '188 g'}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15150711',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed']}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB1055',
#      'name': 'Celulares e Smartphones',
#      'path_from_root': [{'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#       {'id': 'MLB1055', 'name': 'Celulares e Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'type': 'STRING',
#    'values': [{'id': '58993', 'name': 'iPhone'}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as Lojas oficiais', 'results': 198},
#     {'id': '942', 'name': 'Fast Shop', 'results': 65},
#     {'id': '817', 'name': 'COMMCENTER', 'results': 10},
#     {'id': '2162', 'name': 'Apple', 'results': 26},
#     {'id': '2945', 'name': 'Trocafone', 'results': 76}]},
#   {'id': 'discount',
#    'name': 'Descontos',
#    'type': 'range',
#    'values': [{'id': '10-100', 'name': 'Mais de 10% off', 'results': 11},
#     {'id': '20-100', 'name': 'Mais de 20% off', 'results': 9}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4',
#      'name': 'São Paulo',
#      'results': 10734},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 2143},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 2128},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 1152},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 939},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 886},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 831},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 642},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 585},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 399},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 328},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 318},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 198},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 183},
#     {'id': 'TUxCUE1BUk81MWVi', 'name': 'Maranhão', 'results': 147},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 129},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 126},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 105},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 99},
#     {'id': 'TUxCUFBJQUk1NDVj', 'name': 'Piauí', 'results': 81},
#     {'id': 'TUxCUFBBUkE0M2I4', 'name': 'Paraíba', 'results': 78},
#     {'id': 'TUxCUFNFUkUxMmZlOQ', 'name': 'Sergipe', 'results': 75},
#     {'id': 'TUxCUFJPTkExMmU4YQ', 'name': 'Rondônia', 'results': 63},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 39},
#     {'id': 'TUxCUEFNQUExNTZlNg', 'name': 'Amapá', 'results': 24},
#     {'id': 'TUxCUFJPUkExODBiMQ', 'name': 'Roraima', 'results': 24},
#     {'id': 'TUxCUEFDUkVkNTU', 'name': 'Acre', 'results': 21}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-1000.0', 'name': 'Até R$1.000', 'results': 6529},
#     {'id': '1000.0-2000.0', 'name': 'R$1.000 a R$2.000', 'results': 6818},
#     {'id': '2000.0-*', 'name': 'Mais de R$2.000', 'results': 9331}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com MercadoPago', 'results': 22678}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'no_interest', 'name': 'Sem juros', 'results': 4539}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 22505},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 11}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 362}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 714}]},
#   {'id': 'until',
#    'name': 'Filtro por data do fim',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Termina hoje', 'results': 153}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicações com vídeo',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Publicações com vídeo', 'results': 508}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 22579}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 10035}]},
#   {'id': 'shipping_quarantine',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'guaranteed_delivery',
#      'name': 'Enviando normalmente',
#      'results': 489}]},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'results': 19017},
#     {'id': '298332', 'name': 'Vivo', 'results': 429},
#     {'id': '298334', 'name': 'TIM', 'results': 183},
#     {'id': '298333', 'name': 'Claro', 'results': 183},
#     {'id': '298331', 'name': 'Oi', 'results': 141},
#     {'id': '303172', 'name': 'Nextel', 'results': 48}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'type': 'range',
#    'values': [{'id': '(*-32GB)', 'name': 'Menos de 32 GB', 'results': 5844},
#     {'id': '[32GB-64GB)', 'name': '32 a 63 GB', 'results': 4710},
#     {'id': '[64GB-128GB)', 'name': '64 a 127 GB', 'results': 6492},
#     {'id': '[128GB-256GB)', 'name': '128 a 255 GB', 'results': 3495},
#     {'id': '[256GB-*)', 'name': '256 GB ou mais', 'results': 2211}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'É Dual SIM', 'results': 936}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 19212},
#     {'id': '2230284', 'name': 'Novo', 'results': 3477},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 168}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '312155', 'name': 'iPhone 7', 'results': 3717},
#     {'id': '312151', 'name': 'iPhone 6s', 'results': 2622},
#     {'id': '312149', 'name': 'iPhone 6', 'results': 1887},
#     {'id': '312144', 'name': 'iPhone 5s', 'results': 1839},
#     {'id': '2244670', 'name': 'iPhone 8', 'results': 1542},
#     {'id': '312157', 'name': 'iPhone 7 Plus', 'results': 1347},
#     {'id': '2244673', 'name': 'iPhone 8 Plus', 'results': 1185},
#     {'id': '1164456', 'name': 'iPhone X', 'results': 1158},
#     {'id': '312154', 'name': 'iPhone SE', 'results': 816},
#     {'id': '312145', 'name': 'iPhone 4s', 'results': 717},
#     {'id': '312152', 'name': 'iPhone 5', 'results': 636},
#     {'id': '5414260', 'name': 'iPhone XR', 'results': 606},
#     {'id': '5414168', 'name': 'iPhone XS Max', 'results': 453},
#     {'id': '312143', 'name': 'iPhone 5c', 'results': 435},
#     {'id': '14610', 'name': 'iPhone 4', 'results': 417},
#     {'id': '7739079', 'name': 'iPhone 11', 'results': 405},
#     {'id': '312153', 'name': 'iPhone 6s Plus', 'results': 405},
#     {'id': '312150', 'name': 'iPhone 6 Plus', 'results': 390},
#     {'id': '14608', 'name': 'iPhone', 'results': 381},
#     {'id': '5414079', 'name': 'iPhone XS', 'results': 306},
#     {'id': '7741677', 'name': 'iPhone 11 Pro Max', 'results': 273},
#     {'id': '7741023', 'name': 'iPhone 11 Pro', 'results': 156},
#     {'id': '14609', 'name': 'iPhone 3GS', 'results': 120},
#     {'id': '5414092', 'name': 'iPhone XS Dual SIM', 'results': 111},
#     {'id': '8230322', 'name': 'iPhone SE (2nd Generation)', 'results': 48},
#     {'id': '14605', 'name': 'iPhone 3G', 'results': 39},
#     {'id': '5729', 'name': 'XS', 'results': 21},
#     {'id': '4904058', 'name': '8 Plus', 'results': 21},
#     {'id': '27251', 'name': '7', 'results': 21},
#     {'id': '31998', 'name': 'X', 'results': 15},
#     {'id': '58458', 'name': '4S', 'results': 12},
#     {'id': '52828', 'name': '7 Plus', 'results': 12},
#     {'id': '59833', 'name': '6', 'results': 9},
#     {'id': '59000', 'name': '5s', 'results': 9},
#     {'id': '58054', 'name': 'XR', 'results': 9}]},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com reconhecimento facial',
#      'results': 2625}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com leitor de impressão digital',
#      'results': 15969}]}]}

# %%
temp = busca('iphone')

# %%
temp
# Out:
# {'site_id': 'MLB',
#  'query': 'iphone',
#  'paging': {'total': 22719, 'offset': 0, 'limit': 50, 'primary_results': 1039},
#  'results': [{'id': 'MLB1513918236',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 64 Gb Preto 4 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 281817,
#       'canceled': 11829,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 269988},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0235,
#        'value': 1546,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 60721},
#       'cancellations': {'rate': 0.0103, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 4875.89,
#    'currency_id': 'BRL',
#    'available_quantity': 250,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-04-30T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-11-64-gb-preto-4-gb-ram/p/MLB15149561',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/890754-MLA42453930736_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 406.32,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'value_id': '7740544',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '7740544',
#        'name': 'Apple GPU MP4'}],
#      'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU MP4'},
#     {'source': 1,
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'id': 'ITEM_CONDITION',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros'},
#     {'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'source': 1},
#     {'value_id': '7739079',
#      'value_name': 'iPhone 11',
#      'attribute_group_id': 'OTHERS',
#      'source': 4709228965570453,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A13 Bionic',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540'},
#     {'value_struct': {'number': 194, 'unit': 'g'},
#      'values': [{'id': '2583040',
#        'name': '194 g',
#        'struct': {'number': 194, 'unit': 'g'},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '2583040',
#      'value_name': '194 g',
#      'attribute_group_name': 'Outros',
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149561',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1638935509',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 128 Gb Preto 4 Gb Ram',
#    'seller': {'id': 259411419,
#     'permalink': 'http://perfil.mercadolivre.com.br/MINAS_PHONE',
#     'registration_date': '2017-06-05T11:06:25.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1266,
#       'canceled': 141,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.98, 'neutral': 0},
#       'completed': 1125},
#      'power_seller_status': 'gold',
#      'metrics': {'claims': {'rate': 0,
#        'excluded': {'real_rate': 0.0181, 'real_value': 23},
#        'value': 0,
#        'period': '60 months'},
#       'delayed_handling_time': {'rate': 0,
#        'excluded': {'real_rate': 0.0191, 'real_value': 20},
#        'value': 0,
#        'period': '60 months'},
#       'sales': {'period': '60 months', 'completed': 1125},
#       'cancellations': {'rate': 0,
#        'excluded': {'real_rate': 0.0142, 'real_value': 18},
#        'value': 0,
#        'period': '60 months'}},
#      'protection_end_date': '2020-09-22T00:00:00.000-04:00',
#      'real_level': 'green',
#      'level_id': '5_green'},
#     'address': {'zip_code': '37115000',
#      'address': 'Avenida Jorge Vieira 35',
#      'state': 'BR-MG',
#      'city': 'Monte Belo'}},
#    'price': 5050,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-21T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-11-128-gb-preto-4-gb-ram/p/MLB15149567',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/678481-MLA42453875909_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 420.83,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-MG',
#     'state_name': 'Minas Gerais',
#     'city_id': 'TUxCQ01PTjE2OWFh',
#     'city_name': 'Monte Belo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-MG', 'name': 'Minas Gerais'},
#     'city': {'id': 'TUxCQ01PTjE2OWFh', 'name': 'Monte Belo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'struct': None,
#        'source': 1,
#        'id': '9344',
#        'name': 'Apple'}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'name': 'Marca',
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_id': '7740544',
#      'value_name': 'Apple GPU MP4',
#      'source': 1,
#      'value_struct': None,
#      'values': [{'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_struct': None,
#      'source': 7092,
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 7092}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '7739079',
#      'value_name': 'iPhone 11',
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_struct': None},
#     {'attribute_group_id': 'OTHERS',
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'values': [{'source': 1,
#        'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A13 Bionic',
#      'value_struct': None},
#     {'name': 'Peso',
#      'value_id': '2583040',
#      'value_struct': {'number': 194, 'unit': 'g'},
#      'values': [{'id': '2583040',
#        'name': '194 g',
#        'struct': {'number': 194, 'unit': 'g'},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'value_name': '194 g',
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149567',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1507604525',
#    'site_id': 'MLB',
#    'title': 'iPhone 7 32 Gb Preto-fosco 2 Gb Ram',
#    'seller': {'id': 336592499,
#     'permalink': 'http://perfil.mercadolivre.com.br/SICE+DIGITAL',
#     'registration_date': '2018-07-14T07:33:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1235,
#       'canceled': 139,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.96, 'neutral': 0.01},
#       'completed': 1096},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0217, 'value': 26, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0018,
#        'value': 2,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1062},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13097158',
#      'address': 'Rua João de Barro SN',
#      'state': 'BR-SP',
#      'city': 'Campinas'}},
#    'price': 2290.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 25,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-06-27T12:41:49.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-7-32-gb-preto-fosco-2-gb-ram/p/MLB6240116',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/760443-MLA31347321894_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 190.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'id': 'GPU_MODEL',
#      'value_id': '8010379',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8010379',
#        'name': 'PowerVR Series7XT Plus'}]},
#     {'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799,
#        'id': '2230284'}],
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799},
#     {'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'value_id': '58993',
#      'source': 1},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '312155',
#      'values': [{'id': '312155',
#        'name': 'iPhone 7',
#        'struct': None,
#        'source': 1}],
#      'value_name': 'iPhone 7',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Modelo do processador',
#      'value_id': '6946002',
#      'values': [{'id': '6946002',
#        'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A10 Fusion',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Peso',
#      'value_struct': {'number': 138, 'unit': 'g'},
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_id': '522902',
#      'value_name': '138 g',
#      'values': [{'id': '522902',
#        'name': '138 g',
#        'struct': {'unit': 'g', 'number': 138},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6240116',
#    'tags': ['good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1348930369',
#    'site_id': 'MLB',
#    'title': 'iPhone XR 64 Gb Preto 3 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 281817,
#       'canceled': 11829,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 269988},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0235,
#        'value': 1546,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 60721},
#       'cancellations': {'rate': 0.0103, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 3399,
#    'currency_id': 'BRL',
#    'available_quantity': 250,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-10-19T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xr-64-gb-preto-3-gb-ram/p/MLB12866681',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/644351-MLA42521114301_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 283.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_struct': None,
#      'attribute_group_name': 'Outros'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_struct': None,
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_id': '58993',
#      'attribute_group_id': 'OTHERS',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone'},
#     {'attribute_group_name': 'Outros',
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo',
#      'value_id': '5414260',
#      'value_name': 'iPhone XR',
#      'value_struct': None,
#      'values': [{'source': 4709228965570453,
#        'id': '5414260',
#        'name': 'iPhone XR',
#        'struct': None}],
#      'source': 4709228965570453,
#      'id': 'MODEL'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A12 Bionic',
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'value_id': '6927771',
#      'value_struct': None,
#      'source': 1},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '2583040',
#      'value_name': '194 g',
#      'value_struct': {'unit': 'g', 'number': 194},
#      'values': [{'id': '2583040',
#        'name': '194 g',
#        'struct': {'number': 194, 'unit': 'g'},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 4499.9,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866681',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1488721028',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 64 Gb Cinza-espacial 2 Gb Ram',
#    'seller': {'id': 61843260,
#     'permalink': 'http://perfil.mercadolivre.com.br/UAIPLACEBH',
#     'registration_date': '2008-12-06T08:42:58.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 318,
#       'canceled': 21,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 0.98, 'neutral': 0.02},
#       'completed': 297},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0157, 'value': 5, 'period': '60 months'},
#       'delayed_handling_time': {'rate': 0.1541,
#        'value': 37,
#        'period': '60 months'},
#       'sales': {'period': '60 months', 'completed': 297},
#       'cancellations': {'rate': 0.0345, 'value': 11, 'period': '60 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '30492025',
#      'address': 'Rua Professora Bartira Mourao 710',
#      'state': 'BR-MG',
#      'city': 'Belo Horizonte'}},
#    'price': 2418,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-03-30T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-64-gb-cinza-espacial-2-gb-ram/p/MLB6127573',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/818969-MLA31347186317_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 201.5,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-MG',
#     'state_name': 'Minas Gerais',
#     'city_id': 'TUxCQ0JFTGU0ODdm',
#     'city_name': 'Belo Horizonte'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-MG', 'name': 'Minas Gerais'},
#     'city': {'id': 'TUxCQ0JFTGU0ODdm', 'name': 'Belo Horizonte'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_name': 'Outros',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'source': 1},
#     {'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '8094621',
#      'value_struct': None,
#      'values': [{'id': '8094621',
#        'name': 'PowerVR GT7600',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'PowerVR GT7600'},
#     {'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 7092}],
#      'source': 7092,
#      'value_id': '2230284',
#      'value_struct': None},
#     {'id': 'LINE',
#      'value_name': 'iPhone',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Modelo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'MODEL',
#      'value_name': 'iPhone 6s',
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}],
#      'value_id': '312151'},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A9',
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo do processador',
#      'value_id': '6973026',
#      'value_struct': None}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6127573',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1629070761',
#    'site_id': 'MLB',
#    'title': 'iPhone 8 Plus 64 Gb Ouro 3 Gb Ram',
#    'seller': {'id': 326379758,
#     'permalink': 'http://perfil.mercadolivre.com.br/GRESTELAR',
#     'registration_date': '2018-06-06T00:36:19.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'eshop', 'messages_as_seller', 'messages_as_buyer'],
#     'eshop': {'nick_name': 'GRESTELAR',
#      'eshop_rubro': None,
#      'eshop_id': 408182,
#      'eshop_locations': [],
#      'site_id': 'MLB',
#      'eshop_logo_url': 'http://resources.mlstatic.com/eshops/326379758v39e366.png',
#      'eshop_status_id': 1,
#      'seller': 326379758,
#      'eshop_experience': 0},
#     'seller_reputation': {'transactions': {'total': 4613,
#       'canceled': 439,
#       'period': 'historic',
#       'ratings': {'negative': 0.09, 'positive': 0.87, 'neutral': 0.04},
#       'completed': 4174},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0,
#        'excluded': {'real_rate': 0.0539, 'real_value': 75},
#        'value': 0,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0,
#        'excluded': {'real_rate': 0.0119, 'real_value': 15},
#        'value': 0,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1258},
#       'cancellations': {'rate': 0,
#        'excluded': {'real_rate': 0.0179, 'real_value': 25},
#        'value': 0,
#        'period': '3 months'}},
#      'protection_end_date': '2020-09-22T00:00:00.000-04:00',
#      'real_level': 'yellow',
#      'level_id': '5_green'},
#     'address': {'zip_code': '03304000',
#      'address': 'Rua São Bernardo 33',
#      'state': 'BR-SP',
#      'city': 'São Paulo'}},
#    'price': 4010,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-8-plus-64-gb-ouro-3-gb-ram/p/MLB8752451',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/988474-MLA42532404843_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 334.17,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['self_service_out', 'mandatory_free_shipping'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'source': 1, 'id': '9344', 'name': 'Apple', 'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_id': '2230284',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 7092}],
#      'attribute_group_name': 'Outros',
#      'source': 7092},
#     {'id': 'LINE',
#      'source': 1,
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'values': [{'id': '2244673',
#        'name': 'iPhone 8 Plus',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'value_name': 'iPhone 8 Plus',
#      'value_struct': None,
#      'name': 'Modelo',
#      'value_id': '2244673',
#      'attribute_group_name': 'Outros'},
#     {'value_id': '6936434',
#      'value_name': 'Apple A11 Bionic',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Peso',
#      'value_name': '202 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_id': '2263677',
#      'value_struct': {'number': 202, 'unit': 'g'},
#      'values': [{'source': 1,
#        'id': '2263677',
#        'name': '202 g',
#        'struct': {'number': 202, 'unit': 'g'}}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752451',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1336245573',
#    'site_id': 'MLB',
#    'title': 'iPhone XR 128 Gb Preto 3 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 281817,
#       'canceled': 11829,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 269988},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0235,
#        'value': 1546,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 60721},
#       'cancellations': {'rate': 0.0103, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 3799,
#    'currency_id': 'BRL',
#    'available_quantity': 100,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-10-03T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xr-128-gb-preto-3-gb-ram/p/MLB12866686',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/821692-MLA42521114318_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 316.58,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_id': 'OTHERS',
#      'value_id': '9344',
#      'value_struct': None,
#      'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '2230284',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}]},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'value_name': 'iPhone',
#      'value_struct': None},
#     {'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'id': '5414260',
#        'name': 'iPhone XR',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'id': 'MODEL',
#      'value_id': '5414260',
#      'value_name': 'iPhone XR'},
#     {'name': 'Modelo do processador',
#      'value_name': 'Apple A12 Bionic',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '6927771',
#      'values': [{'source': 1,
#        'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None}]},
#     {'value_struct': {'number': 194, 'unit': 'g'},
#      'source': 1,
#      'value_id': '2583040',
#      'value_name': '194 g',
#      'values': [{'id': '2583040',
#        'name': '194 g',
#        'struct': {'number': 194, 'unit': 'g'},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'name': 'Peso'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 4999.9,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866686',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1482772364',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 Pro Max 256 Gb Cinza-espacial 4 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 281817,
#       'canceled': 11829,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 269988},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0235,
#        'value': 1546,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 60721},
#       'cancellations': {'rate': 0.0103, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 6999,
#    'currency_id': 'BRL',
#    'available_quantity': 250,
#    'sold_quantity': 200,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-03-25T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-11-pro-max-256-gb-cinza-espacial-4-gb-ram/p/MLB15150977',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/839025-MLA42456810904_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 583.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'value_struct': None,
#      'values': [{'source': 1,
#        'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU',
#      'id': 'GPU_MODEL',
#      'value_id': '7741027'},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 1,
#        'id': '2230284'}]},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'value_struct': None,
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Linha',
#      'value_id': '58993'},
#     {'value_name': 'iPhone 11 Pro Max',
#      'values': [{'id': '7741677',
#        'name': 'iPhone 11 Pro Max',
#        'struct': None,
#        'source': 1}],
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '7741677',
#      'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'value_name': 'Apple A13 Bionic',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '7740540'},
#     {'name': 'Peso',
#      'value_struct': {'number': 226, 'unit': 'g'},
#      'values': [{'id': '2713650',
#        'name': '226 g',
#        'struct': {'unit': 'g', 'number': 226},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_name': '226 g',
#      'value_id': '2713650'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 9099.9,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15150977',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1478161027',
#    'site_id': 'MLB',
#    'title': 'iPhone XS 512 Gb Prata 4 Gb Ram',
#    'seller': {'id': 516491031,
#     'permalink': 'http://perfil.mercadolivre.com.br/COMMCENTER2',
#     'registration_date': '2020-01-20T13:40:19.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand', 'large_seller', 'messages_as_seller'],
#     'seller_reputation': {'transactions': {'total': 6914,
#       'canceled': 653,
#       'period': 'historic',
#       'ratings': {'negative': 0.05, 'positive': 0.92, 'neutral': 0.03},
#       'completed': 6261},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.012, 'value': 48, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0634,
#        'value': 232,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 3603},
#       'cancellations': {'rate': 0.0017, 'value': 7, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '29161384',
#      'address': 'Avenida Cem SN',
#      'state': 'BR-ES',
#      'city': 'Serra'}},
#    'price': 9099,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-03-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-512-gb-prata-4-gb-ram/p/MLB12866571',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/906231-MLA31348110392_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 864.33,
#     'rate': 13.99,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-ES',
#     'state_name': 'Espírito Santo',
#     'city_id': 'TUxCQ1NFUmI1ZGQx',
#     'city_name': 'Serra'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-ES', 'name': 'Espírito Santo'},
#     'city': {'id': 'TUxCQ1NFUmI1ZGQx', 'name': 'Serra'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_struct': None,
#      'values': [{'source': 1, 'id': '9344', 'name': 'Apple', 'struct': None}]},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'source': 1,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None},
#     {'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'attribute_group_name': 'Outros',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'attribute_group_id': 'OTHERS',
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '5414079',
#      'value_name': 'iPhone XS',
#      'value_struct': None,
#      'values': [{'id': '5414079',
#        'name': 'iPhone XS',
#        'struct': None,
#        'source': 1}]},
#     {'value_name': 'Apple A12 Bionic',
#      'value_struct': None,
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '6927771',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '6927771',
#        'name': 'Apple A12 Bionic'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 817,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866571',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1478189989',
#    'site_id': 'MLB',
#    'title': 'iPhone XS 256 Gb Prata 4 Gb Ram',
#    'seller': {'id': 516491031,
#     'permalink': 'http://perfil.mercadolivre.com.br/COMMCENTER2',
#     'registration_date': '2020-01-20T13:40:19.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand', 'large_seller', 'messages_as_seller'],
#     'seller_reputation': {'transactions': {'total': 6914,
#       'canceled': 653,
#       'period': 'historic',
#       'ratings': {'negative': 0.05, 'positive': 0.92, 'neutral': 0.03},
#       'completed': 6261},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.012, 'value': 48, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0634,
#        'value': 232,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 3603},
#       'cancellations': {'rate': 0.0017, 'value': 7, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '29161384',
#      'address': 'Avenida Cem SN',
#      'state': 'BR-ES',
#      'city': 'Serra'}},
#    'price': 7699,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-03-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-256-gb-prata-4-gb-ram/p/MLB12866568',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/701623-MLA31348461024_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 641.58,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-ES',
#     'state_name': 'Espírito Santo',
#     'city_id': 'TUxCQ1NFUmI1ZGQx',
#     'city_name': 'Serra'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-ES', 'name': 'Espírito Santo'},
#     'city': {'id': 'TUxCQ1NFUmI1ZGQx', 'name': 'Serra'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344'},
#     {'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'source': 1},
#     {'name': 'Linha',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_name': 'iPhone XS',
#      'value_struct': None,
#      'values': [{'id': '5414079',
# ...
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1572}],
#      'attribute_group_name': 'Outros',
#      'attribute_group_id': 'OTHERS',
#      'source': 1572},
#     {'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'source': 1,
#      'id': 'LINE'},
#     {'id': 'MODEL',
#      'value_name': 'iPhone 6s',
#      'value_struct': None,
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}],
#      'name': 'Modelo',
#      'value_id': '312151',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A9',
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1572}],
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo do processador',
#      'value_id': '6973026',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1572},
#     {'value_id': '522899',
#      'value_name': '143 g',
#      'value_struct': {'number': 143, 'unit': 'g'},
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'values': [{'id': '522899',
#        'name': '143 g',
#        'struct': {'number': 143, 'unit': 'g'},
#        'source': 6587939990796619}]}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6127568',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'brand_verified',
#     'catalog_listing_eligible',
#     'immediate_payment',
#     'cart_eligible']},
#   {'id': 'MLB1280952974',
#    'site_id': 'MLB',
#    'title': 'iPhone XR Preto,tela 6,1, 64 Gb, Câmera De 12 Mp - Mry42br/a',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 281817,
#       'canceled': 11829,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 269988},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0235,
#        'value': 1546,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 60721},
#       'cancellations': {'rate': 0.0103, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 3399,
#    'currency_id': 'BRL',
#    'available_quantity': 250,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-07-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://produto.mercadolivre.com.br/MLB-1280952974-iphone-xr-pretotela-61-64-gb-cmera-de-12-mp-mry42bra-_JM',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/875098-MLB42057579053_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 283.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'source': 4861189438295807,
#      'value_id': '9344',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 4861189438295807}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_name': 'Apple',
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'source': 1},
#     {'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1000427007642219}],
#      'source': 1000427007642219,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None},
#     {'source': 4861189438295807,
#      'name': 'Modelo',
#      'value_id': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'value_name': 'MRY42BR/A',
#      'value_struct': None,
#      'values': [{'source': 4861189438295807,
#        'id': None,
#        'name': 'MRY42BR/A',
#        'struct': None}]},
#     {'attribute_group_id': 'OTHERS',
#      'value_name': 'Apple A12 Bionic',
#      'value_struct': None,
#      'value_id': '6927771',
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador'},
#     {'value_name': '0.19 kg',
#      'values': [{'struct': {'number': 0.19, 'unit': 'kg'},
#        'source': 1183438784296846,
#        'id': None,
#        'name': '0.19 kg'}],
#      'source': 1183438784296846,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_struct': {'number': 0.19, 'unit': 'kg'},
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 4499.9,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866681',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed']}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB1055',
#      'name': 'Celulares e Smartphones',
#      'path_from_root': [{'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#       {'id': 'MLB1055', 'name': 'Celulares e Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'type': 'STRING',
#    'values': [{'id': '58993', 'name': 'iPhone'}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as Lojas oficiais', 'results': 198},
#     {'id': '942', 'name': 'Fast Shop', 'results': 65},
#     {'id': '817', 'name': 'COMMCENTER', 'results': 10},
#     {'id': '2162', 'name': 'Apple', 'results': 26},
#     {'id': '2945', 'name': 'Trocafone', 'results': 76}]},
#   {'id': 'discount',
#    'name': 'Descontos',
#    'type': 'range',
#    'values': [{'id': '10-100', 'name': 'Mais de 10% off', 'results': 11},
#     {'id': '20-100', 'name': 'Mais de 20% off', 'results': 9}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4',
#      'name': 'São Paulo',
#      'results': 10734},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 2143},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 2128},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 1152},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 939},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 886},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 831},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 642},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 585},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 399},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 328},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 318},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 198},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 183},
#     {'id': 'TUxCUE1BUk81MWVi', 'name': 'Maranhão', 'results': 147},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 129},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 126},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 105},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 99},
#     {'id': 'TUxCUFBJQUk1NDVj', 'name': 'Piauí', 'results': 81},
#     {'id': 'TUxCUFBBUkE0M2I4', 'name': 'Paraíba', 'results': 78},
#     {'id': 'TUxCUFNFUkUxMmZlOQ', 'name': 'Sergipe', 'results': 75},
#     {'id': 'TUxCUFJPTkExMmU4YQ', 'name': 'Rondônia', 'results': 63},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 39},
#     {'id': 'TUxCUEFNQUExNTZlNg', 'name': 'Amapá', 'results': 24},
#     {'id': 'TUxCUFJPUkExODBiMQ', 'name': 'Roraima', 'results': 24},
#     {'id': 'TUxCUEFDUkVkNTU', 'name': 'Acre', 'results': 21}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-1000.0', 'name': 'Até R$1.000', 'results': 6529},
#     {'id': '1000.0-2000.0', 'name': 'R$1.000 a R$2.000', 'results': 6818},
#     {'id': '2000.0-*', 'name': 'Mais de R$2.000', 'results': 9331}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com MercadoPago', 'results': 22678}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'no_interest', 'name': 'Sem juros', 'results': 4539}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 22505},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 11}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 362}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 714}]},
#   {'id': 'until',
#    'name': 'Filtro por data do fim',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Termina hoje', 'results': 153}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicações com vídeo',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Publicações com vídeo', 'results': 508}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 22579}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 10035}]},
#   {'id': 'shipping_quarantine',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'guaranteed_delivery',
#      'name': 'Enviando normalmente',
#      'results': 489}]},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'results': 19017},
#     {'id': '298332', 'name': 'Vivo', 'results': 429},
#     {'id': '298334', 'name': 'TIM', 'results': 183},
#     {'id': '298333', 'name': 'Claro', 'results': 183},
#     {'id': '298331', 'name': 'Oi', 'results': 141},
#     {'id': '303172', 'name': 'Nextel', 'results': 48}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'type': 'range',
#    'values': [{'id': '(*-32GB)', 'name': 'Menos de 32 GB', 'results': 5844},
#     {'id': '[32GB-64GB)', 'name': '32 a 63 GB', 'results': 4710},
#     {'id': '[64GB-128GB)', 'name': '64 a 127 GB', 'results': 6492},
#     {'id': '[128GB-256GB)', 'name': '128 a 255 GB', 'results': 3495},
#     {'id': '[256GB-*)', 'name': '256 GB ou mais', 'results': 2211}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'É Dual SIM', 'results': 936}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 19212},
#     {'id': '2230284', 'name': 'Novo', 'results': 3477},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 168}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '312155', 'name': 'iPhone 7', 'results': 3717},
#     {'id': '312151', 'name': 'iPhone 6s', 'results': 2622},
#     {'id': '312149', 'name': 'iPhone 6', 'results': 1887},
#     {'id': '312144', 'name': 'iPhone 5s', 'results': 1839},
#     {'id': '2244670', 'name': 'iPhone 8', 'results': 1542},
#     {'id': '312157', 'name': 'iPhone 7 Plus', 'results': 1347},
#     {'id': '2244673', 'name': 'iPhone 8 Plus', 'results': 1185},
#     {'id': '1164456', 'name': 'iPhone X', 'results': 1158},
#     {'id': '312154', 'name': 'iPhone SE', 'results': 816},
#     {'id': '312145', 'name': 'iPhone 4s', 'results': 717},
#     {'id': '312152', 'name': 'iPhone 5', 'results': 636},
#     {'id': '5414260', 'name': 'iPhone XR', 'results': 606},
#     {'id': '5414168', 'name': 'iPhone XS Max', 'results': 453},
#     {'id': '312143', 'name': 'iPhone 5c', 'results': 435},
#     {'id': '14610', 'name': 'iPhone 4', 'results': 417},
#     {'id': '7739079', 'name': 'iPhone 11', 'results': 405},
#     {'id': '312153', 'name': 'iPhone 6s Plus', 'results': 405},
#     {'id': '312150', 'name': 'iPhone 6 Plus', 'results': 390},
#     {'id': '14608', 'name': 'iPhone', 'results': 381},
#     {'id': '5414079', 'name': 'iPhone XS', 'results': 306},
#     {'id': '7741677', 'name': 'iPhone 11 Pro Max', 'results': 273},
#     {'id': '7741023', 'name': 'iPhone 11 Pro', 'results': 156},
#     {'id': '14609', 'name': 'iPhone 3GS', 'results': 120},
#     {'id': '5414092', 'name': 'iPhone XS Dual SIM', 'results': 111},
#     {'id': '8230322', 'name': 'iPhone SE (2nd Generation)', 'results': 48},
#     {'id': '14605', 'name': 'iPhone 3G', 'results': 39},
#     {'id': '5729', 'name': 'XS', 'results': 21},
#     {'id': '4904058', 'name': '8 Plus', 'results': 21},
#     {'id': '27251', 'name': '7', 'results': 21},
#     {'id': '31998', 'name': 'X', 'results': 15},
#     {'id': '58458', 'name': '4S', 'results': 12},
#     {'id': '52828', 'name': '7 Plus', 'results': 12},
#     {'id': '59833', 'name': '6', 'results': 9},
#     {'id': '59000', 'name': '5s', 'results': 9},
#     {'id': '58054', 'name': 'XR', 'results': 9}]},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com reconhecimento facial',
#      'results': 2625}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com leitor de impressão digital',
#      'results': 15969}]}]}

# %%
temp.keys()
# Out:
# dict_keys(['site_id', 'query', 'paging', 'results', 'secondary_results', 'related_results', 'sort', 'available_sorts', 'filters', 'available_filters'])

# %%
for anuncio in temp['results']:
    print(anuncio['title'])
# Out:
# iPhone 11 64 Gb Preto 4 Gb Ram
# iPhone 11 128 Gb Preto 4 Gb Ram
# iPhone 7 32 Gb Preto-fosco 2 Gb Ram
# iPhone XR 64 Gb Preto 3 Gb Ram
# iPhone 6s 64 Gb Cinza-espacial 2 Gb Ram
# iPhone 8 Plus 64 Gb Ouro 3 Gb Ram
# iPhone XR 128 Gb Preto 3 Gb Ram
# iPhone 11 Pro Max 256 Gb Cinza-espacial 4 Gb Ram
# iPhone XS 512 Gb Prata 4 Gb Ram
# iPhone XS 256 Gb Prata 4 Gb Ram
# iPhone XS 64 Gb Prata 4 Gb Ram
# iPhone XR 256 Gb Coral 3 Gb Ram
# iPhone 11 Pro 256 Gb Cinza-espacial 4 Gb Ram
# iPhone 7 128 Gb Preto-fosco 2 Gb Ram
# iPhone 11 256 Gb Preto 4 Gb Ram
# iPhone 11 Pro Max 64 Gb Cinza-espacial 4 Gb Ram
# iPhone 11 Pro 64 Gb Cinza-espacial 4 Gb Ram
# iPhone 8 64 Gb Prata 2 Gb Ram
# iPhone 6s 32 Gb Cinza-espacial 2 Gb Ram
# iPhone X 64 Gb Cinza-espacial 3 Gb Ram
# iPhone 8 Plus 128 Gb Cinza-espacial 3 Gb Ram
# iPhone XS Max 256 Gb Ouro 4 Gb Ram
# iPhone XS Max 64 Gb Cinza-espacial 4 Gb Ram
# iPhone SE (2nd Generation) 64 Gb Preto 3 Gb Ram
# iPhone 7 Plus 128 Gb Preto-fosco 3 Gb Ram
# iPhone SE (2nd Generation) 128 Gb Preto 3 Gb Ram
# iPhone 8 Plus 256 Gb (product)red 3 Gb Ram
# iPhone 7 Plus 32 Gb Ouro Rosa 3 Gb Ram
# iPhone X 256 Gb Prata 3 Gb Ram
# iPhone SE 32 Gb Ouro Rosa 2 Gb Ram
# iPhone 6s 16 Gb Prata 2 Gb Ram
# iPhone 6s 128 Gb Cinza-espacial 2 Gb Ram
# iPhone XS Max 512 Gb Cinza-espacial 4 Gb Ram
# iPhone 6s Plus 32 Gb Prata 2 Gb Ram
# iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram
# iPhone 8 256 Gb Prata 2 Gb Ram
# iPhone XS Dual Sim 256 Gb Ouro 4 Gb Ram
# iPhone 6s Plus 128 Gb Cinza-espacial 2 Gb Ram
# iPhone SE 16 Gb Ouro 2 Gb Ram
#  iPhone 8 Plus Vitrine 64gb Original Apple Em  12x Sem Juros
# iPhone 6s 64g Apple  Exposicao Garantia 12x Sem Juros
# iPhone 11 Preto 6,1  4g 64 Gb E Câmera De 12 Mp - Mwlt2br/a
# iPhone XR 64gb
#  iPhone 8 Vitrine 64gb Original Apple Exposição 12x S/ Juros
# Apple iPhone 7 32 Gb Vitrine + Brinde  12x Sem Juros
# iPhone 11 Preto 6,1  4g 128 Gb E Câmera 12 Mp - Mwm02br/a
# iPhone XR Branco Tela 6,1, 128 Gb E Câmera 12mp - Mryd2br/a
# iPhone XR 64gb
# Apple iPhone 6s Vitrine Original 64gb Garantia Promo À Vista
# iPhone XR Preto,tela 6,1, 64 Gb, Câmera De 12 Mp - Mry42br/a

# %% [markdown]
# Transforme o resultado da API em um Dataframe

# %%
#Coloque seu código aqui
df = pd.DataFrame(temp['results'])
df.head()
# Out:
#               id site_id                                    title  \
# 0  MLB1513918236     MLB           iPhone 11 64 Gb Preto 4 Gb Ram
# 1  MLB1638935509     MLB          iPhone 11 128 Gb Preto 4 Gb Ram
# 2  MLB1507604525     MLB      iPhone 7 32 Gb Preto-fosco 2 Gb Ram
# 3  MLB1348930369     MLB           iPhone XR 64 Gb Preto 3 Gb Ram
# 4  MLB1488721028     MLB  iPhone 6s 64 Gb Cinza-espacial 2 Gb Ram
#
#                                               seller    price currency_id  \
# 0  {'id': 234000251, 'permalink': 'http://perfil....  4875.89         BRL
# 1  {'id': 259411419, 'permalink': 'http://perfil....  5050.00         BRL
# 2  {'id': 336592499, 'permalink': 'http://perfil....  2290.99         BRL
# 3  {'id': 234000251, 'permalink': 'http://perfil....  3399.00         BRL
# 4  {'id': 61843260, 'permalink': 'http://perfil.m...  2418.00         BRL
#
#    available_quantity  sold_quantity buying_mode listing_type_id  ...  \
# 0                 250            500  buy_it_now        gold_pro  ...
# 1                   1              0  buy_it_now        gold_pro  ...
# 2                   1             25  buy_it_now        gold_pro  ...
# 3                 250            500  buy_it_now        gold_pro  ...
# 4                   1              0  buy_it_now        gold_pro  ...
#
#                                       seller_address  \
# 0  {'id': '', 'comment': '', 'address_line': '', ...
# 1  {'id': '', 'comment': '', 'address_line': '', ...
# 2  {'id': '', 'comment': '', 'address_line': '', ...
# 3  {'id': '', 'comment': '', 'address_line': '', ...
# 4  {'id': '', 'comment': '', 'address_line': '', ...
#
#                                           attributes differential_pricing  \
# 0  [{'value_id': '9344', 'values': [{'struct': No...     {'id': 33580182}
# 1  [{'values': [{'struct': None, 'source': 1, 'id...     {'id': 33580182}
# 2  [{'id': 'BRAND', 'name': 'Marca', 'values': [{...     {'id': 33580182}
# 3  [{'value_id': '9344', 'value_name': 'Apple', '...     {'id': 33580182}
# 4  [{'attribute_group_name': 'Outros', 'value_nam...     {'id': 33580182}
#
#   original_price  category_id official_store_id       domain_id  \
# 0            NaN      MLB1055             942.0  MLB-CELLPHONES
# 1            NaN      MLB1055               NaN  MLB-CELLPHONES
# 2            NaN      MLB1055               NaN  MLB-CELLPHONES
# 3         4499.9      MLB1055             942.0  MLB-CELLPHONES
# 4            NaN      MLB1055               NaN  MLB-CELLPHONES
#
#   catalog_product_id                                               tags  \
# 0        MLB15149561  [brand_verified, extended_warranty_eligible, g...
# 1        MLB15149567  [brand_verified, good_quality_picture, good_qu...
# 2         MLB6240116  [good_quality_thumbnail, loyalty_discount_elig...
# 3        MLB12866681  [brand_verified, extended_warranty_eligible, g...
# 4         MLB6127573  [extended_warranty_eligible, good_quality_pict...
#
#   catalog_listing
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#
# [5 rows x 28 columns]

# %%
df.head(1).T
# Out:
#                                                                       0
# id                                                        MLB1513918236
# site_id                                                             MLB
# title                                    iPhone 11 64 Gb Preto 4 Gb Ram
# seller                {'id': 234000251, 'permalink': 'http://perfil....
# price                                                           4875.89
# currency_id                                                         BRL
# available_quantity                                                  250
# sold_quantity                                                       500
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-04-30T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-11-64-g...
# thumbnail             http://mlb-s1-p.mlstatic.com/890754-MLA4245393...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 406.32, 'rate': 0, ...
# address               {'state_id': 'BR-SP', 'state_name': 'São Paulo...
# shipping              {'free_shipping': False, 'mode': 'me1', 'tags'...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'value_id': '9344', 'values': [{'struct': No...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   942
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB15149561
# tags                  [brand_verified, extended_warranty_eligible, g...
# catalog_listing                                                    True

# %%
df.address.apply(pd.Series).head() # desmembrando a coluna address transformando em uma series
# Out:
#   state_id    state_name           city_id       city_name
# 0    BR-SP     São Paulo  QlItU1BDYWphbWFy         Cajamar
# 1    BR-MG  Minas Gerais  TUxCQ01PTjE2OWFh      Monte Belo
# 2    BR-SP     São Paulo          BR-SP-42        Campinas
# 3    BR-SP     São Paulo  QlItU1BDYWphbWFy         Cajamar
# 4    BR-MG  Minas Gerais  TUxCQ0JFTGU0ODdm  Belo Horizonte

# %%
df2 = df.merge(df.address.apply(pd.Series),left_index=True, right_index=True).drop('address', axis=1)

# %%
df2.head(1).T
# Out:
#                                                                       0
# id                                                        MLB1513918236
# site_id                                                             MLB
# title                                    iPhone 11 64 Gb Preto 4 Gb Ram
# seller                {'id': 234000251, 'permalink': 'http://perfil....
# price                                                           4875.89
# currency_id                                                         BRL
# available_quantity                                                  250
# sold_quantity                                                       500
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-04-30T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-11-64-g...
# thumbnail             http://mlb-s1-p.mlstatic.com/890754-MLA4245393...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 406.32, 'rate': 0, ...
# shipping              {'free_shipping': False, 'mode': 'me1', 'tags'...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'value_id': '9344', 'values': [{'struct': No...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   942
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB15149561
# tags                  [brand_verified, extended_warranty_eligible, g...
# catalog_listing                                                    True
# state_id                                                          BR-SP
# state_name                                                    São Paulo
# city_id                                                QlItU1BDYWphbWFy
# city_name                                                       Cajamar

# %%
df2.columns
# Out:
# Index(['id', 'site_id', 'title', 'seller', 'price', 'currency_id',
#        'available_quantity', 'sold_quantity', 'buying_mode', 'listing_type_id',
#        'stop_time', 'condition', 'permalink', 'thumbnail',
#        'accepts_mercadopago', 'installments', 'shipping', 'seller_address',
#        'attributes', 'differential_pricing', 'original_price', 'category_id',
#        'official_store_id', 'domain_id', 'catalog_product_id', 'tags',
#        'catalog_listing', 'state_id', 'state_name', 'city_id', 'city_name'],
#       dtype='object')

# %%
print('Contagem:', df2.loc[df2.state_name=='Minas Gerais',:].price.count())
print('Média:', round(df2.loc[df2.state_name=='Minas Gerais',:].price.mean(),2))
# Out:
# Contagem: 4
# Média: 3409.5

# %% [markdown]
# ___

# %% [markdown]
# ### NBA
# Vamos utilizar a API da NBA para entender os principais jogadores das finais.<br>
# <strong>O que fazer</strong>: consulta a API através de módulos e funções de uma biblioteca<br>
# <strong>Documentação</strong>: https://github.com/swar/nba_api<br>
# <strong>Objetivo</strong>: Qual a distância média de arremessos dos jogadores Kawhi Leonard e Stephen Curry na temporada 18/19<br>
# <strong>Desafio</strong>: Plote um gráfico comparando o perfil de localização dos arremessos.<br>
# <strong>Dica</strong>: A biblioteca tem muitos módulos e funções. Seja objetivo em encontrar aqueles que interessam ao problema

# %%
range_1 = 'Less Than 8 ft.'
range_2 = '8-16 ft.'
range_3 = '16-24 ft.'
range_4 = '24+ ft.'
fig, ax = plt.subplots(1,2, figsize=(20,10))
ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_1,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_1,'LOC_Y'], color='green')
ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_2,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_2,'LOC_Y'], color='yellow')
ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_3,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_3,'LOC_Y'], color='orange')
ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_4,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_4,'LOC_Y'], color='red')
ax[0] = draw_court(ax[0])
# Adjust plot limits to just fit in half court
ax[0].set_xlim(-250,250)
# Descending values along th y axis from bottom to top
# in order to place the hoop by the top of plot
ax[0].set_ylim(422.5, -47.5)
ax[0].set_title(shots1_df.PLAYER_NAME[0])
# get rid of axis tick labels
# plt.tick_params(labelbottom=False, labelleft=False)

ax[1].scatter(shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_1,'LOC_X'], shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_1,'LOC_Y'], color='green')
ax[1].scatter(shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_2,'LOC_X'], shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_2,'LOC_Y'], color='yellow')
ax[1].scatter(shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_3,'LOC_X'], shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_3,'LOC_Y'], color='orange')
ax[1].scatter(shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_4,'LOC_X'], shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_4,'LOC_Y'], color='red')
ax[1] = draw_court(ax[1])
# Adjust plot limits to just fit in half court
ax[1].set_xlim(-250,250)
# Descending values along th y axis from bottom to top
# in order to place the hoop by the top of plot
ax[1].set_ylim(422.5, -47.5)
ax[1].set_title(shots2_df.PLAYER_NAME[0])
# get rid of axis tick labels
# plt.tick_params(labelbottom=False, labelleft=False)

plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-8d9bf5c6adcd> in <module>
#       3 range_3 = '16-24 ft.'
#       4 range_4 = '24+ ft.'
# ----> 5 fig, ax = plt.subplots(1,2, figsize=(20,10))
#       6 ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_1,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_1,'LOC_Y'], color='green')
#       7 ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_2,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_2,'LOC_Y'], color='yellow')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ___

# %% [markdown]
# ## APIs com autenticação

# %% [markdown]
# ### Spotify
# Vamos utilizar a API do Spotify para experimentar o processo de autenticação.<br>
# <strong>O que fazer</strong>: estudando a estrutura da API para conseguir a informação desejada<br>
# <strong>Documentação</strong>: https://developer.spotify.com/documentation/web-api/<br>
# <strong>Objetivo</strong>: Qual a popularidade média da cantora Teresa Cristina e sua música mais popular?<br>
# <strong>Dica</strong>: É crítico entender a estrutura da API (quais são as possíveis requisições e quais dados cada uma entrega). Utilize o console (https://developer.spotify.com/console/) para facilitar esse entendimento.

# %%
token = '' #pegar no site
cabecalho = {'Accept': 'application/json', 'Content-Type': 'application/json', 'Authorization': 'Bearer '+token}
cabecalho

# %%
url = "https://api.spotify.com/v1/search"
q = 'Teresa Cristina'
q_type = 'artist'
market = 'BR'
parametros = {'q':q, 'type': q_type,  'market': market}
parametros

# %%
resultado = requests.get(url, params=parametros, headers=cabecalho)

# %%
print(resultado.url)
print(json.dumps(resultado.json(), sort_keys=True, indent=2))

# %% [markdown]
# ___

# %% [markdown]
# ## Nível 3: APIs com autenticação complexa (e/ou billing)

# %% [markdown]
# ### Google Agenda
#
# Vamos utilizar a API do Google Agenda para experimentar o processo de autenticação do Google.<br>
# <strong>O que fazer</strong>: entender aspectos da autenticação por crendenciais e tokens.<br>
# <strong>Documentação</strong>: https://developers.google.com/calendar/v3/reference<br>
# <strong>Objetivo</strong>: Trazer os próximos 4 eventos na sua agenda do Google.<br>
# <strong>Dica</strong>: o processo é complexo, mas o Google disponibiliza vários "quick start projects" funcionais. Para esse exercício podem seguir esse: https://developers.google.com/calendar/quickstart/python<br>
# <strong>Bibliotecas</strong>: pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %% [markdown]
# ### Twitter

# %% [markdown]
# ___

# %% [markdown]
# # Próximos passos
#
# Há milhares de APIs e cada uma delas tem um jeito próprio de lidar, ou seja, de fazer nossas solicitações de dados e envio de dados.
#
# Uma das muitas vantagens das APIs é tornar as soluções encaixaveis e reutilizaveis em outros programas.
#
# Na nossa área de ciência de dados, não só utilizamos APIs para consultar dados mas muitas vezes para fornecer nossa aplicação de machine learning como um serviço.
#
# Há várias plataformas que monitoram as inúmeras APIs disponíveis:
# - https://99apis.com/home
# - https://www.programmableweb.com/
# - https://rapidapi.com/
#
# Há também softwares utilizados na administração de APIs (tanto para consultas quanto para publicação). Entre os mais famosos estão o Postman (https://www.postman.com/) e o Insomnia (https://insomnia.rest/)
