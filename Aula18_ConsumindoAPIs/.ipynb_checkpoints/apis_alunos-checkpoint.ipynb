# %% [markdown]
# # Introdução

# %% [markdown]
# - <strong>Curso:</strong> Data Science
# - <strong>Turma:</strong> Noite 01 (04/02/2020 a 02/07/2020)
# - <strong>Aula:</strong>  Consumindo APIs
# - <strong>Data:</strong>  02/06/2020
# - <strong>Autor:</strong> Eduardo Tiecher @ Digital House
# - <strong>Instruções gerais:</strong><br>
#   - Vocês precisarão instalar provavelmente apenas uma biblioteca para essa aula (nba_api). Para os exercícios mais avançados, tem um processo mais complexo de instalação de aplicações e bibliotecas (a saber: google-api-python-client, google-auth-httplib2, google-auth-oauthlib)
#   - Precisaremos ter contas em alguns dos serviços que iremos utilizar se der tempo de chegar nos exercícios mais avançados. Tentem criar suas contas antes da aula, pois alguns são bastante complexos. Se não conseguirem não tem problema, aprenderemos bastante já com os serviços mais básicos.
#     - Para os exercícios intermediários, precisaremos de uma conta no Spotify (gratuita é suficiente). Mesmo que não consigam chegar nos exercícios avançados, por favor garantam que a conta esteja criada.
#     - Para os exercícios avançados serão necessários uma conta no Google API, no Google Cloud Platform - GCP e no Twitter (a proposta é passar pelo processo de criação de conta durante a aula).

# %% [markdown]
# ___

# %% [markdown]
# # TEORIA

# %% [markdown]
# ## API (Application Programming Interface)

# %% [markdown]
# Antes de falarmos de API, precisamos entender como a internet funciona e porque devemos separar as partes de um software.

# %% [markdown]
# ## Como funciona o protocolo HTTP
#
# A internet trafega através do protocolo **HTTP (*Hypertext Transfer Protocol*)**. O protocolo HTTP foi criado por **Tim Berners-Lee**, o criador da web, enquanto ele trabalhava na CERN em 1989 (sua equipe e ele também foram responsáveis pelo HTML).
#
# O HTTP possui duas entidades básicas: a **Request (pedido)** e a **Response (resposta)**
#
# Sempre que entramos em uma página, enviamos uma request para o servidor do site e esperamos uma response com o HTML da página.

# %% [markdown]
# Sempre que enviamos um ***Request (pedido)*** devemos especificar um método. A tabela abaixo cita os métodos mais comuns e explica brevemente o objetivo de cada um:
#
# | Método |        Objetivo       |
# |:------:|:---------------------:|
# | GET    | Obter informações     |
# | POST   | Salvar informações    |
# | PUT    | Atualizar informações |
# | DELETE | Deletar informações   |
#
# Todos eles são comumente utilizados por APIs.
#
# O método ***GET*** é o que seu navegador usa para baixar o HTML da página.
#
# O metódo ***POST*** também é muito utilizado sempre que você envia algum formulário em um site.
#
# Além do método, as requisições também possuem um **header**:
#
# O **Header (cabeçalho)** tem a função de dizer para o servidor diversos dados sobre quem fez a solicitação. Dessa forma, o servidor consegue até permitir que você veja mais informações dependendo do seu nível de acesso.

# %% [markdown]
# ### PROTOCOLO DE COMUNICAÇÃO HTTP
# <img src="https://www.pubnub.com/wp-content/uploads/2014/11/HTTP-LONG-POLLING.png">
# <br>
# Os clientes, nossos computadores, conseguem acessar páginas e aplicações na internet atravez deste protocolo, que responde as requisições com arquivos de acordo com seu nível de acesso e com o que foi solicitado.
# Se você acessar o site da Digital House por exemplo e pedir para inspecionar (no Chrome `Ctrl+Shift+i`) os dados de rede, vai ver todos as solicitações e respostas do seu navegador ao servidor.
# <br>
# O resultado será algo parecido com isso:
# <img src="https://developer.chrome.com/devtools/images/network-panel.png">

# %% [markdown]
# ## Códigos de status
# A solicitação que acabamos de fazer tinha um código de status de 200. Os códigos de status são retornados com cada solicitação feita para um servidor da web. Códigos de status indicam informações sobre o que aconteceu com uma solicitação. Aqui estão alguns códigos que são relevantes para solicitações GET :
#
# - 200 - tudo correu bem, e o resultado foi devolvido (se houver)
# - 301- o servidor está redirecionando você para um terminal diferente. Isso pode acontecer quando uma empresa troca nomes de domínio ou um nome de terminal é alterado.
# - 401- o servidor acha que você não está autenticado. Isso acontece quando você não envia as credenciais corretas para acessar uma API (falaremos sobre autenticação em uma postagem posterior).
# - 400- o servidor acha que você fez um pedido incorreto. Isso pode acontecer quando você não envia os dados corretos, entre outras coisas.
# - 403 - o recurso que você está tentando acessar é proibido - você não tem as permissões certas para visualizá-lo.
# - 404 - o recurso que você tentou acessar não foi encontrado no servidor.
#
# Se tentarmos acessar um site ou endereço que não existe, receberemos o código acima.

# %%
import requests

response = requests.get("http://www.globo.com/cursos/data_science")
print(response.status_code)
# Out:
# 404

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json")
print(response.status_code)
# Out:
# 400

# %%
# This is the latitude and longitude of New York City.
parameters = {"q": 'data science'}

# Make a get request with the parameters.
response = requests.get("http://google.com/search", params=parameters)
print(response.status_code)

# Equivalente a URL: http://google.com/search?q=data+science
# Out:
# 200

# %% [markdown]
# ## O que é uma API?

# %% [markdown]
# Podemos dizer que uma API é como se fosse uma página da web só que para computadores. Só eles conseguirem acessar, ler e interagir da maneira adequada com as APIs.
#
# Ao trabalhar com projetos que envolvem dados, é muito comum vocês utilizarão APIs tanto internas (fornecidas pelas próprias empresas em que vocês trabalham) quanto externas.
#
# APIs são uma das principais formas para se obter dados que devem ser analisados.
#
# <center>
# <img src="https://cdn-images-1.medium.com/max/1600/1*CkynRe-J1FVnUAk7JmOTdQ.gif" alt="drawing" width="600px"></center>

# %% [markdown]
# ### Por que acessar uma API ao invez de um banco de dados diretamente?
#
# Porque o mundo está cheio de pessoas mal intencionadas e ao dar acesso direto ao banco de dados você está correndo risco de ter seus dados apagados, alterados ou que as pessoas tenham acesso a dados que deveriam ser confidenciais.
#
# É uma forma de separar, controlar e até multiplicar os acessos a sistemas de forma organizada.
# Imagine se cada cliente de um restaurante fosse fazer os pedidos direto ao Chef na cozinha, é provável que os pedidos saiam errados, fora de ordem ou o Chef fique estressado, por isso existe o garçom que faz o papel de levar os pedidos e trazer a comida organizando uma fila de pedidos.
# A API faz exatamente isso, controlando o que pedir e para quem pedir.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*Elr2TpvMI7xfSack20B6bA.png">

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='s7wmiS2mSXY'

YouTubeVideo(id=id,width=600,height=300)

# %% [markdown]
# Mas por que usar uma API em vez de um conjunto de dados estáticos que você pode baixar? As APIs são úteis nos seguintes casos:
#
# - Os dados estão mudando rapidamente. Um exemplo disso são os dados do preço das ações. Não faz muito sentido gerar um conjunto de dados e baixá-lo a cada minuto - isso demandará muita largura de banda e será bastante lento.
# - Você quer um pequeno pedaço de um conjunto muito maior de dados. Comentários do Reddit são um exemplo. E se você quiser apenas puxar seus próprios comentários no Reddit? Não faz muito sentido baixar todo o banco de dados Reddit, depois filtrar apenas seus próprios comentários.
# - Há computação repetida envolvida. Spotify tem uma API que pode dizer o gênero de uma peça musical. Você poderia, teoricamente, criar seu próprio classificador e usá-lo para categorizar a música, mas nunca terá tantos dados quanto o Spotify.
#
# Em casos como os acima, uma API é a solução certa.
#
# Agora, vamos consultar uma API simples para recuperar dados sobre a Estação Espacial Internacional (ISS). O uso de uma API nos poupará tempo e esforço ao fazermos todos os cálculos.
# Então, faremos uma solicitação GET para http://api.open-notify.org/iss-passum terminal que não existe, de acordo com a documentação da API .

# %%
response = requests.get("http://api.open-notify.org/iss-pass")
print(response.status_code)
# Out:
# 404

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json")
print(response.status_code)
# Out:
# 400

# %%
# This is the latitude and longitude of New York City.
parameters = {"lat": 40.71, "lon": -74}

# Make a get request with the parameters.
iss = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)
print(response.status_code)
# Out:
# 200

# %%
iss.url # e a reposta ao  parametro acima
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74'

# %%
response.text # tras a base de informacoes
# Out:
# '{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1598399782, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 539, \n      "risetime": 1598428665\n    }, \n    {\n      "duration": 653, \n      "risetime": 1598434391\n    }, \n    {\n      "duration": 596, \n      "risetime": 1598440254\n    }, \n    {\n      "duration": 561, \n      "risetime": 1598446140\n    }, \n    {\n      "duration": 623, \n      "risetime": 1598451970\n    }\n  ]\n}\n'

# %%
response.content
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1598399782, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 539, \n      "risetime": 1598428665\n    }, \n    {\n      "duration": 653, \n      "risetime": 1598434391\n    }, \n    {\n      "duration": 596, \n      "risetime": 1598440254\n    }, \n    {\n      "duration": 561, \n      "risetime": 1598446140\n    }, \n    {\n      "duration": 623, \n      "risetime": 1598451970\n    }\n  ]\n}\n'

# %%
type(response.content)
# Out:
# bytes

# %% [markdown]
# ## XML × JSON × YAML
#
# Anos atrás a comunicação entre serviços se dava por XML usando o padrão SOAP. Na era da mobilidade, JSON passou a ser largamente usado. Hoje, aos poucos está sendo substituido por YAML, que é similar,  porém mais amigável para leitura por humanos.
#
# <img src="XML×JSON×YAML.png" width="75%"></img>
#
# A estrutura de um json se parece muito com os dicionários em Python
#
# Ele foi feito para que máquinas entendam seus dados e os utilizem como quiser.
#
# Outra característica das APIs REST é a **divisão dos recursos**. Por exemplo:
#
# https://jsonplaceholder.typicode.com/users/1
#
# Ao abrirmos esta URL estamos fazendo um GET (o navegador executa o GET) para obtermos informações do usuário (/users) com código 1 (/1). Podemos trocar o código do usuário para buscar outros usuários.
#
# Também podemos pedir todos os usuários digitando:
#
# https://jsonplaceholder.typicode.com/users

# %% [markdown]
# ## Trabalhando com dados JSON
# Você deve ter notado que o conteúdo da resposta anterior era um string (embora tenha sido mostrado como um objeto, podemos facilmente converter o conteúdo em uma string usando response.content.decode("utf-8")).
#
# As strings são a forma como passamos as informações para as APIs, mas é difícil obter as informações que queremos delas. Como decodificar a string que recebemos e trabalhar com ela em Python?
#
# O JSON é uma maneira de codificar estruturas de dados, como listas e dicionários, para seqüências de caracteres que garantem que elas sejam facilmente legíveis por máquinas. JSON é o formato principal no qual os dados são passados para as APIs e a maioria dos servidores de API envia suas respostas nesse formato.
#
# O Python tem um ótimo suporte a JSON, com a biblioteca 'json'. Ele faz parte da biblioteca padrão, portanto, não precisamos instalar nada para usá-lo. Podemos converter listas e dicionários em JSON e converter strings em listas e dicionários . No caso dos nossos dados do ISS Pass, é um dicionário codificado para uma string no formato JSON.
#
# A biblioteca json possui dois métodos principais:
#
# - dumps - Utiliza um objeto Python e o converte em uma string.
# - loads - Leva uma string JSON e a converte em um objeto Python.

# %%
response.json() # tras no formato json
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1598311966,
#   'latitude': 40.71,
#   'longitude': -74.0,
#   'passes': 5},
#  'response': [{'duration': 599, 'risetime': 1598345081},
#   {'duration': 647, 'risetime': 1598350853},
#   {'duration': 579, 'risetime': 1598356733},
#   {'duration': 570, 'risetime': 1598362608},
#   {'duration': 640, 'risetime': 1598368426}]}

# %%
meu_dicionario = response.json() # criando um dicionario
meu_dicionario
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1598399782,
#   'latitude': 40.71,
#   'longitude': -74.0,
#   'passes': 5},
#  'response': [{'duration': 539, 'risetime': 1598428665},
#   {'duration': 653, 'risetime': 1598434391},
#   {'duration': 596, 'risetime': 1598440254},
#   {'duration': 561, 'risetime': 1598446140},
#   {'duration': 623, 'risetime': 1598451970}]}

# %%
meu_dicionario['message'] # esta fazendo uma chamada uma determinada chave do dicionario, como se fosse chamar \
# uma coluna do dataframe
# Out:
# 'success'

# %%
request = meu_dicionario['request'] # adiciono a chava request dentro de outra variavel e consegui acessar os\
# parametro da chave individualmente
request['datetime']
# Out:
# 1598399782

# %%
meu_dicionario['request']
# Out:
# {'altitude': 100,
#  'datetime': 1598399782,
#  'latitude': 40.71,
#  'longitude': -74.0,
#  'passes': 5}

# %%
type(response.json())
# Out:
# dict

# %%
import json
print(json.dumps(response.json(),  sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "request": {
#         "altitude": 100,
#         "datetime": 1598399782,
#         "latitude": 40.71,
#         "longitude": -74.0,
#         "passes": 5
#     },
#     "response": [
#         {
#             "duration": 539,
#             "risetime": 1598428665
#         },
#         {
#             "duration": 653,
#             "risetime": 1598434391
#         },
#         {
#             "duration": 596,
#             "risetime": 1598440254
#         },
#         {
#             "duration": 561,
#             "risetime": 1598446140
#         },
#         {
#             "duration": 623,
#             "risetime": 1598451970
#         }
#     ]
# }

# %% [markdown]
# ## Parâmetros de consulta
# Você verá que, no último exemplo, recebemos um código de status '400', que indica uma solicitação incorreta. Se você observar a documentação da API do OpenNotify, veremos que o ponto de extremidade do ISS Pass requer dois parâmetros.
#
# O ponto de extremidade do ISS Pass retorna quando o ISS passará em seguida sobre um determinado local na Terra. Para calcular isso, precisamos passar as coordenadas do local para a API. Fazemos isso passando dois parâmetros - latitude e longitude.
#
# Podemos fazer isso adicionando um argumento opcional de palavra-chave params, a nosso pedido. Neste caso, existem dois parâmetros que precisamos passar:
#
# - lat - A latitude do local que queremos.
# - lon - A longitude do local que queremos.
#
# Podemos criar um dicionário com esses parâmetros e depois passá-los para a função 'requests.get'.
#
# Nós também podemos fazer a mesma coisa diretamente, adicionando os parâmetros de consulta para a url, como este: http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74.
#
# É quase sempre preferível configurar os parâmetros como um dicionário, porque requests cuida de algumas coisas que surgem, como formatar corretamente os parâmetros da consulta.
#
# Faremos uma solicitação usando as coordenadas da cidade de São Paulo e veremos a resposta que recebermos.
#
# __São Paulo__<br>
# Latitude: -23.68<br>
# Longitude: -46.87

# %%
# Este comando busca os mesmos dados que o comando que usamos para buscar os dados de São Paulo acima
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=-23.68&lon=-46.87")
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "request": {
#         "altitude": 100,
#         "datetime": 1598310021,
#         "latitude": -23.68,
#         "longitude": -46.87,
#         "passes": 5
#     },
#     "response": [
#         {
#             "duration": 415,
#             "risetime": 1598321393
#         },
#         {
#             "duration": 656,
#             "risetime": 1598327109
#         },
#         {
#             "duration": 410,
#             "risetime": 1598333013
#         },
#         {
#             "duration": 501,
#             "risetime": 1598375373
#         },
#         {
#             "duration": 648,
#             "risetime": 1598381087
#         }
#     ]
# }

# %% [markdown]
# ## Uma mesma API pode conter diversas **ROTAS** ou endpoints diferentes
#
# Como o servidor faz para saber o que está sendo pedido na solicitação? Isso é especificado na URL (Uniform Resource Locator), uma espécie de caminho que indica onde um recurso pode ser encontrado.
#
# - protocol: Indica o protocolo que será utilizado para acessar (HTTP, FTP, HTTPS)
# - host: Indica como encontrar na rede (local ou internet) o servidor que tem o recurso
# - port: Indica em qual porta o servidor está escutando. A 'porta' de um IP é o que permite que um computador se comunique simultaneamente com outros. Cada comunicação requer uma porta (são ao todo 65.535)
# - path: Indica o caminho para localizar o recurso dentro do servidor. Como se fossem pastas do navegador de arquivos
# - query: Indica qual é a consulta que está sendo realizada. Inclui quais são os argumentos desejados ou necessários, bem como os valores a ser utilizado para cada argumento
#
# <img src="http://digitalad.com.br/DH/Picture1.png">
# <br>
#
# Por exemplo, podemos usar a funcionalidade dessa API da ISS para descobrir todas as pessoas que estão em orbita.

# %%
# Get the response from the API endpoint.
response = requests.get("http://api.open-notify.org/astros.json")
data = response.json()
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "number": 3,
#     "people": [
#         {
#             "craft": "ISS",
#             "name": "Chris Cassidy"
#         },
#         {
#             "craft": "ISS",
#             "name": "Anatoly Ivanishin"
#         },
#         {
#             "craft": "ISS",
#             "name": "Ivan Vagner"
#         }
#     ]
# }

# %% [markdown]
# Para conseguir capturar um dado específico do JSON, basta fazer as referências como se buscasse em um dicionário, identificando o tipo de cada elemento ou nível do dicionário (exemplo: um dicionário de listas, um dicionário de dicionários, etc).

# %%
print('Total de astronautas:', data["number"])
print('Primeiro da lista:', data["people"][0])
print('Nome do 1o da lista:', data["people"][0]['name'])
# Out:
# Total de astronautas: 3
# Primeiro da lista: {'craft': 'ISS', 'name': 'Chris Cassidy'}
# Nome do 1o da lista: Chris Cassidy

# %%
data['people']
# Out:
# [{'craft': 'ISS', 'name': 'Chris Cassidy'},
#  {'craft': 'ISS', 'name': 'Anatoly Ivanishin'},
#  {'craft': 'ISS', 'name': 'Ivan Vagner'}]

# %% [markdown]
# ___

# %% [markdown]
# # PRÁTICA

# %% [markdown]
# ## APIs simples

# %% [markdown]
# ### Mercado Livre
# Vamos utilizar a API do MercadoLivre para consultar anúncios<br>
# <strong>O que fazer</strong>: acesso, download, tratamento e cálculo<br>
# <strong>Documentação</strong>: https://developers.mercadolivre.com.br/pt_br/api-docs-pt-br<br>
# <strong>Objetivo</strong>: Qual o preço médio dos anúncios de iphones em Minas Gerais<br>
# <strong>Desafio</strong>: Resolve o exercício através de uma função para permitir realizar a mesma consulta com outros itens ou estados<br>
# <strong>Dica</strong>: Carregue seus dados para um dataframe para facilitar a manipulação dos dados

# %%
import requests
import pandas as pd
import numpy as np
response = requests.get('https://api.mercadolibre.com/sites/MLB/search?q=iphone')

# %%
response.json()
# Out:
# {'site_id': 'MLB',
#  'query': 'iphone',
#  'paging': {'total': 22455, 'offset': 0, 'limit': 50, 'primary_results': 1012},
#  'results': [{'id': 'MLB1608016128',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s Plus 32 Gb Prata 2 Gb Ram',
#    'seller': {'id': 259218381,
#     'permalink': 'http://perfil.mercadolivre.com.br/F14SHOPP',
#     'registration_date': '2017-06-03T18:39:33.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1116,
#       'canceled': 98,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'positive': 0.92, 'neutral': 0.02},
#       'completed': 1018},
#      'power_seller_status': 'silver',
#      'metrics': {'claims': {'rate': 0,
#        'excluded': {'real_rate': 0.0292, 'real_value': 5},
#        'value': 0,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0,
#        'excluded': {'real_rate': 0.0672, 'real_value': 8},
#        'value': 0,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 153},
#       'cancellations': {'rate': 0,
#        'excluded': {'real_rate': 0, 'real_value': 2},
#        'value': 0,
#        'period': '3 months'}},
#      'protection_end_date': '2020-08-28T00:00:00.000-04:00',
#      'real_level': 'green_gold',
#      'level_id': '5_green'},
#     'address': {'zip_code': '89400000',
#      'address': 'av perimetral 1071',
#      'state': 'BR-SC',
#      'city': 'Porto União'}},
#    'price': 2360,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-plus-32-gb-prata-2-gb-ram/p/MLB11712143',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/820963-MLA31347985928_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 196.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SC',
#     'state_name': 'Santa Catarina',
#     'city_id': 'TUxCQ1BPUjE3NWM0',
#     'city_name': 'Porto União'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SC', 'name': 'Santa Catarina'},
#     'city': {'id': 'TUxCQ1BPUjE3NWM0', 'name': 'Porto União'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_struct': None,
#      'value_name': 'Apple',
#      'source': 1,
#      'name': 'Marca',
#      'value_id': '9344'},
#     {'name': 'Condição do item',
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'source': 1},
#     {'id': 'MODEL',
#      'value_id': '312153',
#      'value_name': 'iPhone 6s Plus',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo',
#      'values': [{'name': 'iPhone 6s Plus',
#        'struct': None,
#        'source': 1,
#        'id': '312153'}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo do processador',
#      'value_id': '6973026',
#      'value_name': 'Apple A9',
#      'source': 1,
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '522894',
#      'value_name': '192 g',
#      'value_struct': {'number': 192, 'unit': 'g'},
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'values': [{'id': '522894',
#        'name': '192 g',
#        'struct': {'number': 192, 'unit': 'g'},
#        'source': 1}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB11712143',
#    'tags': ['loyalty_discount_eligible',
#     'brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1622965271',
#    'site_id': 'MLB',
#    'title': 'iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram',
#    'seller': {'id': 8710030,
#     'permalink': 'http://perfil.mercadolivre.com.br/-DANSL-',
#     'registration_date': '2002-03-27T00:00:00.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 418,
#       'canceled': 32,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 0.97, 'neutral': 0.03},
#       'completed': 386},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0076,
#        'value': 1,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 133},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '09540500',
#      'address': 'Avenida Lemos Monteiro 71',
#      'state': 'BR-SP',
#      'city': 'São Caetano do Sul'}},
#    'price': 4100,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-19T14:49:16.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-se-2nd-generation-256-gb-preto-3-gb-ram/p/MLB15591337',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/917693-MLA42348499125_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 341.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-40',
#     'city_name': 'São Caetano do Sul'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-40', 'name': 'São Caetano do Sul'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha'},
#     {'id': 'MODEL',
#      'value_id': '8230322',
#      'value_struct': None,
#      'name': 'Modelo',
#      'value_name': 'iPhone SE (2nd Generation)',
#      'values': [{'id': '8230322',
#        'name': 'iPhone SE (2nd Generation)',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15591337',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1548895261',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 128 Gb Ouro Rosa 2 Gb Ram',
#    'seller': {'id': 78613217,
#     'permalink': 'http://perfil.mercadolivre.com.br/DIAMANTINASHOP',
#     'registration_date': '2005-02-09T06:31:05.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 438,
#       'canceled': 40,
#       'period': 'historic',
#       'ratings': {'negative': 0.01, 'positive': 0.99, 'neutral': 0},
#       'completed': 398},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0393, 'value': 10, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0167,
#        'value': 4,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 228},
#       'cancellations': {'rate': 0, 'value': 1, 'period': '3 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '46900000',
#      'address': 'RUA PIO XII 368',
#      'state': 'BR-BA',
#      'city': 'Seabra'}},
#    'price': 2850,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-05-31T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-128-gb-ouro-rosa-2-gb-ram/p/MLB6127580',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/819171-MLA31347280256_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 270.73,
#     'rate': 13.99,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-BA',
#     'state_name': 'Bahia',
#     'city_id': 'TUxCQ1NFQThhYjM',
#     'city_name': 'Seabra'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-BA', 'name': 'Bahia'},
#     'city': {'id': 'TUxCQ1NFQThhYjM', 'name': 'Seabra'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'id': 'BRAND',
#      'name': 'Marca'},
#     {'name': 'Modelo de GPU',
#      'value_id': '8094621',
#      'value_name': 'PowerVR GT7600',
#      'value_struct': None,
#      'values': [{'id': '8094621',
#        'name': 'PowerVR GT7600',
#        'struct': None,
#        'source': 1}],
#      'id': 'GPU_MODEL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'source': 2860837171021627,
#      'id': 'ITEM_CONDITION',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284'},
#     {'id': 'LINE',
#      'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'source': 1,
#      'name': 'Modelo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}],
#      'id': 'MODEL',
#      'value_id': '312151',
#      'value_name': 'iPhone 6s'},
#     {'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '6973026',
#      'value_name': 'Apple A9',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Peso',
#      'value_id': '522899',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_struct': {'number': 143, 'unit': 'g'},
#      'values': [{'source': 1,
#        'id': '522899',
#        'name': '143 g',
#        'struct': {'number': 143, 'unit': 'g'}}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': '143 g'}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6127580',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1560352635',
#    'site_id': 'MLB',
#    'title': 'iPhone XS Max 512 Gb Ouro 4 Gb Ram',
#    'seller': {'id': 147172848,
#     'permalink': 'http://perfil.mercadolivre.com.br/FIVENDASONLINE',
#     'registration_date': '2013-10-08T22:59:50.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 11638,
#       'canceled': 714,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.94, 'neutral': 0.03},
#       'completed': 10924},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0214, 'value': 41, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0696,
#        'value': 114,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1711},
#       'cancellations': {'rate': 0.0052, 'value': 10, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '03572340',
#      'address': 'José Da Costa De Andrade 105',
#      'state': 'BR-SP',
#      'city': 'São Paulo'}},
#    'price': 7199,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-06-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-max-512-gb-ouro-4-gb-ram/p/MLB12866634',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/864619-MLA42092921659_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 599.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Apple',
#      'value_struct': None,
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}]},
#     {'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799,
#      'value_id': '2230284',
#      'value_name': 'Novo'},
#     {'value_id': '58993',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '5414168',
#        'name': 'iPhone XS Max'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '5414168',
#      'value_name': 'iPhone XS Max',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'value_id': '6927771',
#      'value_name': 'Apple A12 Bionic',
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866634',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1503227867',
#    'site_id': 'MLB',
#    'title': 'iPhone 7 Plus 128 Gb Preto-brilhante 3 Gb Ram',
#    'seller': {'id': 61843260,
#     'permalink': 'http://perfil.mercadolivre.com.br/UAIPLACEBH',
#     'registration_date': '2008-12-06T08:42:58.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 318,
#       'canceled': 21,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 0.98, 'neutral': 0.02},
#       'completed': 297},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0157, 'value': 5, 'period': '60 months'},
#       'delayed_handling_time': {'rate': 0.1541,
#        'value': 37,
#        'period': '60 months'},
#       'sales': {'period': '60 months', 'completed': 297},
#       'cancellations': {'rate': 0.0345, 'value': 11, 'period': '60 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '30492025',
#      'address': 'Rua Professora Bartira Mourao 710',
#      'state': 'BR-MG',
#      'city': 'Belo Horizonte'}},
#    'price': 4099,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-04-17T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-7-plus-128-gb-preto-brilhante-3-gb-ram/p/MLB6240138',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/686636-MLA40678415629_022020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 341.58,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-MG',
#     'state_name': 'Minas Gerais',
#     'city_id': 'TUxCQ0JFTGU0ODdm',
#     'city_name': 'Belo Horizonte'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-MG', 'name': 'Minas Gerais'},
#     'city': {'id': 'TUxCQ0JFTGU0ODdm', 'name': 'Belo Horizonte'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'source': 1,
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None},
#     {'id': 'GPU_MODEL',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo de GPU',
#      'value_id': '8010379',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8010379',
#        'name': 'PowerVR Series7XT Plus'}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_id': '2230284',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'name': 'iPhone 7 Plus',
#        'struct': None,
#        'source': 1,
#        'id': '312157'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'value_id': '312157',
#      'value_name': 'iPhone 7 Plus',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo'},
#     {'value_id': '6946002',
#      'values': [{'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1,
#        'id': '6946002'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A10 Fusion',
#      'value_struct': None}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6240138',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1621676696',
#    'site_id': 'MLB',
#    'title': 'iPhone XS Dual Sim 256 Gb Ouro 4 Gb Ram',
#    'seller': {'id': 114128462,
#     'permalink': 'http://perfil.mercadolivre.com.br/MIAMISTORE+OFICIAL',
#     'registration_date': '2012-05-31T11:40:16.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'credits_profile',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 38602,
#       'canceled': 656,
#       'period': 'historic',
#       'ratings': {'negative': 0.04, 'positive': 0.92, 'neutral': 0.04},
#       'completed': 37946},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0227, 'value': 66, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.08,
#        'value': 141,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 2716},
#       'cancellations': {'rate': 0.0103, 'value': 30, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13076040',
#      'address': 'Rua Castro Alves 508',
#      'state': 'BR-SP',
#      'city': 'Campinas'}},
#    'price': 6239.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-02T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-dual-sim-256-gb-ouro-4-gb-ram/p/MLB12866589',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/877935-MLA33003199447_112019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 520,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_struct': None,
#      'values': [{'source': 1, 'id': '9344', 'name': 'Apple', 'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': 'Novo',
#      'source': 1},
#     {'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'attribute_group_name': 'Outros',
#      'value_id': '58993',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'values': [{'id': '5414092',
#        'name': 'iPhone XS Dual SIM',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '5414092',
#      'value_name': 'iPhone XS Dual SIM',
#      'value_struct': None,
#      'source': 1},
#     {'id': 'PROCESSOR_MODEL',
#      'value_struct': None,
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'name': 'Modelo do processador',
#      'value_id': '6927771',
#      'value_name': 'Apple A12 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 1087,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866589',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1628084905',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 128 Gb Verde 4 Gb Ram',
#    'seller': {'id': 54486513,
#     'permalink': 'http://perfil.mercadolivre.com.br/ROCHAVARIEDADESGO',
#     'registration_date': '2008-09-17T19:14:47.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 4204,
#       'canceled': 240,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 3964},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0222, 'value': 20, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0085,
#        'value': 7,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 806},
#       'cancellations': {'rate': 0.0144, 'value': 13, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '74560970',
#      'address': 'Avenida Marechal Rondon Quadra 6 Lote 15 849',
#      'state': 'BR-GO',
#      'city': 'Goiânia'}},
#    'price': 6099,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-09T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-11-128-gb-verde-4-gb-ram/p/MLB15149569',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/799546-MLA42453875917_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 508.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-GO',
#     'state_name': 'Goiás',
#     'city_id': 'TUxR29p4m5pYQ',
#     'city_name': 'Goiânia'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-GO', 'name': 'Goiás'},
#     'city': {'id': 'TUxR29p4m5pYQ', 'name': 'Goiânia'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_id': 'OTHERS',
#      'value_name': 'Apple',
#      'value_struct': None},
#     {'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU MP4',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '7740544',
#      'value_struct': None,
#      'values': [{'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 1}],
#      'source': 1},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627,
#        'id': '2230284'}],
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 2860837171021627},
#     {'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '7739079',
#      'value_name': 'iPhone 11',
#      'id': 'MODEL'},
#     {'name': 'Modelo do processador',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '7740540',
#        'name': 'Apple A13 Bionic'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149569',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1633485375',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 16 Gb Ouro Rosa 2 Gb Ram',
#    'seller': {'id': 271840140,
#     'permalink': 'http://perfil.mercadolivre.com.br/GLOBOCEL+CELULARES',
#     'registration_date': '2017-09-04T20:59:17.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 425,
#       'canceled': 60,
#       'period': 'historic',
#       'ratings': {'negative': 0.07, 'positive': 0.88, 'neutral': 0.05},
#       'completed': 365},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0408, 'value': 4, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 89},
#       'cancellations': {'rate': 0, 'value': 1, 'period': '3 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '22631470',
#      'address': 'Avenida Evandro Lins e Silva 440',
#      'state': 'BR-RJ',
#      'city': 'Rio de Janeiro'}},
#    'price': 1599,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-15T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-16-gb-ouro-rosa-2-gb-ram/p/MLB6127572',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/775325-MLA31347321681_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 133.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-RJ',
#     'state_name': 'Rio de Janeiro',
#     'city_id': 'BR-RJ-01',
#     'city_name': 'Rio de Janeiro'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-RJ', 'name': 'Rio de Janeiro'},
#     'city': {'id': 'BR-RJ-01', 'name': 'Rio de Janeiro'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'source': 1,
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Marca'},
#     {'value_id': '8094621',
#      'value_name': 'PowerVR GT7600',
#      'values': [{'id': '8094621',
#        'name': 'PowerVR GT7600',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'ITEM_CONDITION',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1572,
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1572}],
#      'attribute_group_name': 'Outros'},
#     {'id': 'LINE',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'source': 1},
#     {'id': 'MODEL',
#      'value_name': 'iPhone 6s',
#      'value_struct': None,
#      'values': [{'id': '312151',
#        'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo',
#      'value_id': '312151',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_id': '6973026',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A9',
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}]},
#     {'value_name': '143 g',
#      'values': [{'id': '522899',
#        'name': '143 g',
#        'struct': {'unit': 'g', 'number': 143},
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 143, 'unit': 'g'},
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '522899'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6127572',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1625322844',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s Plus 128 Gb Cinza-espacial 2 Gb Ram',
#    'seller': {'id': 110706143,
#     'permalink': 'http://perfil.mercadolivre.com.br/E..A..S..IMPORTS',
#     'registration_date': '2012-04-26T23:03:00.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_active_borrower',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 2653,
#       'canceled': 278,
#       'period': 'historic',
#       'ratings': {'negative': 0.01, 'positive': 0.98, 'neutral': 0.01},
#       'completed': 2375},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0144, 'value': 8, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0042,
#        'value': 2,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 478},
#       'cancellations': {'rate': 0.009, 'value': 5, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '04332050',
#      'address': 'José Estevão de Magalhães 442',
#      'state': 'BR-SP',
#      'city': 'São Paulo'}},
#    'price': 3080,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-07T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-plus-128-gb-cinza-espacial-2-gb-ram/p/MLB6143816',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/884567-MLA31347186400_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 256.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_name': 'Outros',
#      'name': 'Marca',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'BRAND'},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1505}],
#      'attribute_group_name': 'Outros',
#      'source': 1505,
#      'id': 'ITEM_CONDITION',
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'value_struct': None,
#      'values': [{'name': 'iPhone 6s Plus',
#        'struct': None,
#        'source': 1,
#        'id': '312153'}],
#      'source': 1,
#      'value_id': '312153',
#      'name': 'Modelo',
#      'value_name': 'iPhone 6s Plus',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '6973026'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6143816',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1629420452',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s Plus 16 Gb Ouro 2 Gb Ram',
#    'seller': {'id': 336592499,
#     'permalink': 'http://perfil.mercadolivre.com.br/SICE+DIGITAL',
#     'registration_date': '2018-07-14T07:33:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1220,
#       'canceled': 137,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.96, 'neutral': 0.01},
#       'completed': 1083},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0211, 'value': 25, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0018,
#        'value': 2,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1049},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13097158',
#      'address': 'Rua João de Barro SN',
#      'state': 'BR-SP',
#      'city': 'Campinas'}},
#    'price': 2100,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 1,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-plus-16-gb-ouro-2-gb-ram/p/MLB6143810',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/813448-MLA31347280284_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 175,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND'},
#     {'values': [{'source': 2860837171021627,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 2860837171021627,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'name': 'Condição do item',
#      'value_id': '2230284'},
#     {'id': 'LINE',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'name': 'Linha',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo',
#      'values': [{'id': '312153',
#        'name': 'iPhone 6s Plus',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'MODEL',
#      'value_id': '312153',
#      'value_name': 'iPhone 6s Plus',
#      'value_struct': None},
#     {'value_id': '6973026',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'values': [{'id': '522894',
#        'name': '192 g',
#        'struct': {'number': 192, 'unit': 'g'},
#        'source': 1}],
#      'name': 'Peso',
#      'value_name': '192 g',
#      'value_struct': {'number': 192, 'unit': 'g'},
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_id': '522894',
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6143810',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'brand_verified',
#     'extended_warranty_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1343736807',
#    'site_id': 'MLB',
#    'title': 'iPhone SE 32 Gb Cinza-espacial 2 Gb Ram',
#    'seller': {'id': 462162103,
#     'permalink': 'http://perfil.mercadolivre.com.br/EUROZ+OFICIAL',
#     'registration_date': '2019-08-16T17:56:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'mshops', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 800,
#       'canceled': 74,
#       'period': 'historic',
#       'ratings': {'negative': 0.01, 'positive': 0.97, 'neutral': 0.02},
#       'completed': 726},
# ...
#      'name': 'Linha',
#      'values': [{'source': 6587939990796619,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619},
#     {'id': 'MODEL',
#      'value_name': 'iPhone 8 Plus',
#      'values': [{'source': 6587939990796619,
#        'id': '2244673',
#        'name': 'iPhone 8 Plus',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'name': 'Modelo',
#      'value_id': '2244673',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'attribute_group_name': 'Outros',
#      'source': 6587939990796619,
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A11 Bionic',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 6587939990796619,
#        'id': '6936434',
#        'name': 'Apple A11 Bionic'}],
#      'name': 'Modelo do processador',
#      'value_id': '6936434',
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_name': '202 g',
#      'attribute_group_id': 'OTHERS',
#      'source': 6587939990796619,
#      'value_id': '2263677',
#      'value_struct': {'number': 202, 'unit': 'g'},
#      'values': [{'id': '2263677',
#        'name': '202 g',
#        'struct': {'unit': 'g', 'number': 202},
#        'source': 6587939990796619}],
#      'attribute_group_name': 'Outros'}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752450',
#    'tags': ['brand_verified',
#     'catalog_listing_eligible',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible']},
#   {'id': 'MLB1374360266',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 Pro Verde 5,8  4g 64gb Câm 12mp - Mwc62bz/a',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 281209,
#       'canceled': 11776,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 269433},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.025,
#        'value': 1626,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 60166},
#       'cancellations': {'rate': 0.0104, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 6226.64,
#    'currency_id': 'BRL',
#    'available_quantity': 250,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2039-11-22T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://produto.mercadolivre.com.br/MLB-1374360266-iphone-11-pro-verde-58-4g-64gb-cm-12mp-mwc62bza-_JM',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/968069-MLB42057606288_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 518.89,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'values': [{'source': 4060709329251625,
#        'id': '9344',
#        'name': 'Apple',
#        'struct': None}],
#      'source': 4060709329251625,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple'},
#     {'name': 'Modelo de GPU',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'values': [{'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_id': 'OTHERS',
#      'source': 4709228965570453},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'source': 3942444344910321,
#      'id': 'LINE',
#      'value_id': '58993',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 3942444344910321}],
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'value_struct': None},
#     {'value_name': 'iPhone 11 Pro',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 3942444344910321,
#        'id': '7741023',
#        'name': 'iPhone 11 Pro'}],
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '7741023',
#      'attribute_group_id': 'OTHERS',
#      'source': 3942444344910321},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_name': 'Apple A13 Bionic',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '7740540'},
#     {'values': [{'name': '188 g',
#        'struct': {'number': 188, 'unit': 'g'},
#        'source': 3942444344910321,
#        'id': '522900'}],
#      'source': 3942444344910321,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '522900',
#      'attribute_group_name': 'Outros',
#      'value_name': '188 g',
#      'value_struct': {'number': 188, 'unit': 'g'},
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15150711',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed']}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB1055',
#      'name': 'Celulares e Smartphones',
#      'path_from_root': [{'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#       {'id': 'MLB1055', 'name': 'Celulares e Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'type': 'STRING',
#    'values': [{'id': '58993', 'name': 'iPhone'}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as Lojas oficiais', 'results': 137},
#     {'id': '942', 'name': 'Fast Shop', 'results': 51},
#     {'id': '817', 'name': 'COMMCENTER', 'results': 10},
#     {'id': '2162', 'name': 'Apple', 'results': 21},
#     {'id': '2945', 'name': 'Trocafone', 'results': 40}]},
#   {'id': 'discount',
#    'name': 'Descontos',
#    'type': 'range',
#    'values': [{'id': '10-100', 'name': 'Mais de 10% off', 'results': 12},
#     {'id': '20-100', 'name': 'Mais de 20% off', 'results': 10}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4',
#      'name': 'São Paulo',
#      'results': 10477},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 2165},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 2072},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 1176},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 963},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 889},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 852},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 624},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 537},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 435},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 315},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 280},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 210},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 180},
#     {'id': 'TUxCUE1BUk81MWVi', 'name': 'Maranhão', 'results': 144},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 141},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 123},
#     {'id': 'TUxCUFBBUkE0M2I4', 'name': 'Paraíba', 'results': 120},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 114},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 93},
#     {'id': 'TUxCUFNFUkUxMmZlOQ', 'name': 'Sergipe', 'results': 90},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 72},
#     {'id': 'TUxCUFBJQUk1NDVj', 'name': 'Piauí', 'results': 69},
#     {'id': 'TUxCUFJPTkExMmU4YQ', 'name': 'Rondônia', 'results': 69},
#     {'id': 'TUxCUFJPUkExODBiMQ', 'name': 'Roraima', 'results': 30},
#     {'id': 'TUxCUEFDUkVkNTU', 'name': 'Acre', 'results': 24},
#     {'id': 'TUxCUEFNQUExNTZlNg', 'name': 'Amapá', 'results': 15}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-1000.0', 'name': 'Até R$1.000', 'results': 6430},
#     {'id': '1000.0-2000.0', 'name': 'R$1.000 a R$2.000', 'results': 6735},
#     {'id': '2000.0-*', 'name': 'Mais de R$2.000', 'results': 9276}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com MercadoPago', 'results': 22441}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'no_interest', 'name': 'Sem juros', 'results': 4265}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 22306},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 12}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 327}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 720}]},
#   {'id': 'until',
#    'name': 'Filtro por data do fim',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Termina hoje', 'results': 132}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicações com vídeo',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Publicações com vídeo', 'results': 414}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 22342}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 9779}]},
#   {'id': 'shipping_quarantine',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'guaranteed_delivery',
#      'name': 'Enviando normalmente',
#      'results': 420}]},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'results': 18702},
#     {'id': '298332', 'name': 'Vivo', 'results': 402},
#     {'id': '298334', 'name': 'TIM', 'results': 240},
#     {'id': '298333', 'name': 'Claro', 'results': 192},
#     {'id': '298331', 'name': 'Oi', 'results': 141},
#     {'id': '303172', 'name': 'Nextel', 'results': 66}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'type': 'range',
#    'values': [{'id': '(*-32GB)', 'name': 'Menos de 32 GB', 'results': 5766},
#     {'id': '[32GB-64GB)', 'name': '32 a 63 GB', 'results': 4752},
#     {'id': '[64GB-128GB)', 'name': '64 a 127 GB', 'results': 6429},
#     {'id': '[128GB-256GB)', 'name': '128 a 255 GB', 'results': 3258},
#     {'id': '[256GB-*)', 'name': '256 GB ou mais', 'results': 2307}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'É Dual SIM', 'results': 873}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 19011},
#     {'id': '2230284', 'name': 'Novo', 'results': 3399},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 189}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '312155', 'name': 'iPhone 7', 'results': 3555},
#     {'id': '312151', 'name': 'iPhone 6s', 'results': 2553},
#     {'id': '312149', 'name': 'iPhone 6', 'results': 1917},
#     {'id': '312144', 'name': 'iPhone 5s', 'results': 1836},
#     {'id': '2244670', 'name': 'iPhone 8', 'results': 1650},
#     {'id': '312157', 'name': 'iPhone 7 Plus', 'results': 1392},
#     {'id': '1164456', 'name': 'iPhone X', 'results': 1152},
#     {'id': '2244673', 'name': 'iPhone 8 Plus', 'results': 1146},
#     {'id': '312154', 'name': 'iPhone SE', 'results': 831},
#     {'id': '312145', 'name': 'iPhone 4s', 'results': 642},
#     {'id': '312152', 'name': 'iPhone 5', 'results': 603},
#     {'id': '5414260', 'name': 'iPhone XR', 'results': 585},
#     {'id': '5414168', 'name': 'iPhone XS Max', 'results': 447},
#     {'id': '312143', 'name': 'iPhone 5c', 'results': 441},
#     {'id': '14610', 'name': 'iPhone 4', 'results': 432},
#     {'id': '7739079', 'name': 'iPhone 11', 'results': 405},
#     {'id': '312153', 'name': 'iPhone 6s Plus', 'results': 399},
#     {'id': '14608', 'name': 'iPhone', 'results': 384},
#     {'id': '312150', 'name': 'iPhone 6 Plus', 'results': 366},
#     {'id': '5414079', 'name': 'iPhone XS', 'results': 321},
#     {'id': '7741677', 'name': 'iPhone 11 Pro Max', 'results': 234},
#     {'id': '7741023', 'name': 'iPhone 11 Pro', 'results': 213},
#     {'id': '14609', 'name': 'iPhone 3GS', 'results': 132},
#     {'id': '5414092', 'name': 'iPhone XS Dual SIM', 'results': 105},
#     {'id': '8230322', 'name': 'iPhone SE (2nd Generation)', 'results': 60},
#     {'id': '5729', 'name': 'XS', 'results': 60},
#     {'id': '14605', 'name': 'iPhone 3G', 'results': 60},
#     {'id': '27251', 'name': '7', 'results': 27},
#     {'id': '84612', 'name': '6 Plus', 'results': 12},
#     {'id': '59000', 'name': '5s', 'results': 12},
#     {'id': '4904058', 'name': '8 Plus', 'results': 12},
#     {'id': '59833', 'name': '6', 'results': 9},
#     {'id': '58054', 'name': 'XR', 'results': 9},
#     {'id': '11043', 'name': '8', 'results': 9}]},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com reconhecimento facial',
#      'results': 2583}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com leitor de impressão digital',
#      'results': 15828}]}]}

# %%
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'{"site_id":"MLB","query":"iphone","paging":{"total":22455,"offset":0,"limit":50,"primary_results":1012},"results":[{"id":"MLB1608016128","site_id":"MLB","title":"iPhone 6s Plus 32 Gb Prata 2 Gb Ram","seller":{"id":259218381,"permalink":"http://perfil.mercadolivre.com.br/F14SHOPP","registration_date":"2017-06-03T18:39:33.000-04:00","car_dealer":false,"real_estate_agency":false,"tags":["normal","credits_profile","messages_as_seller","messages_as_buyer"],"seller_reputation":{"transactions":{"total":1116,"canceled":98,"period":"historic","ratings":{"negative":0.06,"positive":0.92,"neutral":0.02},"completed":1018},"power_seller_status":"silver","metrics":{"claims":{"rate":0,"excluded":{"real_rate":0.0292,"real_value":5},"value":0,"period":"3 months"},"delayed_handling_time":{"rate":0,"excluded":{"real_rate":0.0672,"real_value":8},"value":0,"period":"3 months"},"sales":{"period":"3 months","completed":153},"cancellations":{"rate":0,"excluded":{"real_rate":0,"real_value":2},"value":0,"period":"3 months"}},"protection_end_date":"2020-08-28T00:00:00.000-04:00","real_level":"green_gold","level_id":"5_green"},"address":{"zip_code":"89400000","address":"av perimetral 1071","state":"BR-SC","city":"Porto Uni\xc3\xa3o"}},"price":2360,"currency_id":"BRL","available_quantity":1,"sold_quantity":5,"buying_mode":"buy_it_now","listing_type_id":"gold_pro","stop_time":"2040-07-20T04:00:00.000Z","condition":"new","permalink":"https://www.mercadolivre.com.br/iphone-6s-plus-32-gb-prata-2-gb-ram/p/MLB11712143","thumbnail":"http://mlb-s1-p.mlstatic.com/820963-MLA31347985928_072019-I.jpg","accepts_mercadopago":true,"installments":{"quantity":12,"amount":196.67,"rate":0,"currency_id":"BRL"},"address":{"state_id":"BR-SC","state_name":"Santa Catarina","city_id":"TUxCQ1BPUjE3NWM0","city_name":"Porto Uni\xc3\xa3o"},"shipping":{"free_shipping":true,"mode":"me2","tags":["mandatory_free_shipping"],"logistic_type":"drop_off","store_pick_up":false},"seller_address":{"id":"","comment":"","address_line":"","zip_code":"","country":{"id":"BR","name":"Brasil"},"state":{"id":"BR-SC","name":"Santa Catarina"},"city":{"id":"TUxCQ1BPUjE3NWM0","name":"Porto Uni\xc3\xa3o"},"latitude":"","longitude":""},"attributes":[{"values":[{"id":"9344","name":"Apple","struct":null,"source":1}],"attribute_group_id":"OTHERS","attribute_group_name":"Outros","id":"BRAND","value_struct":null,"value_name":"Apple","source":1,"name":"Marca","value_id":"9344"},{"name":"Condi\xc3\xa7\xc3\xa3o do item","source":3045741222775799,"id":"ITEM_CONDITION","value_id":"2230284","value_name":"Novo","value_struct":null,"values":[{"id":"2230284","name":"Novo","struct":null,"source":3045741222775799}],"attribute_group_id":"OTHERS","attribute_group_name":"Outros"},{"name":"Linha","value_id":"58993","values":[{"source":1,"id":"58993","name":"iPhone","struct":null}],"attribute_group_id":"OTHERS","attribute_group_name":"Outros","id":"LINE","value_name":"iPhone","value_struct":null,"source":1},{"id":"MODEL","value_id":"312153","value_name":"iPhone 6s Plus","value_struct":null,"attribute_group_id":"OTHERS","name":"Modelo","values":[{"name":"iPhone 6s Plus","struct":null,"source":1,"id":"312153"}],"attribute_group_name":"Outros","source":1},{"name":"Modelo do processador","value_id":"6973026","value_name":"Apple A9","source":1,"attribute_group_name":"Outros","id":"PROCESSOR_MODEL","value_struct":null,"values":[{"id":"6973026","name":"Apple A9","struct":null,"source":1}],"attribute_group_id":"OTHERS"},{"value_id":"522894","value_name":"192 g","value_struct":{"number":192,"unit":"g"},"attribute_group_id":"OTHERS","attribute_group_name":"Outros","source":1,"id":"WEIGHT","name":"Peso","values":[{"id":"522894","name":"192 g","struct":{"number":192,"unit":"g"},"source":1}]}],"differential_pricing":{"id":33580182},"original_price":null,"category_id":"MLB1055","official_store_id":null,"domain_id":"MLB-CELLPHONES","catalog_product_id":"MLB11712143","tags":["loyalty_discount_eligible","brand_verified","extended_warranty_eligib ...

# %%
iphone = pd.DataFrame(response.json()['results'])
iphone.head()
# Out:
#               id site_id                                             title  \
# 0  MLB1608016128     MLB               iPhone 6s Plus 32 Gb Prata 2 Gb Ram
# 1  MLB1622965271     MLB  iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram
# 2  MLB1548895261     MLB               iPhone 6s 128 Gb Ouro Rosa 2 Gb Ram
# 3  MLB1560352635     MLB                iPhone XS Max 512 Gb Ouro 4 Gb Ram
# 4  MLB1503227867     MLB     iPhone 7 Plus 128 Gb Preto-brilhante 3 Gb Ram
#
#                                               seller   price currency_id  \
# 0  {'id': 259218381, 'permalink': 'http://perfil....  2360.0         BRL
# 1  {'id': 8710030, 'permalink': 'http://perfil.me...  4100.0         BRL
# 2  {'id': 78613217, 'permalink': 'http://perfil.m...  2850.0         BRL
# 3  {'id': 147172848, 'permalink': 'http://perfil....  7199.0         BRL
# 4  {'id': 61843260, 'permalink': 'http://perfil.m...  4099.0         BRL
#
#    available_quantity  sold_quantity buying_mode listing_type_id  ...  \
# 0                   1              5  buy_it_now        gold_pro  ...
# 1                   1              0  buy_it_now        gold_pro  ...
# 2                   1              0  buy_it_now    gold_special  ...
# 3                   1              0  buy_it_now        gold_pro  ...
# 4                   1              0  buy_it_now        gold_pro  ...
#
#                                       seller_address  \
# 0  {'id': '', 'comment': '', 'address_line': '', ...
# 1  {'id': '', 'comment': '', 'address_line': '', ...
# 2  {'id': '', 'comment': '', 'address_line': '', ...
# 3  {'id': '', 'comment': '', 'address_line': '', ...
# 4  {'id': '', 'comment': '', 'address_line': '', ...
#
#                                           attributes differential_pricing  \
# 0  [{'values': [{'id': '9344', 'name': 'Apple', '...     {'id': 33580182}
# 1  [{'id': 'BRAND', 'name': 'Marca', 'attribute_g...     {'id': 33580182}
# 2  [{'attribute_group_id': 'OTHERS', 'attribute_g...                  NaN
# 3  [{'value_name': 'Apple', 'value_struct': None,...     {'id': 33580182}
# 4  [{'name': 'Marca', 'source': 1, 'values': [{'s...     {'id': 33580182}
#
#   original_price  category_id official_store_id       domain_id  \
# 0            NaN      MLB1055               NaN  MLB-CELLPHONES
# 1            NaN      MLB1055               NaN  MLB-CELLPHONES
# 2            NaN      MLB1055               NaN  MLB-CELLPHONES
# 3            NaN      MLB1055               NaN  MLB-CELLPHONES
# 4            NaN      MLB1055               NaN  MLB-CELLPHONES
#
#   catalog_product_id                                               tags  \
# 0        MLB11712143  [loyalty_discount_eligible, brand_verified, ex...
# 1        MLB15591337  [brand_verified, extended_warranty_eligible, g...
# 2         MLB6127580  [brand_verified, extended_warranty_eligible, g...
# 3        MLB12866634  [brand_verified, good_quality_picture, good_qu...
# 4         MLB6240138  [extended_warranty_eligible, good_quality_pict...
#
#   catalog_listing
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#
# [5 rows x 28 columns]

# %%
iphone.tail(1).T
# Out:
#                                                                      49
# id                                                        MLB1374360266
# site_id                                                             MLB
# title                 iPhone 11 Pro Verde 5,8  4g 64gb Câm 12mp - Mw...
# seller                {'id': 234000251, 'permalink': 'http://perfil....
# price                                                           6226.64
# currency_id                                                         BRL
# available_quantity                                                  250
# sold_quantity                                                         5
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2039-11-22T04:00:00.000Z
# condition                                                           new
# permalink             https://produto.mercadolivre.com.br/MLB-137436...
# thumbnail             http://mlb-s1-p.mlstatic.com/968069-MLB4205760...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 518.89, 'rate': 0, ...
# address               {'state_id': 'BR-SP', 'state_name': 'São Paulo...
# shipping              {'free_shipping': False, 'mode': 'me1', 'tags'...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'id': 'BRAND', 'values': [{'source': 4060709...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   942
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB15150711
# tags                  [brand_verified, good_quality_picture, good_qu...
# catalog_listing                                                     NaN

# %%
iphone_address = iphone.address.apply(pd.Series).head() # transforma em uma series com 4 colunas
iphone_address
# Out:
#   state_id      state_name           city_id           city_name
# 0    BR-SC  Santa Catarina  TUxCQ1BPUjE3NWM0         Porto União
# 1    BR-SP       São Paulo          BR-SP-40  São Caetano do Sul
# 2    BR-BA           Bahia   TUxCQ1NFQThhYjM              Seabra
# 3    BR-SP       São Paulo          BR-SP-44           São Paulo
# 4    BR-MG    Minas Gerais  TUxCQ0JFTGU0ODdm      Belo Horizonte

# %%
# vou transformar minha coluna address em novas 4 colunas, vou desmenbrar apartir do series que foi criado \
# nao esquecendo de apagar a coluna address para as informacoes nao ficarem duplicadas.
iphone_state = iphone.merge(iphone_address,left_index=True, right_index=True).drop('address', axis=1)
iphone_state.head().T
# Out:
#                                                                       0  \
# id                                                        MLB1608016128
# site_id                                                             MLB
# title                               iPhone 6s Plus 32 Gb Prata 2 Gb Ram
# seller                {'id': 259218381, 'permalink': 'http://perfil....
# price                                                              2360
# currency_id                                                         BRL
# available_quantity                                                    1
# sold_quantity                                                         5
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-07-20T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-6s-plus...
# thumbnail             http://mlb-s1-p.mlstatic.com/820963-MLA3134798...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 196.67, 'rate': 0, ...
# shipping              {'free_shipping': True, 'mode': 'me2', 'tags':...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'values': [{'id': '9344', 'name': 'Apple', '...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   NaN
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB11712143
# tags                  [loyalty_discount_eligible, brand_verified, ex...
# catalog_listing                                                    True
# state_id                                                          BR-SC
# state_name                                               Santa Catarina
# city_id                                                TUxCQ1BPUjE3NWM0
# city_name                                                   Porto União
#
#                                                                       1  \
# id                                                        MLB1622965271
# site_id                                                             MLB
# title                  iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram
# seller                {'id': 8710030, 'permalink': 'http://perfil.me...
# price                                                              4100
# currency_id                                                         BRL
# available_quantity                                                    1
# sold_quantity                                                         0
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-08-19T14:49:16.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-se-2nd-...
# thumbnail             http://mlb-s2-p.mlstatic.com/917693-MLA4234849...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 341.67, 'rate': 0, ...
# shipping              {'free_shipping': True, 'mode': 'me2', 'tags':...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'id': 'BRAND', 'name': 'Marca', 'attribute_g...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   NaN
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB15591337
# tags                  [brand_verified, extended_warranty_eligible, g...
# catalog_listing                                                    True
# state_id                                                          BR-SP
# state_name                                                    São Paulo
# city_id                                                        BR-SP-40
# city_name                                            São Caetano do Sul
#
#                                                                       2  \
# id                                                        MLB1548895261
# site_id                                                             MLB
# title                               iPhone 6s 128 Gb Ouro Rosa 2 Gb Ram
# seller                {'id': 78613217, 'permalink': 'http://perfil.m...
# price                                                              2850
# currency_id                                                         BRL
# available_quantity                                                    1
# sold_quantity                                                         0
# buying_mode                                                  buy_it_now
# listing_type_id                                            gold_special
# stop_time                                      2040-05-31T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-6s-128-...
# thumbnail             http://mlb-s2-p.mlstatic.com/819171-MLA3134728...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 270.73, 'rate': 13....
# shipping              {'free_shipping': True, 'mode': 'me2', 'tags':...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'attribute_group_id': 'OTHERS', 'attribute_g...
# differential_pricing                                                NaN
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   NaN
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                           MLB6127580
# tags                  [brand_verified, extended_warranty_eligible, g...
# catalog_listing                                                    True
# state_id                                                          BR-BA
# state_name                                                        Bahia
# city_id                                                 TUxCQ1NFQThhYjM
# city_name                                                        Seabra
#
#                                                                       3  \
# id                                                        MLB1560352635
# site_id                                                             MLB
# title                                iPhone XS Max 512 Gb Ouro 4 Gb Ram
# seller                {'id': 147172848, 'permalink': 'http://perfil....
# price                                                              7199
# currency_id                                                         BRL
# available_quantity                                                    1
# sold_quantity                                                         0
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-06-11T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-xs-max-...
# thumbnail             http://mlb-s2-p.mlstatic.com/864619-MLA4209292...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 599.92, 'rate': 0, ...
# shipping              {'free_shipping': True, 'mode': 'me2', 'tags':...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'value_name': 'Apple', 'value_struct': None,...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   NaN
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB12866634
# tags                  [brand_verified, good_quality_picture, good_qu...
# catalog_listing                                                    True
# state_id                                                          BR-SP
# state_name                                                    São Paulo
# city_id                                                        BR-SP-44
# city_name                                                     São Paulo
#
#                                                                       4
# id                                                        MLB1503227867
# site_id                                                             MLB
# title                     iPhone 7 Plus 128 Gb Preto-brilhante 3 Gb Ram
# seller                {'id': 61843260, 'permalink': 'http://perfil.m...
# price                                                              4099
# currency_id                                                         BRL
# available_quantity                                                    1
# sold_quantity                                                         0
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-04-17T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-7-plus-...
# thumbnail             http://mlb-s2-p.mlstatic.com/686636-MLA4067841...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 341.58, 'rate': 0, ...
# shipping              {'free_shipping': True, 'mode': 'me2', 'tags':...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'name': 'Marca', 'source': 1, 'values': [{'s...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   NaN
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                           MLB6240138
# tags                  [extended_warranty_eligible, good_quality_pict...
# catalog_listing                                                    True
# state_id                                                          BR-MG
# state_name                                                 Minas Gerais
# city_id                                                TUxCQ0JFTGU0ODdm
# city_name                                                Belo Horizonte

# %%
iphone_state.loc[iphone_state.state_name=='Minas Gerais'].price.mean()
# Out:
# 4099.0

# %%
iphone_state.loc[iphone_state.state_name=='Minas Gerais'].price.count()
# Out:
# 1

# %%
print('Contagem:', iphone_state.loc[iphone_state.state_name=='Minas Gerais',:].price.count())
print('Média:', round(iphone_state.loc[iphone_state.state_name=='Minas Gerais',:].price.mean(),2))
# Out:
# Contagem: 1
# Média: 4099.0

# %%
response = requests.get(" https://api.mercadolibre.com/sites/MLA/domain_discovery/search?limit=1&q=celular%20iphone")
iphone = response.json()
print(json.dumps(response.json(), sort_keys=True, indent=7))
# Out:
# [
#        {
#               "attributes": [
#                      {
#                             "id": "BRAND",
#                             "name": "Marca",
#                             "value_id": "9344",
#                             "value_name": "Apple"
#                      },
#                      {
#                             "id": "LINE",
#                             "name": "L\u00ednea",
#                             "value_id": "58993",
#                             "value_name": "iPhone"
#                      },
#                      {
#                             "id": "MODEL",
#                             "name": "Modelo",
#                             "value_id": "14608",
#                             "value_name": "iPhone"
#                      }
#               ],
#               "category_id": "MLA1055",
#               "category_name": "Celulares y Smartphones",
#               "domain_id": "MLA-CELLPHONES",
#               "domain_name": "Celulares"
#        }
# ]

# %%
response = requests.get(" https://api.mercadolibre.com/sites/MLA/domain_discovery/search?limit=1&q=celular%20iphone")
iphone_1 = pd.DataFrame

# %% [markdown]
# ### NBA
# Vamos utilizar a API da NBA para entender os principais jogadores das finais.<br>
# <strong>O que fazer</strong>: consulta a API através de módulos e funções de uma biblioteca<br>
# <strong>Documentação</strong>: https://github.com/swar/nba_api<br>
# <strong>Objetivo</strong>: Qual a distância média de arremessos dos jogadores Kawhi Leonard e Stephen Curry na temporada 18/19<br>
# <strong>Desafio</strong>: Plote um gráfico comparando o perfil de localização dos arremessos.<br>
# <strong>Dica</strong>: A biblioteca tem muitos módulos e funções. Seja objetivo em encontrar aqueles que interessam ao problema

# %% [markdown]
# ___

# %% [markdown]
# ## APIs com autenticação

# %% [markdown]
# ### Spotify
# Vamos utilizar a API do Spotify para experimentar o processo de autenticação.<br>
# <strong>O que fazer</strong>: estudando a estrutura da API para conseguir a informação desejada<br>
# <strong>Documentação</strong>: https://developer.spotify.com/documentation/web-api/<br>
# <strong>Objetivo</strong>: Qual a popularidade média da cantora Teresa Cristina e sua música mais popular?<br>
# <strong>Dica</strong>: É crítico entender a estrutura da API (quais são as possíveis requisições e quais dados cada uma entrega). Utilize o console (https://developer.spotify.com/console/) para facilitar esse entendimento.

# %% [markdown]
# ___

# %% [markdown]
# ## APIs com autenticação complexa (e/ou billing)

# %% [markdown]
# ### Google Agenda
#
# Vamos utilizar a API do Google Agenda para experimentar o processo de autenticação do Google.<br>
# <strong>O que fazer</strong>: entender aspectos da autenticação por crendenciais e tokens.<br>
# <strong>Documentação</strong>: https://developers.google.com/calendar/v3/reference<br>
# <strong>Objetivo</strong>: Trazer os próximos 4 eventos na sua agenda do Google.<br>
# <strong>Dica</strong>: o processo é complexo, mas o Google disponibiliza vários "quick start projects" funcionais. Para esse exercício podem seguir esse: https://developers.google.com/calendar/quickstart/python<br>
# <strong>Bibliotecas</strong>: pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %% [markdown]
# ### Twitter
# Explorar o serviço.<br>

# %% [markdown]
# ___

# %% [markdown]
# # Próximos passos
#
# Há milhares de APIs e cada uma delas tem um jeito próprio de lidar, ou seja, de fazer nossas solicitações de dados e envio de dados.
#
# Uma das muitas vantagens das APIs é tornar as soluções encaixaveis e reutilizaveis em outros programas.
#
# Na nossa área de ciência de dados, não só utilizamos APIs para consultar dados mas muitas vezes para fornecer nossa aplicação de machine learning como um serviço.
#
# Há várias plataformas que monitoram as inúmeras APIs disponíveis:
# - https://99apis.com/home
# - https://www.programmableweb.com/
# - https://rapidapi.com/
#
# Há também softwares utilizados na administração de APIs (tanto para consultas quanto para publicação). Um dos mais famosos é o Postman (https://www.postman.com/)
