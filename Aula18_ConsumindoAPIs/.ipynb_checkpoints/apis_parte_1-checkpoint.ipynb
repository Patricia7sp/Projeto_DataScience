# %% [markdown]
# # Introdução

# %% [markdown]
# Instruções gerais:
# - Vocês precisarão instalar provavelmente apenas uma biblioteca para essa aula (nba_api). Para os exercícios mais avançados, tem um processo mais complexo de instalação de aplicações e bibliotecas (a saber: google-api-python-client, google-auth-httplib2, google-auth-oauthlib)
# - Precisaremos ter contas em alguns dos serviços que iremos utilizar se der tempo de chegar nos exercícios mais avançados. Tentem criar suas contas antes da aula, pois alguns são bastante complexos. Se não conseguirem não tem problema, aprenderemos bastante já com os serviços mais básicos.
#   - Para os exercícios intermediários, precisaremos de uma conta no Spotify (gratuita é suficiente) e uma conta no Youtube
#   - Para os exercícios avançados serão necessários uma conta no Google API, no Google Cloud Platform - GCP e no Twitter (a proposta é passar pelo processo de criação de conta com vocês)

# %% [markdown]
# # TEORIA

# %% [markdown]
# ## API (Application Programming Interface)

# %% [markdown]
# Antes de falarmos de API, precisamos entender como a internet funciona e porque devemos separar as partes de um software.

# %% [markdown]
# ## Como funciona o protocolo HTTP
#
# A internet trafega através do protocolo **HTTP (*Hypertext Transfer Protocol*)**. O protocolo HTTP foi criado por **Tim Berners-Lee**, o criador da web, enquanto ele trabalhava na CERN em 1989 (sua equipe e ele também foram responsáveis pelo HTML).
#
# O HTTP possui duas entidades básicas: a **Request (pedido)** e a **Response (resposta)**
#
# Sempre que entramos em uma página, enviamos uma request para o servidor do site e esperamos uma response com o HTML da página.

# %% [markdown]
# Sempre que enviamos um ***Request (pedido)*** devemos especificar um método. A tabela abaixo cita os métodos mais comuns e explica brevemente o objetivo de cada um:
#
# | Método |        Objetivo       |
# |:------:|:---------------------:|
# | GET    | Obter informações     |
# | POST   | Salvar informações    |
# | PUT    | Atualizar informações |
# | DELETE | Deletar informações   |
#
# Todos eles são comumente utilizados por APIs.
#
# O método ***GET*** é o que seu navegador usa para baixar o HTML da página.
#
# O metódo ***POST*** também é muito utilizado sempre que você envia algum formulário em um site.
#
# Além do método, as requisições também possuem um **header**:
#
# O **Header (cabeçalho)** tem a função de dizer para o servidor diversos dados sobre quem fez a solicitação. Dessa forma, o servidor consegue até permitir que você veja mais informações dependendo do seu nível de acesso.

# %% [markdown]
# ### PROTOCOLO DE COMUNICAÇÃO HTTP
# <img src="https://www.pubnub.com/wp-content/uploads/2014/11/HTTP-LONG-POLLING.png">
# <br>
# Os clientes, nossos computadores, conseguem acessar páginas e aplicações na internet atravez deste protocolo, que responde as requisições com arquivos de acordo com seu nível de acesso e com o que foi solicitado.
# Se você acessar o site da Digital House por exemplo e pedir para inspecionar (no Chrome `Ctrl+Shift+i`) os dados de rede, vai ver todos as solicitações e respostas do seu navegador ao servidor.
# <br>
# O resultado será algo parecido com isso:
# <img src="https://developer.chrome.com/devtools/images/network-panel.png">

# %% [markdown]
# ## Códigos de status
# A solicitação que acabamos de fazer tinha um código de status de 200. Os códigos de status são retornados com cada solicitação feita para um servidor da web. Códigos de status indicam informações sobre o que aconteceu com uma solicitação. Aqui estão alguns códigos que são relevantes para solicitações GET :
#
# - 200 - tudo correu bem, e o resultado foi devolvido (se houver)
# - 301- o servidor está redirecionando você para um terminal diferente. Isso pode acontecer quando uma empresa troca nomes de domínio ou um nome de terminal é alterado.
# - 401- o servidor acha que você não está autenticado. Isso acontece quando você não envia as credenciais corretas para acessar uma API (falaremos sobre autenticação em uma postagem posterior).
# - 400- o servidor acha que você fez um pedido incorreto. Isso pode acontecer quando você não envia os dados corretos, entre outras coisas.
# - 403 - o recurso que você está tentando acessar é proibido - você não tem as permissões certas para visualizá-lo.
# - 404 - o recurso que você tentou acessar não foi encontrado no servidor.
#
# Se tentarmos acessar um site ou endereço que não existe, receberemos o código acima.

# %%
import requests

response = requests.get("http://www.globo.com/cursos/data_science")
print(response.status_code)
# Out:
# 404

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json")
print(response.status_code)
# Out:
# 400

# %%
# This is the latitude and longitude of New York City.
parameters = {"q": 'data science'}

# Make a get request with the parameters.
response = requests.get("http://google.com/search", params=parameters)
print(response.status_code)

# Equivalente a URL: http://google.com/search?q=data+science
# Out:
# 200

# %% [markdown]
# ___

# %% [markdown]
# ## O que é uma API?

# %% [markdown]
# Podemos dizer que uma API é como se fosse uma página da web só que para computadores. Só eles conseguirem acessar, ler e interagir da maneira adequada com as APIs.
#
# Ao trabalhar com projetos que envolvem dados, é muito comum vocês utilizarão APIs tanto internas (fornecidas pelas próprias empresas em que vocês trabalham) quanto externas.
#
# APIs são uma das principais formas para se obter dados que devem ser analisados.
#
# <center>
# <img src="https://cdn-images-1.medium.com/max/1600/1*CkynRe-J1FVnUAk7JmOTdQ.gif" alt="drawing" width="600px"></center>

# %% [markdown]
# ### Por que acessar uma API ao invez de um banco de dados diretamente?
#
# Porque o mundo está cheio de pessoas mal intencionadas e ao dar acesso direto ao banco de dados você está correndo risco de ter seus dados apagados, alterados ou que as pessoas tenham acesso a dados que deveriam ser confidenciais.
#
# É uma forma de separar, controlar e até multiplicar os acessos a sistemas de forma organizada.
# Imagine se cada cliente de um restaurante fosse fazer os pedidos direto ao Chef na cozinha, é provável que os pedidos saiam errados, fora de ordem ou o Chef fique estressado, por isso existe o garçom que faz o papel de levar os pedidos e trazer a comida organizando uma fila de pedidos.
# A API faz exatamente isso, controlando o que pedir e para quem pedir.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*Elr2TpvMI7xfSack20B6bA.png">

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='s7wmiS2mSXY'

YouTubeVideo(id=id,width=600,height=300)

# %% [markdown]
# Mas por que usar uma API em vez de um conjunto de dados estáticos que você pode baixar? As APIs são úteis nos seguintes casos:
#
# - Os dados estão mudando rapidamente. Um exemplo disso são os dados do preço das ações. Não faz muito sentido gerar um conjunto de dados e baixá-lo a cada minuto - isso demandará muita largura de banda e será bastante lento.
# - Você quer um pequeno pedaço de um conjunto muito maior de dados. Comentários do Reddit são um exemplo. E se você quiser apenas puxar seus próprios comentários no Reddit? Não faz muito sentido baixar todo o banco de dados Reddit, depois filtrar apenas seus próprios comentários.
# - Há computação repetida envolvida. Spotify tem uma API que pode dizer o gênero de uma peça musical. Você poderia, teoricamente, criar seu próprio classificador e usá-lo para categorizar a música, mas nunca terá tantos dados quanto o Spotify.
#
# Em casos como os acima, uma API é a solução certa.
#
# Agora, vamos consultar uma API simples para recuperar dados sobre a Estação Espacial Internacional (ISS). O uso de uma API nos poupará tempo e esforço ao fazermos todos os cálculos.
# Então, faremos uma solicitação GET para http://api.open-notify.org/iss-passum terminal que não existe, de acordo com a documentação da API .

# %%
response = requests.get("http://api.open-notify.org/iss-pass")
print(response.status_code)
# Out:
# 404

# %%
response = requests.get("http://api.open-notify.org/iss-now.json")
print(response.status_code)
# Out:
# 200

# %%
response.text
# Out:
# '{"timestamp": 1598308337, "iss_position": {"longitude": "-127.0597", "latitude": "4.4769"}, "message": "success"}'

# %%
# This is the latitude and longitude of New York City.
parameters = {"lat": 40.71, "lon": -74}

# Make a get request with the parameters.
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)
print(response.status_code)
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74'

# %%
response.content
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1598308260, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 599, \n      "risetime": 1598345081\n    }, \n    {\n      "duration": 647, \n      "risetime": 1598350853\n    }, \n    {\n      "duration": 579, \n      "risetime": 1598356733\n    }, \n    {\n      "duration": 570, \n      "risetime": 1598362608\n    }, \n    {\n      "duration": 640, \n      "risetime": 1598368426\n    }\n  ]\n}\n'

# %%
type(response.content)
# Out:
# bytes

# %% [markdown]
# ___

# %% [markdown]
# ## XML × JSON × YAML
#
# Anos atrás a comunicação entre serviços se dava por XML usando o padrão SOAP. Na era da mobilidade, JSON passou a ser largamente usado. Hoje, aos poucos está sendo substituido por YAML, que é similar,  porém mais amigável para leitura por humanos.
#
# <img src="XML×JSON×YAML.png" width="150%"></img>
#
# A estrutura de um json se parece muito com os dicionários em Python
#
# Ele foi feito para que máquinas entendam seus dados e os utilizem como quiser.
#
# Outra característica das APIs REST é a **divisão dos recursos**. Por exemplo:
#
# https://jsonplaceholder.typicode.com/users/1
#
# Ao abrirmos esta URL estamos fazendo um GET (o navegador executa o GET) para obtermos informações do usuário (/users) com código 1 (/1). Podemos trocar o código do usuário para buscar outros usuários.
#
# Também podemos pedir todos os usuários digitando:
#
# https://jsonplaceholder.typicode.com/users

# %% [markdown]
# ## Trabalhando com dados JSON
# Você deve ter notado que o conteúdo da resposta anterior era um string (embora tenha sido mostrado como um objeto, podemos facilmente converter o conteúdo em uma string usando response.content.decode("utf-8")).
#
# As strings são a forma como passamos as informações para as APIs, mas é difícil obter as informações que queremos delas. Como decodificar a string que recebemos e trabalhar com ela em Python?
#
# O JSON é uma maneira de codificar estruturas de dados, como listas e dicionários, para seqüências de caracteres que garantem que elas sejam facilmente legíveis por máquinas. JSON é o formato principal no qual os dados são passados para as APIs e a maioria dos servidores de API envia suas respostas nesse formato.
#
# O Python tem um ótimo suporte a JSON, com a biblioteca 'json'. Ele faz parte da biblioteca padrão, portanto, não precisamos instalar nada para usá-lo. Podemos converter listas e dicionários em JSON e converter strings em listas e dicionários . No caso dos nossos dados do ISS Pass, é um dicionário codificado para uma string no formato JSON.
#
# A biblioteca json possui dois métodos principais:
#
# - dumps - Utiliza um objeto Python e o converte em uma string.
# - loads - Leva uma string JSON e a converte em um objeto Python.

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1598308260,
#   'latitude': 40.71,
#   'longitude': -74.0,
#   'passes': 5},
#  'response': [{'duration': 599, 'risetime': 1598345081},
#   {'duration': 647, 'risetime': 1598350853},
#   {'duration': 579, 'risetime': 1598356733},
#   {'duration': 570, 'risetime': 1598362608},
#   {'duration': 640, 'risetime': 1598368426}]}

# %%
type(response.json())
# Out:
# dict

# %%
meu_dicionario = response.json()
meu_dicionario
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1598308260,
#   'latitude': 40.71,
#   'longitude': -74.0,
#   'passes': 5},
#  'response': [{'duration': 599, 'risetime': 1598345081},
#   {'duration': 647, 'risetime': 1598350853},
#   {'duration': 579, 'risetime': 1598356733},
#   {'duration': 570, 'risetime': 1598362608},
#   {'duration': 640, 'risetime': 1598368426}]}

# %%
meu_request = meu_dicionario['request']
meu_request
# Out:
# {'altitude': 100,
#  'datetime': 1598308260,
#  'latitude': 40.71,
#  'longitude': -74.0,
#  'passes': 5}

# %%
meu_request['datetime']
# Out:
# 1598308260

# %%
response.json()['request']['datetime']
# Out:
# 1598308260

# %%
import json
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "request": {
#         "altitude": 100,
#         "datetime": 1598308260,
#         "latitude": 40.71,
#         "longitude": -74.0,
#         "passes": 5
#     },
#     "response": [
#         {
#             "duration": 599,
#             "risetime": 1598345081
#         },
#         {
#             "duration": 647,
#             "risetime": 1598350853
#         },
#         {
#             "duration": 579,
#             "risetime": 1598356733
#         },
#         {
#             "duration": 570,
#             "risetime": 1598362608
#         },
#         {
#             "duration": 640,
#             "risetime": 1598368426
#         }
#     ]
# }

# %% [markdown]
# ## Parâmetros de consulta
# Você verá que, no último exemplo, recebemos um código de status '400', que indica uma solicitação incorreta. Se você observar a documentação da API do OpenNotify, veremos que o ponto de extremidade do ISS Pass requer dois parâmetros.
#
# O ponto de extremidade do ISS Pass retorna quando o ISS passará em seguida sobre um determinado local na Terra. Para calcular isso, precisamos passar as coordenadas do local para a API. Fazemos isso passando dois parâmetros - latitude e longitude.
#
# Podemos fazer isso adicionando um argumento opcional de palavra-chave params, a nosso pedido. Neste caso, existem dois parâmetros que precisamos passar:
#
# - lat - A latitude do local que queremos.
# - lon - A longitude do local que queremos.
#
# Podemos criar um dicionário com esses parâmetros e depois passá-los para a função 'requests.get'.
#
# Nós também podemos fazer a mesma coisa diretamente, adicionando os parâmetros de consulta para a url, como este: http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74.
#
# É quase sempre preferível configurar os parâmetros como um dicionário, porque requests cuida de algumas coisas que surgem, como formatar corretamente os parâmetros da consulta.
#
# Faremos uma solicitação usando as coordenadas da cidade de São Paulo e veremos a resposta que recebermos.
#
# __São Paulo__<br>
# Latitude: -23.68<br>
# Longitude: -46.87

# %%
# Este comando busca os mesmos dados que o comando que usamos para buscar os dados de São Paulo acima
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=-23.68&lon=-46.87")
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "request": {
#         "altitude": 100,
#         "datetime": 1598306270,
#         "latitude": -23.68,
#         "longitude": -46.87,
#         "passes": 5
#     },
#     "response": [
#         {
#             "duration": 415,
#             "risetime": 1598321393
#         },
#         {
#             "duration": 656,
#             "risetime": 1598327109
#         },
#         {
#             "duration": 410,
#             "risetime": 1598333013
#         },
#         {
#             "duration": 501,
#             "risetime": 1598375373
#         },
#         {
#             "duration": 648,
#             "risetime": 1598381087
#         }
#     ]
# }

# %% [markdown]
# ## Uma mesma API pode conter diversas **ROTAS** ou endpoints diferentes
#
# Como o servidor faz para saber o que está sendo pedido na solicitação? Isso é especificado na URL (Uniform Resource Locator), uma espécie de caminho que indica onde um recurso pode ser encontrado.
#
# - protocol: Indica o protocolo que será utilizado para acessar (HTTP, FTP, HTTPS)
# - host: Indica como encontrar na rede (local ou internet) o servidor que tem o recurso
# - port: Indica em qual porta o servidor está escutando. A 'porta' de um IP é o que permite que um computador se comunique simultaneamente com outros. Cada comunicação requer uma porta (são ao todo 65.535)
# - path: Indica o caminho para localizar o recurso dentro do servidor. Como se fossem pastas do navegador de arquivos
# - query: Indica qual é a consulta que está sendo realizada. Inclui quais são os argumentos desejados ou necessários, bem como os valores a ser utilizado para cada argumento
#
# <img src="http://digitalad.com.br/DH/Picture1.png">
# <br>
#
# Por exemplo, podemos usar a funcionalidade dessa API da ISS para descobrir todas as pessoas que estão em orbita.

# %%
# Get the response from the API endpoint.
response = requests.get("http://api.open-notify.org/astros.json")
data = response.json()
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "number": 3,
#     "people": [
#         {
#             "craft": "ISS",
#             "name": "Chris Cassidy"
#         },
#         {
#             "craft": "ISS",
#             "name": "Anatoly Ivanishin"
#         },
#         {
#             "craft": "ISS",
#             "name": "Ivan Vagner"
#         }
#     ]
# }

# %% [markdown]
# Para conseguir capturar um dado específico do JSON, basta fazer as referências como se buscasse em um dicionário, identificando o tipo de cada elemento ou nível do dicionário (exemplo: um dicionário de listas, um dicionário de dicionários, etc).

# %%
print('Total de astronautas:', data["number"])
print('Primeiro da lista:', data["people"][0])
print('Nome do 1o da lista:', data["people"][0]['name'])
# Out:
# Total de astronautas: 3
# Primeiro da lista: {'craft': 'ISS', 'name': 'Chris Cassidy'}
# Nome do 1o da lista: Chris Cassidy

# %%
data['people']
# Out:
# [{'craft': 'ISS', 'name': 'Chris Cassidy'},
#  {'craft': 'ISS', 'name': 'Anatoly Ivanishin'},
#  {'craft': 'ISS', 'name': 'Ivan Vagner'}]

# %% [markdown]
# ___

# %% [markdown]
# # PRÁTICA

# %% [markdown]
# ## Acesso simples

# %% [markdown]
# ### Mercado Livre
# Vamos utilizar a API do MercadoLivre para consultar anúncios<br>
# <strong>O que fazer</strong>: acesso, download, tratamento e cálculo<br>
# <strong>Documentação</strong>: https://developers.mercadolivre.com.br/pt_br/api-docs-pt-br<br>
# <strong>Objetivo</strong>: Qual o preço médio dos anúncios de iphones em Minas Gerais<br>
# <strong>Desafio</strong>: Resolve o exercício através de uma função para permitir realizar a mesma consulta com outros itens ou estados<br>
# <strong>Dica</strong>: Carregue seus dados para um dataframe para facilitar a manipulação dos dados

# %%
import sys
import json
import codecs
import urllib.request
import urllib.parse
import pandas as pd

def usage():
    print('Uso: {0} "PRODUTO"'.format(sys.argv[0]))
    print('Busque um produto por vez')
    sys.exit(1)


def busca(item):
    url = 'https://api.mercadolibre.com/sites/MLB/search?q={0}'.format(item)
    opener = urllib.request.build_opener()
    opener.addheaders = [
        ('User-agent',
         "Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201")]

    with opener.open(url) as fd:
        content = fd.read()
        encoding = fd.info().get_content_charset()
        content = content.decode(encoding)

    dic = json.loads(content)
    #utf-8

# encoding
# 0001 = 'A' (encoding 1)
# 0001 = '$' (encoding 2)

    
    return dic

# %%
temp = requests.get('https://api.mercadolibre.com/sites/MLB/search?q=iphone')

# %%
temp.json()
# Out:
# {'site_id': 'MLB',
#  'query': 'iphone',
#  'paging': {'total': 22344, 'offset': 0, 'limit': 50, 'primary_results': 1015},
#  'results': [{'id': 'MLB1585945069',
#    'site_id': 'MLB',
#    'title': 'iPhone SE (2nd Generation) 128 Gb Branco 3 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 11736,
#       'completed': 268893,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'neutral': 0.04, 'positive': 0.94},
#       'total': 280629},
#      'metrics': {'sales': {'period': '3 months', 'completed': 59626},
#       'claims': {'period': '3 months', 'rate': 0.0251, 'value': 1619},
#       'delayed_handling_time': {'period': '3 months', 'rate': 0, 'value': 0},
#       'cancellations': {'period': '3 months', 'rate': 0.0105, 'value': 682}}},
#     'address': {'address': 'Rodovia Anhaguera Km 37',
#      'city': 'Cajamar',
#      'state': 'BR-SP',
#      'zip_code': '07789100'}},
#    'price': 3715.46,
#    'currency_id': 'BRL',
#    'available_quantity': 200,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-02T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-se-2nd-generation-128-gb-branco-3-gb-ram/p/MLB15591335',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/983659-MLA42348493114_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 309.62,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'values': [{'name': 'Apple GPU',
#        'struct': None,
#        'source': 1,
#        'id': '7741027'}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Condição do item',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}]},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'value_id': '58993'},
#     {'id': 'MODEL',
#      'value_id': '8230322',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_name': 'iPhone SE (2nd Generation)',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8230322',
#        'name': 'iPhone SE (2nd Generation)'}],
#      'source': 1},
#     {'id': 'PROCESSOR_MODEL',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15591335',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1608016128',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s Plus 32 Gb Prata 2 Gb Ram',
#    'seller': {'id': 259218381,
#     'permalink': 'http://perfil.mercadolivre.com.br/F14SHOPP',
#     'registration_date': '2017-06-03T18:39:33.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'silver',
#      'real_level': 'green_gold',
#      'protection_end_date': '2020-08-28T00:00:00.000-04:00',
#      'transactions': {'canceled': 98,
#       'completed': 1017,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.02, 'positive': 0.92},
#       'total': 1115},
#      'metrics': {'sales': {'period': '3 months', 'completed': 152},
#       'claims': {'period': '3 months',
#        'rate': 0,
#        'value': 0,
#        'excluded': {'real_value': 5, 'real_rate': 0.0294}},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0,
#        'value': 0,
#        'excluded': {'real_value': 8, 'real_rate': 0.0672}},
#       'cancellations': {'period': '3 months',
#        'rate': 0,
#        'value': 0,
#        'excluded': {'real_value': 2, 'real_rate': 0}}}},
#     'address': {'address': 'av perimetral 1071',
#      'city': 'Porto União',
#      'state': 'BR-SC',
#      'zip_code': '89400000'}},
#    'price': 2360,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-plus-32-gb-prata-2-gb-ram/p/MLB11712143',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/820963-MLA31347985928_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 196.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SC',
#     'state_name': 'Santa Catarina',
#     'city_id': 'TUxCQ1BPUjE3NWM0',
#     'city_name': 'Porto União'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SC', 'name': 'Santa Catarina'},
#     'city': {'id': 'TUxCQ1BPUjE3NWM0', 'name': 'Porto União'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'value_struct': None,
#      'values': [{'source': 3045741222775799,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}],
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone'},
#     {'id': 'MODEL',
#      'source': 1,
#      'value_name': 'iPhone 6s Plus',
#      'value_struct': None,
#      'values': [{'name': 'iPhone 6s Plus',
#        'struct': None,
#        'source': 1,
#        'id': '312153'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_id': '312153'},
#     {'value_id': '6973026',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB11712143',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1622965271',
#    'site_id': 'MLB',
#    'title': 'iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram',
#    'seller': {'id': 8710030,
#     'permalink': 'http://perfil.mercadolivre.com.br/-DANSL-',
#     'registration_date': '2002-03-27T00:00:00.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': None,
#      'transactions': {'canceled': 32,
#       'completed': 385,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'neutral': 0.03, 'positive': 0.97},
#       'total': 417},
#      'metrics': {'sales': {'period': '3 months', 'completed': 132},
#       'claims': {'period': '3 months', 'rate': 0, 'value': 0},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0.0076,
#        'value': 1},
#       'cancellations': {'period': '3 months', 'rate': 0, 'value': 0}}},
#     'address': {'address': 'Avenida Lemos Monteiro 71',
#      'city': 'São Caetano do Sul',
#      'state': 'BR-SP',
#      'zip_code': '09540500'}},
#    'price': 4100,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-19T14:49:16.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-se-2nd-generation-256-gb-preto-3-gb-ram/p/MLB15591337',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/917693-MLA42348499125_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 341.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-40',
#     'city_name': 'São Caetano do Sul'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-40', 'name': 'São Caetano do Sul'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha'},
#     {'id': 'MODEL',
#      'value_id': '8230322',
#      'value_struct': None,
#      'name': 'Modelo',
#      'value_name': 'iPhone SE (2nd Generation)',
#      'values': [{'id': '8230322',
#        'name': 'iPhone SE (2nd Generation)',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15591337',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1622334438',
#    'site_id': 'MLB',
#    'title': 'iPhone 8 256 Gb Prata 2 Gb Ram',
#    'seller': {'id': 336592499,
#     'permalink': 'http://perfil.mercadolivre.com.br/SICE+DIGITAL',
#     'registration_date': '2018-07-14T07:33:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': None,
#      'transactions': {'canceled': 137,
#       'completed': 1071,
#       'period': 'historic',
#       'ratings': {'negative': 0.04, 'neutral': 0.01, 'positive': 0.95},
#       'total': 1208},
#      'metrics': {'sales': {'period': '3 months', 'completed': 1037},
#       'claims': {'period': '3 months', 'rate': 0.0222, 'value': 26},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0.0018,
#        'value': 2},
#       'cancellations': {'period': '3 months', 'rate': 0, 'value': 0}}},
#     'address': {'address': 'Rua João de Barro SN',
#      'city': 'Campinas',
#      'state': 'BR-SP',
#      'zip_code': '13097158'}},
#    'price': 3499.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-03T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-8-256-gb-prata-2-gb-ram/p/MLB8752434',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/694892-MLA42533131046_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 291.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'source': 1},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 2860837171021627,
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627}]},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'id': 'LINE',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'MODEL',
#      'value_id': '2244670',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'value_name': 'iPhone 8',
#      'value_struct': None,
#      'values': [{'id': '2244670',
#        'name': 'iPhone 8',
#        'struct': None,
#        'source': 1}]},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A11 Bionic',
#      'value_struct': None,
#      'source': 1,
#      'value_id': '6936434',
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752434',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1560352635',
#    'site_id': 'MLB',
#    'title': 'iPhone XS Max 512 Gb Ouro 4 Gb Ram',
#    'seller': {'id': 147172848,
#     'permalink': 'http://perfil.mercadolivre.com.br/FIVENDASONLINE',
#     'registration_date': '2013-10-08T22:59:50.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 714,
#       'completed': 10918,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'neutral': 0.03, 'positive': 0.94},
#       'total': 11632},
#      'metrics': {'sales': {'period': '3 months', 'completed': 1705},
#       'claims': {'period': '3 months', 'rate': 0.0215, 'value': 41},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0.0698,
#        'value': 114},
#       'cancellations': {'period': '3 months', 'rate': 0.0052, 'value': 10}}},
#     'address': {'address': 'José Da Costa De Andrade 105',
#      'city': 'São Paulo',
#      'state': 'BR-SP',
#      'zip_code': '03572340'}},
#    'price': 7199,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-06-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-max-512-gb-ouro-4-gb-ram/p/MLB12866634',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/864619-MLA42092921659_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 599.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Apple',
#      'value_struct': None,
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}]},
#     {'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799,
#      'value_id': '2230284',
#      'value_name': 'Novo'},
#     {'value_id': '58993',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '5414168',
#        'name': 'iPhone XS Max'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '5414168',
#      'value_name': 'iPhone XS Max',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'value_id': '6927771',
#      'value_name': 'Apple A12 Bionic',
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866634',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1503227867',
#    'site_id': 'MLB',
#    'title': 'iPhone 7 Plus 128 Gb Preto-brilhante 3 Gb Ram',
#    'seller': {'id': 61843260,
#     'permalink': 'http://perfil.mercadolivre.com.br/UAIPLACEBH',
#     'registration_date': '2008-12-06T08:42:58.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '3_yellow',
#      'power_seller_status': None,
#      'transactions': {'canceled': 21,
#       'completed': 297,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'neutral': 0.02, 'positive': 0.98},
#       'total': 318},
#      'metrics': {'sales': {'period': '60 months', 'completed': 297},
#       'claims': {'period': '60 months', 'rate': 0.0157, 'value': 5},
#       'delayed_handling_time': {'period': '60 months',
#        'rate': 0.1541,
#        'value': 37},
#       'cancellations': {'period': '60 months', 'rate': 0.0345, 'value': 11}}},
#     'address': {'address': 'Rua Professora Bartira Mourao 710',
#      'city': 'Belo Horizonte',
#      'state': 'BR-MG',
#      'zip_code': '30492025'}},
#    'price': 4099,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-04-17T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-7-plus-128-gb-preto-brilhante-3-gb-ram/p/MLB6240138',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/686636-MLA40678415629_022020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 341.58,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-MG',
#     'state_name': 'Minas Gerais',
#     'city_id': 'TUxCQ0JFTGU0ODdm',
#     'city_name': 'Belo Horizonte'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-MG', 'name': 'Minas Gerais'},
#     'city': {'id': 'TUxCQ0JFTGU0ODdm', 'name': 'Belo Horizonte'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'source': 1,
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None},
#     {'id': 'GPU_MODEL',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo de GPU',
#      'value_id': '8010379',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8010379',
#        'name': 'PowerVR Series7XT Plus'}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_id': '2230284',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'name': 'iPhone 7 Plus',
#        'struct': None,
#        'source': 1,
#        'id': '312157'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'value_id': '312157',
#      'value_name': 'iPhone 7 Plus',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo'},
#     {'value_id': '6946002',
#      'values': [{'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1,
#        'id': '6946002'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A10 Fusion',
#      'value_struct': None}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6240138',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1629045107',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 32 Gb Prata 2 Gb Ram',
#    'seller': {'id': 227936319,
#     'permalink': 'http://perfil.mercadolivre.com.br/OUTLET-IMPORTADOS',
#     'registration_date': '2016-09-09T19:42:39.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '3_yellow',
#      'power_seller_status': None,
#      'transactions': {'canceled': 50,
#       'completed': 550,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'neutral': 0.03, 'positive': 0.95},
#       'total': 600},
#      'metrics': {'sales': {'period': '3 months', 'completed': 497},
#       'claims': {'period': '3 months', 'rate': 0.0537, 'value': 29},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0.0388,
#        'value': 20},
#       'cancellations': {'period': '3 months', 'rate': 0, 'value': 2}}},
#     'address': {'address': 'Rua Macabu 241',
#      'city': 'São Paulo',
#      'state': 'BR-SP',
#      'zip_code': '08411470'}},
#    'price': 5000,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-32-gb-prata-2-gb-ram/p/MLB6282513',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/831527-MLA31347985627_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 416.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_name': 'Outros',
#      'value_id': '9344',
#      'name': 'Marca',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'BRAND'},
#     {'id': 'GPU_MODEL',
#      'value_id': '8094621',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8094621',
#        'name': 'PowerVR GT7600'}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo de GPU',
#      'value_name': 'PowerVR GT7600',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'values': [{'struct': None,
#        'source': 7092,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 7092},
#     {'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'value_struct': None,
#      'name': 'Linha',
#      'value_name': 'iPhone'},
#     {'values': [{'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1,
#        'id': '312151'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '312151',
#      'value_struct': None,
#      'value_name': 'iPhone 6s',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'values': [{'name': 'Apple A9',
#        'struct': None,
#        'source': 1,
#        'id': '6973026'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '6973026'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6282513',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1628219336',
#    'site_id': 'MLB',
#    'title': 'iPhone XS Dual Sim 256 Gb Prata 4 Gb Ram',
#    'seller': {'id': 114128462,
#     'permalink': 'http://perfil.mercadolivre.com.br/MIAMISTORE+OFICIAL',
#     'registration_date': '2012-05-31T11:40:16.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'credits_profile',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': None,
#      'transactions': {'canceled': 653,
#       'completed': 37917,
#       'period': 'historic',
#       'ratings': {'negative': 0.04, 'neutral': 0.04, 'positive': 0.92},
#       'total': 38570},
#      'metrics': {'sales': {'period': '3 months', 'completed': 2687},
#       'claims': {'period': '3 months', 'rate': 0.023, 'value': 66},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0.0807,
#        'value': 141},
#       'cancellations': {'period': '3 months', 'rate': 0.0104, 'value': 30}}},
#     'address': {'address': 'Rua Castro Alves 508',
#      'city': 'Campinas',
#      'state': 'BR-SP',
#      'zip_code': '13076040'}},
#    'price': 6239.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-09T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-dual-sim-256-gb-prata-4-gb-ram/p/MLB12866588',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/764851-MLA33003199444_112019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 520,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_struct': None,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'values': [{'struct': None,
#        'source': 1,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'attribute_group_name': 'Outros',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_struct': None},
#     {'value_id': '5414092',
#      'value_name': 'iPhone XS Dual SIM',
#      'value_struct': None,
#      'source': 1,
#      'name': 'Modelo',
#      'values': [{'id': '5414092',
#        'name': 'iPhone XS Dual SIM',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL'},
#     {'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A12 Bionic',
#      'attribute_group_name': 'Outros',
#      'value_id': '6927771',
#      'value_struct': None,
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 1087,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866588',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1628084905',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 128 Gb Verde 4 Gb Ram',
#    'seller': {'id': 54486513,
#     'permalink': 'http://perfil.mercadolivre.com.br/ROCHAVARIEDADESGO',
#     'registration_date': '2008-09-17T19:14:47.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 240,
#       'completed': 3961,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'neutral': 0, 'positive': 1},
#       'total': 4201},
#      'metrics': {'sales': {'period': '3 months', 'completed': 803},
#       'claims': {'period': '3 months', 'rate': 0.0201, 'value': 18},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0.0085,
#        'value': 7},
#       'cancellations': {'period': '3 months', 'rate': 0.0145, 'value': 13}}},
#     'address': {'address': 'Avenida Marechal Rondon Quadra 6 Lote 15 849',
#      'city': 'Goiânia',
#      'state': 'BR-GO',
#      'zip_code': '74560970'}},
#    'price': 6099,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-09T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-11-128-gb-verde-4-gb-ram/p/MLB15149569',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/799546-MLA42453875917_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 508.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-GO',
#     'state_name': 'Goiás',
#     'city_id': 'TUxR29p4m5pYQ',
#     'city_name': 'Goiânia'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-GO', 'name': 'Goiás'},
#     'city': {'id': 'TUxR29p4m5pYQ', 'name': 'Goiânia'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_id': 'OTHERS',
#      'value_name': 'Apple',
#      'value_struct': None},
#     {'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU MP4',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '7740544',
#      'value_struct': None,
#      'values': [{'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 1}],
#      'source': 1},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627,
#        'id': '2230284'}],
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 2860837171021627},
#     {'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '7739079',
#      'value_name': 'iPhone 11',
#      'id': 'MODEL'},
#     {'name': 'Modelo do processador',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '7740540',
#        'name': 'Apple A13 Bionic'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149569',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1633485375',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 16 Gb Ouro Rosa 2 Gb Ram',
#    'seller': {'id': 271840140,
#     'permalink': 'http://perfil.mercadolivre.com.br/GLOBOCEL+CELULARES',
#     'registration_date': '2017-09-04T20:59:17.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'level_id': '3_yellow',
#      'power_seller_status': None,
#      'transactions': {'canceled': 59,
#       'completed': 363,
#       'period': 'historic',
#       'ratings': {'negative': 0.07, 'neutral': 0.05, 'positive': 0.88},
#       'total': 422},
#      'metrics': {'sales': {'period': '3 months', 'completed': 87},
#       'claims': {'period': '3 months', 'rate': 0.0421, 'value': 4},
#       'delayed_handling_time': {'period': '3 months', 'rate': 0, 'value': 0},
#       'cancellations': {'period': '3 months', 'rate': 0, 'value': 1}}},
#     'address': {'address': 'Avenida Evandro Lins e Silva 440',
#      'city': 'Rio de Janeiro',
#      'state': 'BR-RJ',
#      'zip_code': '22631470'}},
#    'price': 1599,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-15T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-16-gb-ouro-rosa-2-gb-ram/p/MLB6127572',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/775325-MLA31347321681_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 133.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-RJ',
#     'state_name': 'Rio de Janeiro',
#     'city_id': 'BR-RJ-01',
#     'city_name': 'Rio de Janeiro'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-RJ', 'name': 'Rio de Janeiro'},
#     'city': {'id': 'BR-RJ-01', 'name': 'Rio de Janeiro'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'source': 1, 'id': '9344', 'name': 'Apple', 'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None},
#     {'name': 'Modelo de GPU',
#      'value_id': '8094621',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'value_name': 'PowerVR GT7600',
#      'values': [{'name': 'PowerVR GT7600',
#        'struct': None,
#        'source': 1,
#        'id': '8094621'}],
#      'source': 1},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1572}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1572,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo'},
#     {'value_id': '58993',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'LINE',
#      'name': 'Linha',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_name': 'iPhone',
#      'value_struct': None},
#     {'values': [{'struct': None,
#        'source': 1,
#        'id': '312151',
#        'name': 'iPhone 6s'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_struct': None,
#      'value_id': '312151',
#      'value_name': 'iPhone 6s'},
#     {'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '6973026',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'name': 'Modelo do processador',
#      'values': [{'source': 1,
#        'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6127572',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1636749823',
#    'site_id': 'MLB',
#    'title': 'iPhone 5s 32 Gb Cinza-espacial 1 Gb Ram',
#    'seller': {'id': 420284504,
#     'permalink': 'http://perfil.mercadolivre.com.br/FORTECCOMRCIOELETRNICO',
#     'registration_date': '2019-03-27T10:19:56.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'eshop',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'eshop': {'eshop_id': 359424,
#      'seller': 420284504,
#      'nick_name': 'FORTECCOMRCIOELETRNICO',
#      'eshop_status_id': 1,
#      'site_id': 'MLB',
#      'eshop_logo_url': 'http://resources.mlstatic.com/eshops/420284504v0e8fbc.png',
#      'eshop_experience': 0,
#      'eshop_rubro': None,
#      'eshop_locations': []},
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': 'platinum',
#      'transactions': {'canceled': 1330,
#       'completed': 19153,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'neutral': 0.04, 'positive': 0.9},
#       'total': 20483},
#      'metrics': {'sales': {'period': '3 months', 'completed': 8951},
#       'claims': {'period': '3 months', 'rate': 0.0206, 'value': 197},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0.0442,
#        'value': 190},
#       'cancellations': {'period': '3 months', 'rate': 0.0046, 'value': 44}}},
#     'address': {'address': 'Avenida General Olímpio da Silveira 655',
#      'city': 'São Paulo',
#      'state': 'BR-SP',
#      'zip_code': '01150001'}},
#    'price': 1149,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-19T04:00:00.000Z',
#    'condition': 'new',
# ...
#     {'value_name': 'Apple GPU',
#      'values': [{'source': 4709228965570453,
#        'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo de GPU',
#      'value_struct': None},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 1,
#        'id': '2230284'}],
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo'},
#     {'id': 'LINE',
#      'value_id': '58993',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 3942444344910321}],
#      'attribute_group_id': 'OTHERS',
#      'source': 3942444344910321,
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_name': 'Outros'},
#     {'value_id': '7741023',
#      'value_name': 'iPhone 11 Pro',
#      'value_struct': None,
#      'values': [{'id': '7741023',
#        'name': 'iPhone 11 Pro',
#        'struct': None,
#        'source': 3942444344910321}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 3942444344910321,
#      'id': 'MODEL',
#      'name': 'Modelo'},
#     {'value_id': '7740540',
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A13 Bionic',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo do processador'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15150711',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed']},
#   {'id': 'MLB1616667152',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 64gb - Amarelo',
#    'seller': {'id': 386261073,
#     'permalink': 'http://perfil.mercadolivre.com.br/LOJA+APPLE',
#     'registration_date': '2018-12-12T14:34:01.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand', 'large_seller', 'messages_as_seller'],
#     'seller_reputation': {'level_id': '5_green',
#      'power_seller_status': None,
#      'transactions': {'canceled': 576,
#       'completed': 4205,
#       'period': 'historic',
#       'ratings': {'negative': 0.08, 'neutral': 0.03, 'positive': 0.89},
#       'total': 4781},
#      'metrics': {'sales': {'period': '3 months', 'completed': 1913},
#       'claims': {'period': '3 months', 'rate': 0.0115, 'value': 25},
#       'delayed_handling_time': {'period': '3 months',
#        'rate': 0.0253,
#        'value': 51},
#       'cancellations': {'period': '3 months', 'rate': 0.0213, 'value': 46}}},
#     'address': {'address': 'ROD VICE-PREFEITO HERMENEGILDO TONOLLI 1500',
#      'city': 'Jundiaí',
#      'state': 'BR-SP',
#      'zip_code': '13213086'}},
#    'price': 4729,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 3,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-29T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://produto.mercadolivre.com.br/MLB-1616667152-iphone-11-64gb-amarelo-_JM',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/807247-MLB41719256095_052020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 394.08,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-14',
#     'city_name': 'Jundiaí'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping', 'optional_me2_chosen'],
#     'logistic_type': 'fulfillment',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-14', 'name': 'Jundiaí'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 2201547788276092}],
#      'attribute_group_name': 'Outros',
#      'source': 2201547788276092,
#      'name': 'Marca',
#      'value_struct': None,
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'value_id': '9344'},
#     {'value_id': '7740544',
#      'value_name': 'Apple GPU MP4',
#      'values': [{'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 4709228965570453,
#        'id': '7740544'}],
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'name': 'Modelo de GPU',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'id': 'GPU_MODEL'},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros'},
#     {'id': 'LINE',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1000427007642219}],
#      'source': 1000427007642219},
#     {'id': 'MODEL',
#      'value_id': '7739079',
#      'value_name': 'iPhone 11',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 2201547788276092}],
#      'source': 2201547788276092},
#     {'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 5199,
#    'category_id': 'MLB1055',
#    'official_store_id': 2162,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149560',
#    'tags': ['good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'brand_verified',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed']}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB1055',
#      'name': 'Celulares e Smartphones',
#      'path_from_root': [{'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#       {'id': 'MLB1055', 'name': 'Celulares e Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'type': 'STRING',
#    'values': [{'id': '58993', 'name': 'iPhone'}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as Lojas oficiais', 'results': 111},
#     {'id': '942', 'name': 'Fast Shop', 'results': 59},
#     {'id': '817', 'name': 'COMMCENTER', 'results': 13},
#     {'id': '2162', 'name': 'Apple', 'results': 30}]},
#   {'id': 'discount',
#    'name': 'Descontos',
#    'type': 'range',
#    'values': [{'id': '10-100', 'name': 'Mais de 10% off', 'results': 11},
#     {'id': '20-100', 'name': 'Mais de 20% off', 'results': 9}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4',
#      'name': 'São Paulo',
#      'results': 10456},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 2174},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 2022},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 1365},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 930},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 868},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 766},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 612},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 484},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 405},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 334},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 321},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 228},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 162},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 150},
#     {'id': 'TUxCUE1BUk81MWVi', 'name': 'Maranhão', 'results': 129},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 117},
#     {'id': 'TUxCUFBBUkE0M2I4', 'name': 'Paraíba', 'results': 114},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 108},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 90},
#     {'id': 'TUxCUFNFUkUxMmZlOQ', 'name': 'Sergipe', 'results': 69},
#     {'id': 'TUxCUFBJQUk1NDVj', 'name': 'Piauí', 'results': 63},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 54},
#     {'id': 'TUxCUFJPTkExMmU4YQ', 'name': 'Rondônia', 'results': 48},
#     {'id': 'TUxCUEFDUkVkNTU', 'name': 'Acre', 'results': 21},
#     {'id': 'TUxCUEFNQUExNTZlNg', 'name': 'Amapá', 'results': 21},
#     {'id': 'TUxCUFJPUkExODBiMQ', 'name': 'Roraima', 'results': 18}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-1000.0', 'name': 'Até R$1.000', 'results': 6328},
#     {'id': '1000.0-2000.0', 'name': 'R$1.000 a R$2.000', 'results': 6734},
#     {'id': '2000.0-*', 'name': 'Mais de R$2.000', 'results': 9265}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com MercadoPago', 'results': 22327}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'no_interest', 'name': 'Sem juros', 'results': 4211}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 22184},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 15}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 326}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 612}]},
#   {'id': 'until',
#    'name': 'Filtro por data do fim',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Termina hoje', 'results': 165}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicações com vídeo',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Publicações com vídeo', 'results': 382}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 22231}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 9896}]},
#   {'id': 'shipping_quarantine',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'guaranteed_delivery',
#      'name': 'Enviando normalmente',
#      'results': 405}]},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'results': 18537},
#     {'id': '298332', 'name': 'Vivo', 'results': 390},
#     {'id': '298334', 'name': 'TIM', 'results': 261},
#     {'id': '298333', 'name': 'Claro', 'results': 231},
#     {'id': '298331', 'name': 'Oi', 'results': 126},
#     {'id': '303172', 'name': 'Nextel', 'results': 39}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'type': 'range',
#    'values': [{'id': '(*-32GB)', 'name': 'Menos de 32 GB', 'results': 5745},
#     {'id': '[32GB-64GB)', 'name': '32 a 63 GB', 'results': 4557},
#     {'id': '[64GB-128GB)', 'name': '64 a 127 GB', 'results': 6432},
#     {'id': '[128GB-256GB)', 'name': '128 a 255 GB', 'results': 3366},
#     {'id': '[256GB-*)', 'name': '256 GB ou mais', 'results': 2295}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'É Dual SIM', 'results': 969}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 18882},
#     {'id': '2230284', 'name': 'Novo', 'results': 3456},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 156}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '312155', 'name': 'iPhone 7', 'results': 3603},
#     {'id': '312151', 'name': 'iPhone 6s', 'results': 2670},
#     {'id': '312149', 'name': 'iPhone 6', 'results': 1998},
#     {'id': '312144', 'name': 'iPhone 5s', 'results': 1785},
#     {'id': '2244670', 'name': 'iPhone 8', 'results': 1545},
#     {'id': '312157', 'name': 'iPhone 7 Plus', 'results': 1365},
#     {'id': '1164456', 'name': 'iPhone X', 'results': 1137},
#     {'id': '2244673', 'name': 'iPhone 8 Plus', 'results': 1104},
#     {'id': '312154', 'name': 'iPhone SE', 'results': 786},
#     {'id': '312152', 'name': 'iPhone 5', 'results': 657},
#     {'id': '312145', 'name': 'iPhone 4s', 'results': 570},
#     {'id': '5414260', 'name': 'iPhone XR', 'results': 546},
#     {'id': '5414168', 'name': 'iPhone XS Max', 'results': 462},
#     {'id': '14610', 'name': 'iPhone 4', 'results': 447},
#     {'id': '312150', 'name': 'iPhone 6 Plus', 'results': 420},
#     {'id': '7739079', 'name': 'iPhone 11', 'results': 414},
#     {'id': '312153', 'name': 'iPhone 6s Plus', 'results': 399},
#     {'id': '14608', 'name': 'iPhone', 'results': 390},
#     {'id': '312143', 'name': 'iPhone 5c', 'results': 384},
#     {'id': '7741677', 'name': 'iPhone 11 Pro Max', 'results': 285},
#     {'id': '5414079', 'name': 'iPhone XS', 'results': 285},
#     {'id': '7741023', 'name': 'iPhone 11 Pro', 'results': 180},
#     {'id': '5414092', 'name': 'iPhone XS Dual SIM', 'results': 117},
#     {'id': '14609', 'name': 'iPhone 3GS', 'results': 102},
#     {'id': '14605', 'name': 'iPhone 3G', 'results': 60},
#     {'id': '8230322', 'name': 'iPhone SE (2nd Generation)', 'results': 48},
#     {'id': '5729', 'name': 'XS', 'results': 48},
#     {'id': '58054', 'name': 'XR', 'results': 21},
#     {'id': '27251', 'name': '7', 'results': 21},
#     {'id': '59000', 'name': '5s', 'results': 12},
#     {'id': '84612', 'name': '6 Plus', 'results': 9},
#     {'id': '52828', 'name': '7 Plus', 'results': 9},
#     {'id': '165838', 'name': 'SE', 'results': 9},
#     {'id': '11043', 'name': '8', 'results': 9}]},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com reconhecimento facial',
#      'results': 2400}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com leitor de impressão digital',
#      'results': 12297}]}]}

# %%
temp = busca('iphone')

# %%
temp
# Out:
# {'site_id': 'MLB',
#  'query': 'iphone',
#  'paging': {'total': 22338, 'offset': 0, 'limit': 50, 'primary_results': 1015},
#  'results': [{'id': 'MLB1585945069',
#    'site_id': 'MLB',
#    'title': 'iPhone SE (2nd Generation) 128 Gb Branco 3 Gb Ram',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 280629,
#       'canceled': 11736,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 268893},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0251,
#        'value': 1619,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 59626},
#       'cancellations': {'rate': 0.0105, 'value': 682, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '07789100',
#      'address': 'Rodovia Anhaguera Km 37',
#      'state': 'BR-SP',
#      'city': 'Cajamar'}},
#    'price': 3715.46,
#    'currency_id': 'BRL',
#    'available_quantity': 200,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-02T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-se-2nd-generation-128-gb-branco-3-gb-ram/p/MLB15591335',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/983659-MLA42348493114_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 309.62,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'values': [{'name': 'Apple GPU',
#        'struct': None,
#        'source': 1,
#        'id': '7741027'}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Condição do item',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}]},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'value_id': '58993'},
#     {'id': 'MODEL',
#      'value_id': '8230322',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_name': 'iPhone SE (2nd Generation)',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8230322',
#        'name': 'iPhone SE (2nd Generation)'}],
#      'source': 1},
#     {'id': 'PROCESSOR_MODEL',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15591335',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1608016128',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s Plus 32 Gb Prata 2 Gb Ram',
#    'seller': {'id': 259218381,
#     'permalink': 'http://perfil.mercadolivre.com.br/F14SHOPP',
#     'registration_date': '2017-06-03T18:39:33.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1115,
#       'canceled': 98,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'positive': 0.92, 'neutral': 0.02},
#       'completed': 1017},
#      'power_seller_status': 'silver',
#      'metrics': {'claims': {'rate': 0,
#        'excluded': {'real_rate': 0.0294, 'real_value': 5},
#        'value': 0,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0,
#        'excluded': {'real_rate': 0.0672, 'real_value': 8},
#        'value': 0,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 152},
#       'cancellations': {'rate': 0,
#        'excluded': {'real_rate': 0, 'real_value': 2},
#        'value': 0,
#        'period': '3 months'}},
#      'protection_end_date': '2020-08-28T00:00:00.000-04:00',
#      'real_level': 'green_gold',
#      'level_id': '5_green'},
#     'address': {'zip_code': '89400000',
#      'address': 'av perimetral 1071',
#      'state': 'BR-SC',
#      'city': 'Porto União'}},
#    'price': 2360,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 5,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-plus-32-gb-prata-2-gb-ram/p/MLB11712143',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/820963-MLA31347985928_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 196.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SC',
#     'state_name': 'Santa Catarina',
#     'city_id': 'TUxCQ1BPUjE3NWM0',
#     'city_name': 'Porto União'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SC', 'name': 'Santa Catarina'},
#     'city': {'id': 'TUxCQ1BPUjE3NWM0', 'name': 'Porto União'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'value_struct': None,
#      'values': [{'source': 3045741222775799,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}],
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone'},
#     {'id': 'MODEL',
#      'source': 1,
#      'value_name': 'iPhone 6s Plus',
#      'value_struct': None,
#      'values': [{'name': 'iPhone 6s Plus',
#        'struct': None,
#        'source': 1,
#        'id': '312153'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_id': '312153'},
#     {'value_id': '6973026',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'values': [{'id': '6973026',
#        'name': 'Apple A9',
#        'struct': None,
#        'source': 1}],
#      'source': 1}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB11712143',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1622965271',
#    'site_id': 'MLB',
#    'title': 'iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram',
#    'seller': {'id': 8710030,
#     'permalink': 'http://perfil.mercadolivre.com.br/-DANSL-',
#     'registration_date': '2002-03-27T00:00:00.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 417,
#       'canceled': 32,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 0.97, 'neutral': 0.03},
#       'completed': 385},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0076,
#        'value': 1,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 132},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '09540500',
#      'address': 'Avenida Lemos Monteiro 71',
#      'state': 'BR-SP',
#      'city': 'São Caetano do Sul'}},
#    'price': 4100,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-19T14:49:16.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-se-2nd-generation-256-gb-preto-3-gb-ram/p/MLB15591337',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/917693-MLA42348499125_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 341.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-40',
#     'city_name': 'São Caetano do Sul'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-40', 'name': 'São Caetano do Sul'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha'},
#     {'id': 'MODEL',
#      'value_id': '8230322',
#      'value_struct': None,
#      'name': 'Modelo',
#      'value_name': 'iPhone SE (2nd Generation)',
#      'values': [{'id': '8230322',
#        'name': 'iPhone SE (2nd Generation)',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15591337',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1622334438',
#    'site_id': 'MLB',
#    'title': 'iPhone 8 256 Gb Prata 2 Gb Ram',
#    'seller': {'id': 336592499,
#     'permalink': 'http://perfil.mercadolivre.com.br/SICE+DIGITAL',
#     'registration_date': '2018-07-14T07:33:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1208,
#       'canceled': 137,
#       'period': 'historic',
#       'ratings': {'negative': 0.04, 'positive': 0.95, 'neutral': 0.01},
#       'completed': 1071},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0222, 'value': 26, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0018,
#        'value': 2,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1037},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13097158',
#      'address': 'Rua João de Barro SN',
#      'state': 'BR-SP',
#      'city': 'Campinas'}},
#    'price': 3499.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-03T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-8-256-gb-prata-2-gb-ram/p/MLB8752434',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/694892-MLA42533131046_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 291.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'source': 1},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 2860837171021627,
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627}]},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'id': 'LINE',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'MODEL',
#      'value_id': '2244670',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'value_name': 'iPhone 8',
#      'value_struct': None,
#      'values': [{'id': '2244670',
#        'name': 'iPhone 8',
#        'struct': None,
#        'source': 1}]},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A11 Bionic',
#      'value_struct': None,
#      'source': 1,
#      'value_id': '6936434',
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752434',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1560352635',
#    'site_id': 'MLB',
#    'title': 'iPhone XS Max 512 Gb Ouro 4 Gb Ram',
#    'seller': {'id': 147172848,
#     'permalink': 'http://perfil.mercadolivre.com.br/FIVENDASONLINE',
#     'registration_date': '2013-10-08T22:59:50.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 11632,
#       'canceled': 714,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.94, 'neutral': 0.03},
#       'completed': 10918},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0215, 'value': 41, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0698,
#        'value': 114,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1705},
#       'cancellations': {'rate': 0.0052, 'value': 10, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '03572340',
#      'address': 'José Da Costa De Andrade 105',
#      'state': 'BR-SP',
#      'city': 'São Paulo'}},
#    'price': 7199,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-06-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-max-512-gb-ouro-4-gb-ram/p/MLB12866634',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/864619-MLA42092921659_062020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 599.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Apple',
#      'value_struct': None,
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}]},
#     {'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_id': 'OTHERS',
#      'source': 3045741222775799,
#      'value_id': '2230284',
#      'value_name': 'Novo'},
#     {'value_id': '58993',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '5414168',
#        'name': 'iPhone XS Max'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '5414168',
#      'value_name': 'iPhone XS Max',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'value_id': '6927771',
#      'value_name': 'Apple A12 Bionic',
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866634',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1636749823',
#    'site_id': 'MLB',
#    'title': 'iPhone 5s 32 Gb Cinza-espacial 1 Gb Ram',
#    'seller': {'id': 420284504,
#     'permalink': 'http://perfil.mercadolivre.com.br/FORTECCOMRCIOELETRNICO',
#     'registration_date': '2019-03-27T10:19:56.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'eshop',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'eshop': {'nick_name': 'FORTECCOMRCIOELETRNICO',
#      'eshop_rubro': None,
#      'eshop_id': 359424,
#      'eshop_locations': [],
#      'site_id': 'MLB',
#      'eshop_logo_url': 'http://resources.mlstatic.com/eshops/420284504v0e8fbc.png',
#      'eshop_status_id': 1,
#      'seller': 420284504,
#      'eshop_experience': 0},
#     'seller_reputation': {'transactions': {'total': 20480,
#       'canceled': 1330,
#       'period': 'historic',
#       'ratings': {'negative': 0.06, 'positive': 0.9, 'neutral': 0.04},
#       'completed': 19150},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0206,
#        'value': 197,
#        'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0442,
#        'value': 190,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 8948},
#       'cancellations': {'rate': 0.0046, 'value': 44, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '01150001',
#      'address': 'Avenida General Olímpio da Silveira 655',
#      'state': 'BR-SP',
#      'city': 'São Paulo'}},
#    'price': 1149,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-19T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-5s-32-gb-cinza-espacial-1-gb-ram/p/MLB6007309',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/749916-MLA31347321590_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 95.75,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros'},
#     {'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item'},
#     {'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '58993',
#      'value_name': 'iPhone'},
#     {'id': 'MODEL',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '312144',
#        'name': 'iPhone 5s',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '312144',
#      'value_name': 'iPhone 5s',
#      'attribute_group_name': 'Outros'},
#     {'value_id': '7199618',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A7',
#      'values': [{'id': '7199618',
#        'name': 'Apple A7',
#        'struct': None,
#        'source': 1}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6007309',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1503227867',
#    'site_id': 'MLB',
#    'title': 'iPhone 7 Plus 128 Gb Preto-brilhante 3 Gb Ram',
#    'seller': {'id': 61843260,
#     'permalink': 'http://perfil.mercadolivre.com.br/UAIPLACEBH',
#     'registration_date': '2008-12-06T08:42:58.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 318,
#       'canceled': 21,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 0.98, 'neutral': 0.02},
#       'completed': 297},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0157, 'value': 5, 'period': '60 months'},
#       'delayed_handling_time': {'rate': 0.1541,
#        'value': 37,
#        'period': '60 months'},
#       'sales': {'period': '60 months', 'completed': 297},
#       'cancellations': {'rate': 0.0345, 'value': 11, 'period': '60 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '30492025',
#      'address': 'Rua Professora Bartira Mourao 710',
#      'state': 'BR-MG',
#      'city': 'Belo Horizonte'}},
#    'price': 4099,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-04-17T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-7-plus-128-gb-preto-brilhante-3-gb-ram/p/MLB6240138',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/686636-MLA40678415629_022020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 341.58,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-MG',
#     'state_name': 'Minas Gerais',
#     'city_id': 'TUxCQ0JFTGU0ODdm',
#     'city_name': 'Belo Horizonte'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-MG', 'name': 'Minas Gerais'},
#     'city': {'id': 'TUxCQ0JFTGU0ODdm', 'name': 'Belo Horizonte'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'source': 1,
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None},
#     {'id': 'GPU_MODEL',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo de GPU',
#      'value_id': '8010379',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8010379',
#        'name': 'PowerVR Series7XT Plus'}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_id': '2230284',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'name': 'iPhone 7 Plus',
#        'struct': None,
#        'source': 1,
#        'id': '312157'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'value_id': '312157',
#      'value_name': 'iPhone 7 Plus',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo'},
#     {'value_id': '6946002',
#      'values': [{'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1,
#        'id': '6946002'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A10 Fusion',
#      'value_struct': None}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6240138',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1629045107',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 32 Gb Prata 2 Gb Ram',
#    'seller': {'id': 227936319,
#     'permalink': 'http://perfil.mercadolivre.com.br/OUTLET-IMPORTADOS',
#     'registration_date': '2016-09-09T19:42:39.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 600,
#       'canceled': 50,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.95, 'neutral': 0.03},
#       'completed': 550},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0537, 'value': 29, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0389,
#        'value': 20,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 497},
#       'cancellations': {'rate': 0, 'value': 2, 'period': '3 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '08411470',
#      'address': 'Rua Macabu 241',
#      'state': 'BR-SP',
#      'city': 'São Paulo'}},
#    'price': 5000,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-11T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-32-gb-prata-2-gb-ram/p/MLB6282513',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/831527-MLA31347985627_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 416.67,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_name': 'Outros',
#      'value_id': '9344',
#      'name': 'Marca',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'BRAND'},
#     {'id': 'GPU_MODEL',
#      'value_id': '8094621',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '8094621',
#        'name': 'PowerVR GT7600'}],
#      'attribute_group_id': 'OTHERS',
#      'name': 'Modelo de GPU',
#      'value_name': 'PowerVR GT7600',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'values': [{'struct': None,
#        'source': 7092,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 7092},
#     {'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'value_struct': None,
#      'name': 'Linha',
#      'value_name': 'iPhone'},
#     {'values': [{'name': 'iPhone 6s',
#        'struct': None,
#        'source': 1,
#        'id': '312151'}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '312151',
#      'value_struct': None,
#      'value_name': 'iPhone 6s',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A9',
#      'value_struct': None,
#      'values': [{'name': 'Apple A9',
#        'struct': None,
#        'source': 1,
#        'id': '6973026'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '6973026'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6282513',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1628219336',
#    'site_id': 'MLB',
#    'title': 'iPhone XS Dual Sim 256 Gb Prata 4 Gb Ram',
#    'seller': {'id': 114128462,
#     'permalink': 'http://perfil.mercadolivre.com.br/MIAMISTORE+OFICIAL',
#     'registration_date': '2012-05-31T11:40:16.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'credits_profile',
#      'large_seller',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 38570,
#       'canceled': 653,
#       'period': 'historic',
#       'ratings': {'negative': 0.04, 'positive': 0.92, 'neutral': 0.04},
#       'completed': 37917},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.023, 'value': 66, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0807,
#        'value': 141,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 2687},
#       'cancellations': {'rate': 0.0104, 'value': 30, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13076040',
#      'address': 'Rua Castro Alves 508',
#      'state': 'BR-SP',
#      'city': 'Campinas'}},
#    'price': 6239.99,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-09T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xs-dual-sim-256-gb-prata-4-gb-ram/p/MLB12866588',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/764851-MLA33003199444_112019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 520,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-42',
#     'city_name': 'Campinas'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-42', 'name': 'Campinas'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_struct': None,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_name': 'Apple',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'values': [{'struct': None,
#        'source': 1,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'attribute_group_name': 'Outros',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_struct': None},
#     {'value_id': '5414092',
#      'value_name': 'iPhone XS Dual SIM',
#      'value_struct': None,
#      'source': 1,
#      'name': 'Modelo',
#      'values': [{'id': '5414092',
#        'name': 'iPhone XS Dual SIM',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL'},
#     {'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A12 Bionic',
#      'attribute_group_name': 'Outros',
#      'value_id': '6927771',
#      'value_struct': None,
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 1087,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866588',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True},
#   {'id': 'MLB1628084905',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 128 Gb Verde 4 Gb Ram',
#    'seller': {'id': 54486513,
#     'permalink': 'http://perfil.mercadolivre.com.br/ROCHAVARIEDADESGO',
#     'registration_date': '2008-09-17T19:14:47.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 4200,
#       'canceled': 240,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 3960},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0201, 'value': 18, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0085,
#        'value': 7,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 802},
#       'cancellations': {'rate': 0.0145, 'value': 13, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '74560970',
#      'address': 'Avenida Marechal Rondon Quadra 6 Lote 15 849',
#      'state': 'BR-GO',
#      'city': 'Goiânia'}},
#    'price': 6099,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-09T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-11-128-gb-verde-4-gb-ram/p/MLB15149569',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/799546-MLA42453875917_072020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 508.25,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-GO',
#     'state_name': 'Goiás',
#     'city_id': 'TUxR29p4m5pYQ',
#     'city_name': 'Goiânia'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-GO', 'name': 'Goiás'},
#     'city': {'id': 'TUxR29p4m5pYQ', 'name': 'Goiânia'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_id': 'OTHERS',
#      'value_name': 'Apple',
#      'value_struct': None},
#     {'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU MP4',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '7740544',
#      'value_struct': None,
#      'values': [{'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 1}],
#      'source': 1},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627,
#        'id': '2230284'}],
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 2860837171021627},
#     {'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'values': [{'source': 1,
#        'id': '58993',
#        'name': 'iPhone',
#        'struct': None}],
#      'attribute_group_name': 'Outros'},
#     {'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '7739079',
#      'value_name': 'iPhone 11',
#      'id': 'MODEL'},
#     {'name': 'Modelo do processador',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '7740540',
#        'name': 'Apple A13 Bionic'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149569',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True},
#   {'id': 'MLB1633485375',
#    'site_id': 'MLB',
#    'title': 'iPhone 6s 16 Gb Ouro Rosa 2 Gb Ram',
#    'seller': {'id': 271840140,
#     'permalink': 'http://perfil.mercadolivre.com.br/GLOBOCEL+CELULARES',
#     'registration_date': '2017-09-04T20:59:17.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 422,
#       'canceled': 59,
#       'period': 'historic',
#       'ratings': {'negative': 0.07, 'positive': 0.88, 'neutral': 0.05},
#       'completed': 363},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0421, 'value': 4, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 87},
#       'cancellations': {'rate': 0, 'value': 1, 'period': '3 months'}},
#      'level_id': '3_yellow'},
#     'address': {'zip_code': '22631470',
#      'address': 'Avenida Evandro Lins e Silva 440',
#      'state': 'BR-RJ',
#      'city': 'Rio de Janeiro'}},
#    'price': 1599,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-08-15T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-6s-16-gb-ouro-rosa-2-gb-ram/p/MLB6127572',
#    'thumbnail': 'http://mlb-s2-p.mlstatic.com/775325-MLA31347321681_072019-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 133.25,
#     'rate': 0,
# ...
#      'source': 4060709329251625,
#      'value_id': '9344'},
#     {'values': [{'struct': None,
#        'source': 4709228965570453,
#        'id': '7741027',
#        'name': 'Apple GPU'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'value_struct': None,
#      'source': 4709228965570453},
#     {'value_id': '2230284',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item'},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Linha',
#      'value_struct': None,
#      'value_name': 'iPhone',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 3942444344910321}],
#      'attribute_group_name': 'Outros',
#      'source': 3942444344910321,
#      'id': 'LINE',
#      'value_id': '58993'},
#     {'value_id': '7741023',
#      'values': [{'id': '7741023',
#        'name': 'iPhone 11 Pro',
#        'struct': None,
#        'source': 3942444344910321}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'source': 3942444344910321,
#      'value_name': 'iPhone 11 Pro',
#      'value_struct': None},
#     {'name': 'Modelo do processador',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'id': 'PROCESSOR_MODEL',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15150711',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed']},
#   {'id': 'MLB1616667152',
#    'site_id': 'MLB',
#    'title': 'iPhone 11 64gb - Amarelo',
#    'seller': {'id': 386261073,
#     'permalink': 'http://perfil.mercadolivre.com.br/LOJA+APPLE',
#     'registration_date': '2018-12-12T14:34:01.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand', 'large_seller', 'messages_as_seller'],
#     'seller_reputation': {'transactions': {'total': 4781,
#       'canceled': 576,
#       'period': 'historic',
#       'ratings': {'negative': 0.08, 'positive': 0.89, 'neutral': 0.03},
#       'completed': 4205},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0115, 'value': 25, 'period': '3 months'},
#       'delayed_handling_time': {'rate': 0.0253,
#        'value': 51,
#        'period': '3 months'},
#       'sales': {'period': '3 months', 'completed': 1913},
#       'cancellations': {'rate': 0.0213, 'value': 46, 'period': '3 months'}},
#      'level_id': '5_green'},
#     'address': {'zip_code': '13213086',
#      'address': 'ROD VICE-PREFEITO HERMENEGILDO TONOLLI 1500',
#      'state': 'BR-SP',
#      'city': 'Jundiaí'}},
#    'price': 4729,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 3,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-29T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://produto.mercadolivre.com.br/MLB-1616667152-iphone-11-64gb-amarelo-_JM',
#    'thumbnail': 'http://mlb-s1-p.mlstatic.com/807247-MLB41719256095_052020-I.jpg',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 394.08,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-14',
#     'city_name': 'Jundiaí'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping', 'optional_me2_chosen'],
#     'logistic_type': 'fulfillment',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-14', 'name': 'Jundiaí'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 2201547788276092}],
#      'attribute_group_name': 'Outros',
#      'source': 2201547788276092,
#      'name': 'Marca',
#      'value_struct': None,
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'value_id': '9344'},
#     {'value_id': '7740544',
#      'value_name': 'Apple GPU MP4',
#      'values': [{'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 4709228965570453,
#        'id': '7740544'}],
#      'attribute_group_name': 'Outros',
#      'source': 4709228965570453,
#      'name': 'Modelo de GPU',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'id': 'GPU_MODEL'},
#     {'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros'},
#     {'id': 'LINE',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1000427007642219}],
#      'source': 1000427007642219},
#     {'id': 'MODEL',
#      'value_id': '7739079',
#      'value_name': 'iPhone 11',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 2201547788276092}],
#      'source': 2201547788276092},
#     {'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'id': 'PROCESSOR_MODEL',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 5199,
#    'category_id': 'MLB1055',
#    'official_store_id': 2162,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149560',
#    'tags': ['good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'brand_verified',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed']}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB1055',
#      'name': 'Celulares e Smartphones',
#      'path_from_root': [{'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#       {'id': 'MLB1055', 'name': 'Celulares e Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'type': 'STRING',
#    'values': [{'id': '58993', 'name': 'iPhone'}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as Lojas oficiais', 'results': 129},
#     {'id': '942', 'name': 'Fast Shop', 'results': 53},
#     {'id': '817', 'name': 'COMMCENTER', 'results': 13},
#     {'id': '2162', 'name': 'Apple', 'results': 15}]},
#   {'id': 'discount',
#    'name': 'Descontos',
#    'type': 'range',
#    'values': [{'id': '10-100', 'name': 'Mais de 10% off', 'results': 11},
#     {'id': '20-100', 'name': 'Mais de 20% off', 'results': 9}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4',
#      'name': 'São Paulo',
#      'results': 10825},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 2112},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 2009},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 1191},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 922},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 783},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 781},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 529},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 519},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 354},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 324},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 310},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 216},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 192},
#     {'id': 'TUxCUFBBUkE0M2I4', 'name': 'Paraíba', 'results': 135},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 132},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 129},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 123},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 111},
#     {'id': 'TUxCUFBJQUk1NDVj', 'name': 'Piauí', 'results': 102},
#     {'id': 'TUxCUE1BUk81MWVi', 'name': 'Maranhão', 'results': 90},
#     {'id': 'TUxCUFNFUkUxMmZlOQ', 'name': 'Sergipe', 'results': 63},
#     {'id': 'TUxCUFJPTkExMmU4YQ', 'name': 'Rondônia', 'results': 60},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 51},
#     {'id': 'TUxCUEFNQUExNTZlNg', 'name': 'Amapá', 'results': 30},
#     {'id': 'TUxCUEFDUkVkNTU', 'name': 'Acre', 'results': 27},
#     {'id': 'TUxCUFJPUkExODBiMQ', 'name': 'Roraima', 'results': 15}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-1000.0', 'name': 'Até R$1.000', 'results': 6322},
#     {'id': '1000.0-2000.0', 'name': 'R$1.000 a R$2.000', 'results': 6830},
#     {'id': '2000.0-*', 'name': 'Mais de R$2.000', 'results': 9169}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com MercadoPago', 'results': 22321}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'no_interest', 'name': 'Sem juros', 'results': 4241}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 22148},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 12}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 332}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 597}]},
#   {'id': 'until',
#    'name': 'Filtro por data do fim',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Termina hoje', 'results': 150}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicações com vídeo',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Publicações com vídeo', 'results': 367}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 22222}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 9698}]},
#   {'id': 'shipping_quarantine',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'guaranteed_delivery',
#      'name': 'Enviando normalmente',
#      'results': 441}]},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'results': 18561},
#     {'id': '298332', 'name': 'Vivo', 'results': 408},
#     {'id': '298334', 'name': 'TIM', 'results': 231},
#     {'id': '298333', 'name': 'Claro', 'results': 219},
#     {'id': '298331', 'name': 'Oi', 'results': 117},
#     {'id': '303172', 'name': 'Nextel', 'results': 45}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'type': 'range',
#    'values': [{'id': '(*-32GB)', 'name': 'Menos de 32 GB', 'results': 5796},
#     {'id': '[32GB-64GB)', 'name': '32 a 63 GB', 'results': 4632},
#     {'id': '[64GB-128GB)', 'name': '64 a 127 GB', 'results': 6357},
#     {'id': '[128GB-256GB)', 'name': '128 a 255 GB', 'results': 3321},
#     {'id': '[256GB-*)', 'name': '256 GB ou mais', 'results': 2280}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'É Dual SIM', 'results': 978}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 19014},
#     {'id': '2230284', 'name': 'Novo', 'results': 3318},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 159}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '312155', 'name': 'iPhone 7', 'results': 3519},
#     {'id': '312151', 'name': 'iPhone 6s', 'results': 2625},
#     {'id': '312149', 'name': 'iPhone 6', 'results': 1959},
#     {'id': '312144', 'name': 'iPhone 5s', 'results': 1734},
#     {'id': '2244670', 'name': 'iPhone 8', 'results': 1548},
#     {'id': '312157', 'name': 'iPhone 7 Plus', 'results': 1464},
#     {'id': '2244673', 'name': 'iPhone 8 Plus', 'results': 1164},
#     {'id': '1164456', 'name': 'iPhone X', 'results': 1095},
#     {'id': '312154', 'name': 'iPhone SE', 'results': 783},
#     {'id': '312152', 'name': 'iPhone 5', 'results': 648},
#     {'id': '5414260', 'name': 'iPhone XR', 'results': 645},
#     {'id': '312145', 'name': 'iPhone 4s', 'results': 624},
#     {'id': '312143', 'name': 'iPhone 5c', 'results': 507},
#     {'id': '5414168', 'name': 'iPhone XS Max', 'results': 456},
#     {'id': '14610', 'name': 'iPhone 4', 'results': 432},
#     {'id': '312153', 'name': 'iPhone 6s Plus', 'results': 426},
#     {'id': '7739079', 'name': 'iPhone 11', 'results': 375},
#     {'id': '312150', 'name': 'iPhone 6 Plus', 'results': 372},
#     {'id': '14608', 'name': 'iPhone', 'results': 363},
#     {'id': '7741677', 'name': 'iPhone 11 Pro Max', 'results': 264},
#     {'id': '5414079', 'name': 'iPhone XS', 'results': 261},
#     {'id': '7741023', 'name': 'iPhone 11 Pro', 'results': 171},
#     {'id': '14609', 'name': 'iPhone 3GS', 'results': 108},
#     {'id': '5414092', 'name': 'iPhone XS Dual SIM', 'results': 90},
#     {'id': '5729', 'name': 'XS', 'results': 57},
#     {'id': '14605', 'name': 'iPhone 3G', 'results': 45},
#     {'id': '8230322', 'name': 'iPhone SE (2nd Generation)', 'results': 39},
#     {'id': '27251', 'name': '7', 'results': 24},
#     {'id': '58054', 'name': 'XR', 'results': 18},
#     {'id': '59000', 'name': '5s', 'results': 15},
#     {'id': '4904058', 'name': '8 Plus', 'results': 12},
#     {'id': '52828', 'name': '7 Plus', 'results': 9},
#     {'id': '11043', 'name': '8', 'results': 9}]},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com reconhecimento facial',
#      'results': 2547}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com leitor de impressão digital',
#      'results': 12144}]}]}

# %%
temp.keys()
# Out:
# dict_keys(['site_id', 'query', 'paging', 'results', 'secondary_results', 'related_results', 'sort', 'available_sorts', 'filters', 'available_filters'])

# %%
for anuncio in temp['results']:
    print(anuncio['title'])
# Out:
# iPhone SE (2nd Generation) 128 Gb Branco 3 Gb Ram
# iPhone 6s Plus 32 Gb Prata 2 Gb Ram
# iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram
# iPhone 8 256 Gb Prata 2 Gb Ram
# iPhone XS Max 512 Gb Ouro 4 Gb Ram
# iPhone 5s 32 Gb Cinza-espacial 1 Gb Ram
# iPhone 7 Plus 128 Gb Preto-brilhante 3 Gb Ram
# iPhone 6s 32 Gb Prata 2 Gb Ram
# iPhone XS Dual Sim 256 Gb Prata 4 Gb Ram
# iPhone 11 128 Gb Verde 4 Gb Ram
# iPhone 6s 16 Gb Ouro Rosa 2 Gb Ram
# iPhone 6s Plus 128 Gb Cinza-espacial 2 Gb Ram
# iPhone 6s Plus 16 Gb Ouro 2 Gb Ram
# iPhone 11 64 Gb Roxo 4 Gb Ram
# iPhone SE 16 Gb Ouro 2 Gb Ram
# iPhone 6s 64g Apple  Exposicao Garantia 12x Sem Juros
# iPhone 11 Preto 6,1  4g 64 Gb E Câmera De 12 Mp - Mwlt2br/a
# iPhone XR 64gb
#  iPhone 8 Vitrine 64gb Original Apple Exposição 12x S/ Juros
# Apple iPhone 7 32 Gb Vitrine + Brinde  12x Sem Juros
# iPhone 11 Preto 6,1  4g 128 Gb E Câmera 12 Mp - Mwm02br/a
# iPhone XR 64gb
# iPhone XR Branco Tela 6,1, 128 Gb E Câmera 12mp - Mryd2br/a
# Apple iPhone 6s Vitrine Original 64gb Garantia Promo À Vista
# iPhone XR Preto,tela 6,1, 64 Gb, Câmera De 12 Mp - Mry42br/a
# iPhone 11 Pro Max 256gb + 2 Brindes Consultar Pronta Entrega
# iPhone XR Preto Tela 6,1, 128 Gb,câmera De 12 Mp - Mry92br/a
# iPhone XR Branco 6,1 , 4g, 64 Gb Câmera De 12 Mp - Mry52br/a
# Apple iPhone 7 128 Gb Original Entrega Já - Vitrine
# iPhone SE 64gb
# Celular Apple iPhone XS 512gb 4gb Ram 12mp Tela 5.8 Prata
# Celular Apple iPhone XS 512gb 4gb Ram 12mp Tela 5.8 Prata
# Apple iPhone 7  128gb Exposição Original Tela 4k 12x S/juros
# iPhone 8 Plus 64gb Vitrinecom Acessórios + Nfe
# Celular Apple iPhone XR 256gb 3gb Ram 12mp Tela 6.1 Coral
# Celular Apple iPhone XS 64gb 4gb Ram 12mp Tela 5.8 Prata
# Celular Apple iPhone XS 256gb 4gb Ram 12mp Tela 5.8 Prata
# Celular Apple iPhone XR 256gb 3gb Ram 12mp Tela 6.1 Coral
# Apple iPhone 7 128 Gb 4k 4g Original Promoção
# Celular Apple iPhone XS 256gb 4gb Ram 12mp Tela 5.8 Prata
# Celular Apple iPhone XS 64gb 4gb Ram 12mp Tela 5.8 Prata
# iPhone 11 Pro Max Cinza 6,5  4g 256gb Câm 12mp - Mwhj2bz/a
# iPhone 11 Pro Cinza Espac 5,8  4g 256gb Câm 12mp - Mwc72bz/a
# iPhone SE 64gb
# iPhone 11 Pro Verde 5,8 , 4g 256 Gb Câmera 12 Mp - Mwcc2bz/a
# iPhone 7 32gb
# Apple iPhone 7 Plus 128 Gb Vitrine Pronta Entrega
# iPhone 11 Pro 64gb
# iPhone 11 Pro Verde 5,8  4g 64gb Câm 12mp - Mwc62bz/a
# iPhone 11 64gb - Amarelo

# %% [markdown]
# Transforme o resultado da API em um Dataframe

# %%
#Coloque seu código aqui
df = pd.DataFrame(temp['results'])
df.head()
# Out:
#               id site_id                                              title  \
# 0  MLB1585945069     MLB  iPhone SE (2nd Generation) 128 Gb Branco 3 Gb Ram
# 1  MLB1633819794     MLB                  iPhone 11 128 Gb Amarelo 4 Gb Ram
# 2  MLB1608016128     MLB                iPhone 6s Plus 32 Gb Prata 2 Gb Ram
# 3  MLB1622965271     MLB   iPhone SE (2nd Generation) 256 Gb Preto 3 Gb Ram
# 4  MLB1622334438     MLB                     iPhone 8 256 Gb Prata 2 Gb Ram
#
#                                               seller    price currency_id  \
# 0  {'id': 234000251, 'permalink': 'http://perfil....  3715.46         BRL
# 1  {'id': 148197949, 'permalink': 'http://perfil....  5599.80         BRL
# 2  {'id': 259218381, 'permalink': 'http://perfil....  2360.00         BRL
# 3  {'id': 8710030, 'permalink': 'http://perfil.me...  4100.00         BRL
# 4  {'id': 336592499, 'permalink': 'http://perfil....  3499.99         BRL
#
#    available_quantity  sold_quantity buying_mode listing_type_id  ...  \
# 0                 200              5  buy_it_now        gold_pro  ...
# 1                   1              0  buy_it_now        gold_pro  ...
# 2                   1              5  buy_it_now        gold_pro  ...
# 3                   1              0  buy_it_now        gold_pro  ...
# 4                   1              0  buy_it_now        gold_pro  ...
#
#                                       seller_address  \
# 0  {'id': '', 'comment': '', 'address_line': '', ...
# 1  {'id': '', 'comment': '', 'address_line': '', ...
# 2  {'id': '', 'comment': '', 'address_line': '', ...
# 3  {'id': '', 'comment': '', 'address_line': '', ...
# 4  {'id': '', 'comment': '', 'address_line': '', ...
#
#                                           attributes differential_pricing  \
# 0  [{'id': 'BRAND', 'name': 'Marca', 'value_struc...     {'id': 33580182}
# 1  [{'value_struct': None, 'values': [{'id': '934...     {'id': 33580182}
# 2  [{'name': 'Marca', 'value_id': '9344', 'values...     {'id': 33580182}
# 3  [{'id': 'BRAND', 'name': 'Marca', 'attribute_g...     {'id': 33580182}
# 4  [{'name': 'Marca', 'value_id': '9344', 'value_...     {'id': 33580182}
#
#   original_price  category_id official_store_id       domain_id  \
# 0            NaN      MLB1055             942.0  MLB-CELLPHONES
# 1            NaN      MLB1055               NaN  MLB-CELLPHONES
# 2            NaN      MLB1055               NaN  MLB-CELLPHONES
# 3            NaN      MLB1055               NaN  MLB-CELLPHONES
# 4            NaN      MLB1055               NaN  MLB-CELLPHONES
#
#   catalog_product_id                                               tags  \
# 0        MLB15591335  [brand_verified, extended_warranty_eligible, g...
# 1        MLB15149570  [good_quality_picture, good_quality_thumbnail,...
# 2        MLB11712143  [brand_verified, extended_warranty_eligible, g...
# 3        MLB15591337  [brand_verified, extended_warranty_eligible, g...
# 4         MLB8752434  [brand_verified, extended_warranty_eligible, g...
#
#   catalog_listing
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#
# [5 rows x 28 columns]

# %%
df.head(1).T
# Out:
#                                                                       0
# id                                                        MLB1585945069
# site_id                                                             MLB
# title                 iPhone SE (2nd Generation) 128 Gb Branco 3 Gb Ram
# seller                {'id': 234000251, 'permalink': 'http://perfil....
# price                                                           3715.46
# currency_id                                                         BRL
# available_quantity                                                  200
# sold_quantity                                                         5
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-07-02T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-se-2nd-...
# thumbnail             http://mlb-s2-p.mlstatic.com/983659-MLA4234849...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 309.62, 'rate': 0, ...
# address               {'state_id': 'BR-SP', 'state_name': 'São Paulo...
# shipping              {'free_shipping': False, 'mode': 'me1', 'tags'...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'id': 'BRAND', 'name': 'Marca', 'value_struc...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   942
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB15591335
# tags                  [brand_verified, extended_warranty_eligible, g...
# catalog_listing                                                    True

# %%
df.address.apply(pd.Series).head()
# Out:
#   state_id      state_name           city_id           city_name
# 0    BR-SP       São Paulo  QlItU1BDYWphbWFy             Cajamar
# 1    BR-SP       São Paulo          BR-SP-44           São Paulo
# 2    BR-SC  Santa Catarina  TUxCQ1BPUjE3NWM0         Porto União
# 3    BR-SP       São Paulo          BR-SP-40  São Caetano do Sul
# 4    BR-SP       São Paulo          BR-SP-42            Campinas

# %%
df2 = df.merge(df.address.apply(pd.Series),left_index=True, right_index=True).drop('address', axis=1)

# %%
df2.head(1).T
# Out:
#                                                                       0
# id                                                        MLB1585945069
# site_id                                                             MLB
# title                 iPhone SE (2nd Generation) 128 Gb Branco 3 Gb Ram
# seller                {'id': 234000251, 'permalink': 'http://perfil....
# price                                                           3715.46
# currency_id                                                         BRL
# available_quantity                                                  200
# sold_quantity                                                         5
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-07-02T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/iphone-se-2nd-...
# thumbnail             http://mlb-s2-p.mlstatic.com/983659-MLA4234849...
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 309.62, 'rate': 0, ...
# shipping              {'free_shipping': False, 'mode': 'me1', 'tags'...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'id': 'BRAND', 'name': 'Marca', 'value_struc...
# differential_pricing                                   {'id': 33580182}
# original_price                                                      NaN
# category_id                                                     MLB1055
# official_store_id                                                   942
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB15591335
# tags                  [brand_verified, extended_warranty_eligible, g...
# catalog_listing                                                    True
# state_id                                                          BR-SP
# state_name                                                    São Paulo
# city_id                                                QlItU1BDYWphbWFy
# city_name                                                       Cajamar

# %%
df2.columns
# Out:
# Index(['id', 'site_id', 'title', 'seller', 'price', 'currency_id',
#        'available_quantity', 'sold_quantity', 'buying_mode', 'listing_type_id',
#        'stop_time', 'condition', 'permalink', 'thumbnail',
#        'accepts_mercadopago', 'installments', 'shipping', 'seller_address',
#        'attributes', 'differential_pricing', 'original_price', 'category_id',
#        'official_store_id', 'domain_id', 'catalog_product_id', 'tags',
#        'catalog_listing', 'state_id', 'state_name', 'city_id', 'city_name'],
#       dtype='object')

# %%
print('Contagem:', df2.loc[df2.state_name=='Minas Gerais',:].price.count())
print('Média:', round(df2.loc[df2.state_name=='Minas Gerais',:].price.mean(),2))
# Out:
# Contagem: 2
# Média: 6349.5

# %% [markdown]
# ___

# %% [markdown]
# ### NBA
# Vamos utilizar a API da NBA para entender os principais jogadores das finais.<br>
# <strong>O que fazer</strong>: consulta a API através de módulos e funções de uma biblioteca<br>
# <strong>Documentação</strong>: https://github.com/swar/nba_api<br>
# <strong>Objetivo</strong>: Qual a distância média de arremessos dos jogadores Kawhi Leonard e Stephen Curry na temporada 18/19<br>
# <strong>Desafio</strong>: Plote um gráfico comparando o perfil de localização dos arremessos.<br>
# <strong>Dica</strong>: A biblioteca tem muitos módulos e funções. Seja objetivo em encontrar aqueles que interessam ao problema

# %%
# Out:
# array(['16-24 ft.', '8-16 ft.', 'Less Than 8 ft.', '24+ ft.'],
#       dtype=object)

# %%
range_1 = 'Less Than 8 ft.'
range_2 = '8-16 ft.'
range_3 = '16-24 ft.'
range_4 = '24+ ft.'
fig, ax = plt.subplots(1,2, figsize=(20,10))
ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_1,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_1,'LOC_Y'], color='green')
ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_2,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_2,'LOC_Y'], color='yellow')
ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_3,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_3,'LOC_Y'], color='orange')
ax[0].scatter(shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_4,'LOC_X'], shots1_df.loc[shots1_df.SHOT_ZONE_RANGE==range_4,'LOC_Y'], color='red')
ax[0] = draw_court(ax[0])
# Adjust plot limits to just fit in half court
ax[0].set_xlim(-250,250)
# Descending values along th y axis from bottom to top
# in order to place the hoop by the top of plot
ax[0].set_ylim(422.5, -47.5)
ax[0].set_title(shots1_df.PLAYER_NAME[0])
# get rid of axis tick labels
# plt.tick_params(labelbottom=False, labelleft=False)

ax[1].scatter(shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_1,'LOC_X'], shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_1,'LOC_Y'], color='green')
ax[1].scatter(shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_2,'LOC_X'], shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_2,'LOC_Y'], color='yellow')
ax[1].scatter(shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_3,'LOC_X'], shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_3,'LOC_Y'], color='orange')
ax[1].scatter(shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_4,'LOC_X'], shots2_df.loc[shots2_df.SHOT_ZONE_RANGE==range_4,'LOC_Y'], color='red')
ax[1] = draw_court(ax[1])
# Adjust plot limits to just fit in half court
ax[1].set_xlim(-250,250)
# Descending values along th y axis from bottom to top
# in order to place the hoop by the top of plot
ax[1].set_ylim(422.5, -47.5)
ax[1].set_title(shots2_df.PLAYER_NAME[0])
# get rid of axis tick labels
# plt.tick_params(labelbottom=False, labelleft=False)

plt.show();

# %% [markdown]
# ___

# %% [markdown]
# ## APIs com autenticação

# %% [markdown]
# ### Spotify
# Vamos utilizar a API do Spotify para experimentar o processo de autenticação.<br>
# <strong>O que fazer</strong>: estudando a estrutura da API para conseguir a informação desejada<br>
# <strong>Documentação</strong>: https://developer.spotify.com/documentation/web-api/<br>
# <strong>Objetivo</strong>: Qual a popularidade média da cantora Teresa Cristina e sua música mais popular?<br>
# <strong>Dica</strong>: É crítico entender a estrutura da API (quais são as possíveis requisições e quais dados cada uma entrega). Utilize o console (https://developer.spotify.com/console/) para facilitar esse entendimento.

# %%
token = '' #pegar no site
cabecalho = {'Accept': 'application/json', 'Content-Type': 'application/json', 'Authorization': 'Bearer '+token}
cabecalho
# Out:
# {'Accept': 'application/json',
#  'Content-Type': 'application/json',
#  'Authorization': 'Bearer BQAIffJTk3iJK8w8dzTcOb5KrWHEdzy0BNZxFbw-KpUyl28sN1lcDMDWwruW4IdlkH9BoquNfvDBYG9sCyePqWJ7CfGrQE6-v9B0graeDNTt-ogqKCDpvz3qAx1b3CNVKIKoBz85AwzqhLULV7QKo2ZfdtIyKHWvOpO6j0Gutg9bmR1GY3BxUlIxbPanZHdF'}

# %%
url = "https://api.spotify.com/v1/search"
q = 'Teresa Cristina'
q_type = 'artist'
market = 'BR'
parametros = {'q':q, 'type': q_type,  'market': market}
parametros
# Out:
# {'q': 'Teresa Cristina', 'type': 'artist', 'market': 'BR'}

# %%
resultado = requests.get(url, params=parametros, headers=cabecalho)

# %%
print(resultado.url)
print(json.dumps(resultado.json(), sort_keys=True, indent=2))
# Out:
# https://api.spotify.com/v1/search?q=Teresa+Cristina&type=artist&market=BR
# {
#   "artists": {
#     "href": "https://api.spotify.com/v1/search?query=Teresa+Cristina&type=artist&market=BR&offset=0&limit=20",
#     "items": [
#       {
#         "external_urls": {
#           "spotify": "https://open.spotify.com/artist/2j5unrF80yCu3AF8MPE2VE"
#         },
#         "followers": {
#           "href": null,
#           "total": 73586
#         },
#         "genres": [
#           "bossa nova",
#           "mpb",
#           "nova mpb",
#           "pagode",
#           "samba",
#           "samba moderno",
#           "velha guarda"
#         ],
#         "href": "https://api.spotify.com/v1/artists/2j5unrF80yCu3AF8MPE2VE",
#         "id": "2j5unrF80yCu3AF8MPE2VE",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/9476b5bf82750fe8121ecdda35f70d9c21dc78d0",
#             "width": 640
#           },
#           {
#             "height": 320,
#             "url": "https://i.scdn.co/image/5f7b6c9c7cf0eca85794f4aefbb85b74be6b4475",
#             "width": 320
#           },
#           {
#             "height": 160,
#             "url": "https://i.scdn.co/image/47a48a28c300cba0da022311aebc031944df04da",
#             "width": 160
#           }
#         ],
#         "name": "Teresa Cristina",
#         "popularity": 55,
#         "type": "artist",
#         "uri": "spotify:artist:2j5unrF80yCu3AF8MPE2VE"
#       },
#       {
#         "external_urls": {
#           "spotify": "https://open.spotify.com/artist/7s4sRje5zgHObX9oIqybAB"
#         },
#         "followers": {
#           "href": null,
#           "total": 826
#         },
#         "genres": [
#           "pagode",
#           "samba",
#           "velha guarda"
#         ],
#         "href": "https://api.spotify.com/v1/artists/7s4sRje5zgHObX9oIqybAB",
#         "id": "7s4sRje5zgHObX9oIqybAB",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2737922ae517b65ce329b5b3ff6",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e027922ae517b65ce329b5b3ff6",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048517922ae517b65ce329b5b3ff6",
#             "width": 64
#           }
#         ],
#         "name": "Teresa Cristina e Grupo Semente",
#         "popularity": 16,
#         "type": "artist",
#         "uri": "spotify:artist:7s4sRje5zgHObX9oIqybAB"
#       },
#       {
#         "external_urls": {
#           "spotify": "https://open.spotify.com/artist/1FRP0U7TrtqircjqkTr7i4"
#         },
#         "followers": {
#           "href": null,
#           "total": 32
#         },
#         "genres": [],
#         "href": "https://api.spotify.com/v1/artists/1FRP0U7TrtqircjqkTr7i4",
#         "id": "1FRP0U7TrtqircjqkTr7i4",
#         "images": [
#           {
#             "height": 640,
#             "url": "https://i.scdn.co/image/ab67616d0000b2730cc05e9a7368fc7f3c6b773c",
#             "width": 640
#           },
#           {
#             "height": 300,
#             "url": "https://i.scdn.co/image/ab67616d00001e020cc05e9a7368fc7f3c6b773c",
#             "width": 300
#           },
#           {
#             "height": 64,
#             "url": "https://i.scdn.co/image/ab67616d000048510cc05e9a7368fc7f3c6b773c",
#             "width": 64
#           }
#         ],
#         "name": "Teresa Cristina",
#         "popularity": 2,
#         "type": "artist",
#         "uri": "spotify:artist:1FRP0U7TrtqircjqkTr7i4"
#       },
#       {
#         "external_urls": {
#           "spotify": "https://open.spotify.com/artist/7uNCQXJRsQ4zvvNABbEq96"
#         },
#         "followers": {
#           "href": null,
#           "total": 0
#         },
#         "genres": [],
#         "href": "https://api.spotify.com/v1/artists/7uNCQXJRsQ4zvvNABbEq96",
#         "id": "7uNCQXJRsQ4zvvNABbEq96",
#         "images": [],
#         "name": "Cristina Bertol, Teresa Ponce de Le\u00f3n",
#         "popularity": 0,
#         "type": "artist",
#         "uri": "spotify:artist:7uNCQXJRsQ4zvvNABbEq96"
#       }
#     ],
#     "limit": 20,
#     "next": null,
#     "offset": 0,
#     "previous": null,
#     "total": 7
#   }
# }

# %% [markdown]
# ___

# %% [markdown]
# ## Nível 3: APIs com autenticação complexa (e/ou billing)

# %% [markdown]
# ### Google Agenda
#
# Vamos utilizar a API do Google Agenda para experimentar o processo de autenticação do Google.<br>
# <strong>O que fazer</strong>: entender aspectos da autenticação por crendenciais e tokens.<br>
# <strong>Documentação</strong>: https://developers.google.com/calendar/v3/reference<br>
# <strong>Objetivo</strong>: Trazer os próximos 4 eventos na sua agenda do Google.<br>
# <strong>Dica</strong>: o processo é complexo, mas o Google disponibiliza vários "quick start projects" funcionais. Para esse exercício podem seguir esse: https://developers.google.com/calendar/quickstart/python<br>
# <strong>Bibliotecas</strong>: pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %% [markdown]
# ### Twitter

# %% [markdown]
# ___

# %% [markdown]
# # Próximos passos
#
# Há milhares de APIs e cada uma delas tem um jeito próprio de lidar, ou seja, de fazer nossas solicitações de dados e envio de dados.
#
# Uma das muitas vantagens das APIs é tornar as soluções encaixaveis e reutilizaveis em outros programas.
#
# Na nossa área de ciência de dados, não só utilizamos APIs para consultar dados mas muitas vezes para fornecer nossa aplicação de machine learning como um serviço.
#
# Há várias plataformas que monitoram as inúmeras APIs disponíveis:
# - https://99apis.com/home
# - https://www.programmableweb.com/
# - https://rapidapi.com/
#
# Há também softwares utilizados na administração de APIs (tanto para consultas quanto para publicação). Entre os mais famosos estão o Postman (https://www.postman.com/) e o Insomnia (https://insomnia.rest/)
