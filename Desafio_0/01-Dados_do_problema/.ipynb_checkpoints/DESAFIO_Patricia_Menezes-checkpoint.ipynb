# %% [markdown]
# # DESAFIO 0

# %% [markdown]
# The period between 1970 and 1982 marked a significant shift in the United States car industry. American production shifted from heavy, powerful six- and eight-cylinder cars with poor gas mileage to lighter, less powerful, four-cylinder cars with higher fuel efficiency. The global auto industry–including Americans and their European and Japanese competitors–raised overall miles per gallon (MPG) by focusing on four-cylinder cars and making them more fuel efficient.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Faça a leitura inicial dos dados e explore suas informações, estude seus tipos, sua forma e apresente uma análise inicial das medidas de dispersão de seus atributos.

# %%
car = pd.read_csv('auto_industry.csv', encoding = 'UTF-8', sep = ',' )
car.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
car.shape
# Out:
# (398, 9)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
round(car.describe().T,2)
# Out:
#               count     mean     std     min      25%     50%      75%     max
# mpg           398.0    23.51    7.82     9.0    17.50    23.0    29.00    46.6
# cylinders     398.0     5.45    1.70     3.0     4.00     4.0     8.00     8.0
# displacement  398.0   193.43  104.27    68.0   104.25   148.5   262.00   455.0
# horsepower    392.0   104.47   38.49    46.0    75.00    93.5   126.00   230.0
# weight        398.0  2970.42  846.84  1613.0  2223.75  2803.5  3608.00  5140.0
# acceleration  398.0    15.57    2.76     8.0    13.82    15.5    17.17    24.8
# model_year    398.0    76.01    3.70    70.0    73.00    76.0    79.00    82.0

# %% [markdown]
# ## Procure por valores faltantes nas colunas do dataframe e faça as substituições mais razoáveis.

# %%
car.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
car.loc[car['horsepower'].isnull()] # Para verificar quais sao os casos NaN
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
print('Verificando o valor da moda  para fazer a substituicao de NAN por este valor')
car['horsepower'].mode()
# Out:
# Verificando o valor da moda  para fazer a substituicao de NAN por este valor
# 0    150.0
# dtype: float64

# %%
car['horsepower'].fillna(150.0, inplace = True)

# %%
print('Verificando se a substituicao foi feita', '\n\n')
car.iloc[[32,126,330,336,354,374]]
# Out:
# Verificando se a substituicao foi feita
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0       150.0    2046          19.0
# 126  21.0          6         200.0       150.0    2875          17.0
# 330  40.9          4          85.0       150.0    1835          17.3
# 336  23.6          4         140.0       150.0    2905          14.3
# 354  34.5          4         100.0       150.0    2320          15.8
# 374  23.0          4         151.0       150.0    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
print('Os valores NaN de horsepower e igual:') 

car['horsepower'].isnull().sum()
# Out:
# Os valores NaN de horsepower e igual:
# 0

# %%
car.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# ## Calcule quantos modelos foram lançados em anos pares

# %%
def model_Apares(x):
    return x % 2 == 0

# %%
print('Modelos lancados nos anos pares!!')
pares = car['model_year'].apply(model_Apares)
pares.sum()
# Out:
# Modelos lancados nos anos pares!!
# 214

# %%
print('Verificando quantos modelos foram lancados nos anos pares e nos anos impares', '\n')
pares = car['model_year'].apply(model_Apares)
pares.value_counts()
# Out:
# Verificando quantos modelos foram lancados nos anos pares e nos anos impares
# True     214
# False    184
# Name: model_year, dtype: int64

# %% [markdown]
# ## Crie uma coluna para a marca do veículo e outra para o nome

# %%
car['name'].values
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'datsun pl510', 'chevrolet vega 2300',
#        'toyota corona', 'ford pinto', 'amc gremlin',
#        'plymouth satellite custom', 'chevrolet chevelle malibu',
#        'ford torino 500', 'amc matador', 'chevrolet impala',
#        'pontiac catalina brougham', 'ford galaxie 500',
#        'plymouth fury iii', 'dodge monaco (sw)',
# ...

# %%
car[['brand car', 'name']] = car['name'].str.split(n=1, expand=True)

# %%
car.head(15)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 1   15.0          8         350.0       165.0    3693          11.5
# 2   18.0          8         318.0       150.0    3436          11.0
# 3   16.0          8         304.0       150.0    3433          12.0
# 4   17.0          8         302.0       140.0    3449          10.5
# 5   15.0          8         429.0       198.0    4341          10.0
# 6   14.0          8         454.0       220.0    4354           9.0
# 7   14.0          8         440.0       215.0    4312           8.5
# 8   14.0          8         455.0       225.0    4425          10.0
# 9   15.0          8         390.0       190.0    3850           8.5
# 10  15.0          8         383.0       170.0    3563          10.0
# 11  14.0          8         340.0       160.0    3609           8.0
# 12  15.0          8         400.0       150.0    3761           9.5
# ...

# %% [markdown]
# ## É posível identificar alguma relação entre mpg e acceleration?

# %%
print('E uma relacao fraca')
relacao = round(car['mpg'].corr(car['acceleration']),2)
# Out:
# E uma relacao fraca

# %% [raw]
# plt.figure(figsize=(20, 8)) plt.plot(c, 'o') plt.show()

# %%
plt.figure(figsize=(20, 8)) 
plt.plot(relacao, 'o') 
plt.show()

# %% [markdown]
# ## Explore a função [`get_group()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.GroupBy.get_group.html) para criar um subconjunto dos dados e analisar apenas as entradas referentes à `'origin' = usa`.

# %%
car['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
car_usa = car.groupby('origin').get_group('usa')

# %%
print( 'Quantidade de dadps referente Usa', '\n')
car_usa['origin'].value_counts()
# Out:
# Quantidade de dadps referente Usa
# usa    249
# Name: origin, dtype: int64

# %%
car_usa
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin             name  brand car
# 0            70    usa  chevelle malibu  chevrolet
# ...

# %% [markdown]
# ## Remova os elementos duplicados e crie uma tabela de consumo em (Km/L), altere os nomes dos países de orígem para que todos comecem com letras maiúsculas.

# %%
car = car.drop_duplicates()

# %%
car['origin']= car['origin'].str.title() # Alterando as primeira letra para maiuscula

# %%
car.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin             name  brand car
# 0          70    Usa  chevelle malibu  chevrolet
# 1          70    Usa      skylark 320      buick
# 2          70    Usa        satellite   plymouth
# 3          70    Usa        rebel sst        amc
# 4          70    Usa           torino       ford

# %%
car_km = pd.DataFrame(car[['mpg']].apply(lambda x: x * 0.43))
car_km = car_km.rename(columns={'mpg':'Km/L'})

# %%
car_km
# Out:
#       Km/L
# 0     7.74
# 1     6.45
# 2     7.74
# 3     6.88
# 4     7.31
# ..     ...
# 393  11.61
# 394  18.92
# 395  13.76
# 396  12.04
# 397  13.33
#
# [398 rows x 1 columns]

# %%
carKm_1 = pd.concat([car_km, car], axis = 1).drop(columns=['mpg']) # unindo a tabela carKm_1 a car e excluindo a coluna mpg
carKm_1.head(5)
# Out:
#    Km/L  cylinders  displacement  horsepower  weight  acceleration  \
# 0  7.74          8         307.0       130.0    3504          12.0
# 1  6.45          8         350.0       165.0    3693          11.5
# 2  7.74          8         318.0       150.0    3436          11.0
# 3  6.88          8         304.0       150.0    3433          12.0
# 4  7.31          8         302.0       140.0    3449          10.5
#
#    model_year origin             name  brand car
# 0          70    Usa  chevelle malibu  chevrolet
# 1          70    Usa      skylark 320      buick
# 2          70    Usa        satellite   plymouth
# 3          70    Usa        rebel sst        amc
# 4          70    Usa           torino       ford

# %% [markdown]
# ## Use a função [pivot_table()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) para criar uma tabela dinâmica que calcule a média do consumo (miles/galon) `'mpg'`. Divida o dataframe em ano de modelo `'model_year'` e número de cilindros `'cylinders'`. Estude e descreva os resultados.

# %%
car.pivot_table(['mpg'],  index='model_year', columns ='cylinders', aggfunc= {'mpg':[np.mean]})
# Out:
#              mpg
#             mean
# cylinders      3          4     5          6          8
# model_year
# 70           NaN  25.285714   NaN  20.500000  14.111111
# 71           NaN  27.461538   NaN  18.000000  13.428571
# 72          19.0  23.428571   NaN        NaN  13.615385
# 73          18.0  22.727273   NaN  19.000000  13.200000
# 74           NaN  27.800000   NaN  17.857143  14.200000
# 75           NaN  25.250000   NaN  17.583333  15.666667
# 76           NaN  26.766667   NaN  20.000000  14.666667
# 77          21.5  29.107143   NaN  19.500000  16.000000
# 78           NaN  29.576471  20.3  19.066667  19.050000
# 79           NaN  31.525000  25.4  22.950000  18.630000
# 80          23.7  34.612000  36.4  25.900000        NaN
# 81           NaN  32.814286   NaN  23.428571  26.600000
# 82           NaN  32.071429   NaN  28.333333        NaN

# %% [markdown]
# ## Agrupe o dataframe por origem  `'origin'` e número cilindros `'cylinders'` e calcule a média da potência `'horsepower'` dos carros fabricados.

# %%
car[['origin','cylinders', 'horsepower']].groupby(['origin', 'cylinders']).mean()
# Out:
#                   horsepower
# origin cylinders
# Europe 4           80.587302
#        5           82.333333
#        6          113.500000
# Japan  3           99.250000
#        4           75.579710
#        6          115.833333
# Usa    4           83.833333
#        6          100.351351
#        8          158.300971

# %% [markdown]
# ## Faça uma segregação ainda mais severa com os dados, criando uma lista de intervalos de anos (dois a dois) como corte para a leitura da média de consumo dos veículos produzidos, como agrupados por origem `'origin'`, ano de modelo `'year_model'` e número de cilindros `'cylinders'`. Discuta a evolução na média de consumo, por ano e por país e por cilindro.

# %%
carKm_1['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82])

# %%
##car['year(2-2)'] = car['model_year'].rolling(2, min_periods=2).
##car.head()

# %%
#Fazendo uma faixa de ano de 2 em 2 -comecadando no ano de 68
carKm_1['faixa_ano'] = pd.cut(carKm_1['model_year'], [68,70,71,72,74,76,78,80,82])
carKm_1.head()
# Out:
#    Km/L  cylinders  displacement  horsepower  weight  acceleration  \
# 0  7.74          8         307.0       130.0    3504          12.0
# 1  6.45          8         350.0       165.0    3693          11.5
# 2  7.74          8         318.0       150.0    3436          11.0
# 3  6.88          8         304.0       150.0    3433          12.0
# 4  7.31          8         302.0       140.0    3449          10.5
#
#    model_year origin             name  brand car faixa_ano  peso/potencia
# 0          70    Usa  chevelle malibu  chevrolet  (68, 70]          26.95
# 1          70    Usa      skylark 320      buick  (68, 70]          22.38
# 2          70    Usa        satellite   plymouth  (68, 70]          22.91
# 3          70    Usa        rebel sst        amc  (68, 70]          22.89
# 4          70    Usa           torino       ford  (68, 70]          24.64

# %%
print('Analisando consumo em km/L para cada faixa de ano', '\n')
round(carKm_1.groupby(['faixa_ano'])['Km/L'].mean(), 2)
# Out:
# Analisando consumo em km/L para cada faixa de ano
# faixa_ano
# (68, 70]     7.61
# (70, 72]     8.59
# (72, 74]     8.32
# (74, 76]     9.01
# (76, 78]    10.22
# (78, 80]    12.64
# (80, 82]    13.35
# Name: Km/L, dtype: float64

# %%
print('Analisando consumo em km/L para cada país', '\n')
round(carKm_1.groupby(['origin'])['Km/L'].mean(), 2)
# Out:
# Analisando consumo em km/L para cada país
# origin
# Europe    11.99
# Japan     13.09
# Usa        8.64
# Name: Km/L, dtype: float64

# %%
print('Analisando consumo em km/L po ano de Fabricacao', '\n')
round(carKm_1.groupby(['model_year'])['Km/L'].mean(), 2)
# Out:
# Analisando consumo em km/L po ano de Fabricacao
# model_year
# 70     7.61
# 71     9.14
# 72     8.05
# 73     7.35
# 74     9.76
# 75     8.71
# 76     9.28
# 77    10.05
# 78    10.35
# 79    10.79
# 80    14.49
# 81    13.04
# 82    13.64
# Name: Km/L, dtype: float64

# %%
print('Analisando consumo em km/L por Cilindros', '\n')
round(carKm_1.groupby(['cylinders'])['Km/L'].mean(), 2)
# Out:
# Analisando consumo em km/L por Cilindros
# cylinders
# 3     8.84
# 4    12.59
# 5    11.77
# 6     8.59
# 8     6.43
# Name: Km/L, dtype: float64

# %%
print('Evolução da média de consumo (km/L) por país', '\n')
carKm_1.pivot_table(values = 'Km/L', index = 'origin', columns = 'faixa_ano', aggfunc = 'mean')
# Out:
# Evolução da média de consumo (km/L) por país
# faixa_ano   (68, 70]   (70, 72]   (72, 74]   (74, 76]   (76, 78]   (78, 80]  \
# origin
# Europe     10.836000  10.750000  10.915385  10.473571  11.468100  15.129385
# Japan      10.965000  11.418889  11.008000  11.932500  12.347143  15.081533
# Usa         6.567273   7.411842   6.948409   7.970357   9.159000  10.340067
#
# faixa_ano   (80, 82]
# origin
# Europe     14.784833
# Japan      14.527857
# Usa        12.338394

# %% [markdown]
# ## Crie uma nova coluna que reflita a região mundial em que as origens dos veículos se encontram, certifique-se de que essa coluna também conterá valores que começam com letras maiúsculas.

# %%
world_region= {
           'Usa': 'North america',
           'Europe': 'Europe',
           'Japan': 'Asia'}

# %%
world_region
# Out:
# {'Usa': 'North america', 'Europe': 'Europe', 'Japan': 'Asia'}

# %%
pd.DataFrame(world_region.values(),index=world_region.keys()).reset_index().rename({0:'world_region'},axis=1)
# Out:
#     index   world_region
# 0     Usa  North america
# 1  Europe         Europe
# 2   Japan           Asia

# %%
car['world_region'] = car['origin'].apply(str.title).map(world_region)
car.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin             name  brand car  year(2-2)   world_region
# 0          70    Usa  chevelle malibu  chevrolet        NaN  North america
# 1          70    Usa      skylark 320      buick        2.0  North america
# 2          70    Usa        satellite   plymouth        2.0  North america
# 3          70    Usa        rebel sst        amc        2.0  North america
# 4          70    Usa           torino       ford        2.0  North america

# %%
car = car[['mpg', 'cylinders', 'displacement',	'horsepower', 'weight',	'acceleration',	'model_year',\
           'origin', 'world_region', 'name',	'brand car']]
car.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin   world_region             name  brand car
# 0          70    Usa  North america  chevelle malibu  chevrolet
# 1          70    Usa  North america      skylark 320      buick
# 2          70    Usa  North america        satellite   plymouth
# 3          70    Usa  North america        rebel sst        amc
# 4          70    Usa  North america           torino       ford

# %% [markdown]
# # Bônus - estatística

# %% [markdown]
# ## Apresente a centralidade, dispersão e distribuição das variáveis

# %%
round(car.mean(),2)
# Out:
# mpg               23.51
# cylinders          5.45
# displacement     193.43
# horsepower       105.16
# weight          2970.42
# acceleration      15.57
# model_year        76.01
# dtype: float64

# %%
car.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  13.0        4.0          97.0       150.0    1985          14.5
# 1   NaN        NaN           NaN         NaN    2130           NaN
#
#    model_year origin   world_region   name brand car
# 0        73.0    Usa  North america  pinto      ford
# 1         NaN    NaN            NaN    NaN       NaN

# %%
car.median()
# Out:
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# horsepower        95.0
# weight          2803.5
# acceleration      15.5
# model_year        76.0
# dtype: float64

# %%
round(car.std(),2)
# Out:
# mpg               7.82
# cylinders         1.70
# displacement    104.27
# horsepower       38.60
# weight          846.84
# acceleration      2.76
# model_year        3.70
# dtype: float64

# %%
round(car.var(),2)
# Out:
# mpg                 61.09
# cylinders            2.89
# displacement     10872.20
# horsepower        1490.04
# weight          717140.99
# acceleration         7.60
# model_year          13.67
# dtype: float64

# %%
round(car.cov(),2)
# Out:
#                   mpg  cylinders  displacement  horsepower     weight  \
# mpg             61.09     -10.31       -655.40     -227.24   -5505.21
# cylinders      -10.31       2.89        168.62       53.74    1290.70
# displacement  -655.40     168.62      10872.20     3515.08   82368.42
# horsepower    -227.24      53.74       3515.08     1490.04   27516.56
# weight       -5505.21    1290.70      82368.42    27516.56  717140.99
# acceleration     9.06      -2.37       -156.33      -70.88    -974.90
# model_year      16.74      -2.19       -142.72      -56.77    -959.95
#
#               acceleration  model_year
# mpg                   9.06       16.74
# cylinders            -2.37       -2.19
# displacement       -156.33     -142.72
# horsepower          -70.88      -56.77
# weight             -974.90     -959.95
# acceleration          7.60        2.94
# model_year            2.94       13.67

# %% [markdown]
# ## Gere matriz e gráfico de correlação

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10,6))
plt.title('Matriz de correlacao')
sns.heatmap(car.corr(), cmap='Greens', annot= True) #matriz de correlação
plt.show()

# %%
car.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.753177 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.818454  0.896017
# displacement -0.804203   0.950721      1.000000    0.873330  0.932824
# horsepower   -0.753177   0.818454      0.873330    1.000000  0.841770
# weight       -0.831741   0.896017      0.932824    0.841770  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.665833 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.397772 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.665833   -0.397772
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %% [markdown]
# ## Eliminando os elementos `'origin'`, `'name'`, `'model_year'`, calcule a matriz de correlação entre atributos remanecentes, incluindo apenas aquelas correlações em que o módulo supera o corte de `0.8`, discuta também suas relações de proporcionalidade.

# %%
car_1 = car.drop(['origin', 'name', 'model_year'], axis=1)
car_1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#     world_region  brand car
# 0  North america  chevrolet
# 1  North america      buick
# 2  North america   plymouth
# 3  North america        amc
# 4  North america       ford

# %%
plt.figure(figsize=(10,6))
sns.heatmap(car_1.corr(),vmin=0.8, cmap='Blues', annot= True )
plt.show()

# %% [markdown]
# # Bonus - DataViz

# %% [markdown]
# ## Gere gráficos de boxplots para todos os elementos numéricos do dataframe.

# %%
plt.figure(1, figsize=(20, 10))

plt.subplot(241)
plt.boxplot(car['mpg'])
plt.legend(['MPG'])

plt.subplot(242)
plt.boxplot(car['cylinders'])
plt.legend(['Cylinders'])

plt.subplot(243)
plt.boxplot(car['displacement'])
plt.legend(['Displacement'])

plt.subplot(244)
plt.boxplot(car['horsepower'])
plt.legend(['Horsepower'])


plt.subplot(245)
plt.boxplot(car['weight'])
plt.legend(['Weight'])

plt.subplot(246)
plt.boxplot(car['acceleration'])
plt.legend(['Acceleration'])

plt.subplot(247)
plt.boxplot(car['model_year'])
plt.legend(['Model_year'])

plt.suptitle('Grafico dos Elementos Numericos', size=20)

plt.show;

# %% [markdown]
# ## Crie uma nova coluna com a relação peso/potência para cada veículo e plote um gráfico de dispersão dessa coluna com a de consumo que você criou

# %%
carKm_1['peso/potencia'] = round(carKm_1['weight'] / carKm_1['horsepower'], 2)
carKm_1.head()
# Out:
#    Km/L  cylinders  displacement  horsepower  weight  acceleration  \
# 0  7.74          8         307.0       130.0    3504          12.0
# 1  6.45          8         350.0       165.0    3693          11.5
# 2  7.74          8         318.0       150.0    3436          11.0
# 3  6.88          8         304.0       150.0    3433          12.0
# 4  7.31          8         302.0       140.0    3449          10.5
#
#    model_year origin             name  brand car faixa_ano  peso/potencia
# 0          70    Usa  chevelle malibu  chevrolet  (68, 70]          26.95
# 1          70    Usa      skylark 320      buick  (68, 70]          22.38
# 2          70    Usa        satellite   plymouth  (68, 70]          22.91
# 3          70    Usa        rebel sst        amc  (68, 70]          22.89
# 4          70    Usa           torino       ford  (68, 70]          24.64

# %%
plt.figure(figsize=(10,5))
plt.scatter(carKm_1['Km/L'], carKm_1['peso/potencia'])
plt.xlabel('Km/L')
plt.ylabel('peso/potência')
plt.title('Correlação')
plt.show()
